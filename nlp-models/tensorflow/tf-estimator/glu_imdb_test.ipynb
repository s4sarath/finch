# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# <img src="img/glu.png" width="200">
#
# $$ Y = X \otimes [1 - \sigma( \space Conv1D_2(X) \space )] \space + \space Conv1D_1(X) \otimes \sigma( \space Conv1D_2(X) \space ) $$
#
# $$ Y = X + ( \space Conv1D_1(X) - X \space ) \otimes \sigma( \space Conv1D_2(X) \space ) $$
#
# $$ \text{Assume} \space \space Conv1D_1(X) \space \space \text{learns} \space \space ( \space Conv1D_1(X) - X \space) $$
#
# $$ Y = X + Conv1D_1(X) \otimes \sigma( \space Conv1D_2(X) \space ) $$

# %%
import tensorflow as tf
import numpy as np

# %%
VOCAB_SIZE = 5000
MAX_LEN = 400
BATCH_SIZE = 32
K_SIZE = 3
EMBED_DIM = 50
N_CLASS = 2
N_EPOCH = 2
LR = {'start': 5e-3, 'end': 5e-4, 'steps': 1500}

# %%
def gated_linear_unit(x, dilation_rate):
    c = tf.layers.conv1d(inputs = x,
                         filters = 2*EMBED_DIM,
                         kernel_size = K_SIZE,
                         dilation_rate=dilation_rate,
                         padding = 'same')
    c1, c2 = tf.split(c, 2, -1)
    x += c1 * tf.sigmoid(c2)
    return x


def forward(x, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    
    x = tf.contrib.layers.embed_sequence(x, VOCAB_SIZE, EMBED_DIM)
    x = tf.layers.dropout(x, 0.2, training=is_training)
    
    for dilation_rate in [1, 2, 4]:
        x = gated_linear_unit(x, dilation_rate)
    
    x = tf.reduce_max(x, 1)
    x = tf.layers.flatten(x)
    
    x = tf.layers.dropout(x, 0.2, training=is_training)
    x = tf.layers.dense(x, EMBED_DIM, tf.nn.relu)
    logits = tf.layers.dense(x, N_CLASS)
    return logits


def model_fn(features, labels, mode):
    logits = forward(features, mode)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        preds = tf.argmax(logits, -1)
        return tf.estimator.EstimatorSpec(mode, predictions=preds)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        global_step = tf.train.get_global_step()

        lr_op = tf.train.exponential_decay(
            LR['start'], global_step, LR['steps'], LR['end']/LR['start'])

        loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(
            logits=logits, labels=labels))

        train_op = tf.train.AdamOptimizer(lr_op).minimize(
            loss_op, global_step=global_step)

        lth = tf.train.LoggingTensorHook({'lr': lr_op}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=VOCAB_SIZE)
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, MAX_LEN)
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, MAX_LEN)

estimator = tf.estimator.Estimator(model_fn)

for _ in range(N_EPOCH):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = X_train, y = y_train,
        batch_size = BATCH_SIZE,
        shuffle = True))
    y_pred = np.fromiter(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = X_test,
        batch_size = BATCH_SIZE,
        shuffle = False)), np.int32)
    print("\nValidation Accuracy: %.4f\n" % (y_pred==y_test).mean())
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11879f550>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia/model.ckpt.
# INFO:tensorflow:loss = 0.6947588, step = 1
# INFO:tensorflow:lr = 0.005
# INFO:tensorflow:global_step/sec: 10.7799
# INFO:tensorflow:loss = 0.36111224, step = 101 (9.278 sec)
# INFO:tensorflow:lr = 0.004288479 (9.278 sec)
# INFO:tensorflow:global_step/sec: 11.1681
# INFO:tensorflow:loss = 0.2832433, step = 201 (8.954 sec)
# INFO:tensorflow:lr = 0.0036782112 (8.955 sec)
# INFO:tensorflow:global_step/sec: 11.5506
# INFO:tensorflow:loss = 0.46424508, step = 301 (8.657 sec)
# INFO:tensorflow:lr = 0.0031547868 (8.657 sec)
# INFO:tensorflow:global_step/sec: 12.2965
# INFO:tensorflow:loss = 0.34958476, step = 401 (8.133 sec)
# INFO:tensorflow:lr = 0.0027058476 (8.132 sec)
# INFO:tensorflow:global_step/sec: 12.3482
# INFO:tensorflow:loss = 0.40976176, step = 501 (8.098 sec)
# INFO:tensorflow:lr = 0.0023207942 (8.098 sec)
# INFO:tensorflow:global_step/sec: 11.802
# INFO:tensorflow:loss = 0.35335207, step = 601 (8.473 sec)
# INFO:tensorflow:lr = 0.0019905358 (8.473 sec)
# INFO:tensorflow:global_step/sec: 11.5816
# INFO:tensorflow:loss = 0.30573878, step = 701 (8.634 sec)
# INFO:tensorflow:lr = 0.0017072745 (8.634 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.31926906.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.8912
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia/model.ckpt.
# INFO:tensorflow:loss = 0.25274086, step = 783
# INFO:tensorflow:lr = 0.0015053472
# INFO:tensorflow:global_step/sec: 11.6193
# INFO:tensorflow:loss = 0.23518002, step = 883 (8.608 sec)
# INFO:tensorflow:lr = 0.00129113 (8.607 sec)
# INFO:tensorflow:global_step/sec: 10.9637
# INFO:tensorflow:loss = 0.29234618, step = 983 (9.121 sec)
# INFO:tensorflow:lr = 0.001107397 (9.121 sec)
# INFO:tensorflow:global_step/sec: 11.0424
# INFO:tensorflow:loss = 0.24859089, step = 1083 (9.056 sec)
# INFO:tensorflow:lr = 0.00094980985 (9.056 sec)
# INFO:tensorflow:global_step/sec: 10.7458
# INFO:tensorflow:loss = 0.08109589, step = 1183 (9.306 sec)
# INFO:tensorflow:lr = 0.00081464805 (9.306 sec)
# INFO:tensorflow:global_step/sec: 11.2785
# INFO:tensorflow:loss = 0.22115585, step = 1283 (8.866 sec)
# INFO:tensorflow:lr = 0.0006987203 (8.866 sec)
# INFO:tensorflow:global_step/sec: 11.3229
# INFO:tensorflow:loss = 0.1704095, step = 1383 (8.832 sec)
# INFO:tensorflow:lr = 0.00059928955 (8.831 sec)
# INFO:tensorflow:global_step/sec: 11.3604
# INFO:tensorflow:loss = 0.05618495, step = 1483 (8.803 sec)
# INFO:tensorflow:lr = 0.00051400816 (8.802 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.034203455.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmph3s6naia/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Validation Accuracy: 0.8954
