# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# <img src="cnn_vae.png" width="300">

# %%
import tensorflow as tf
import numpy as np

# %%
PARAMS = {
    'max_len': 15,
    'vocab_size': 10000,
    'embed_dims': 128,
    'rnn_size': 128,
    'cnn_size': 128,
    'latent_size': 16,
    'kernel_sz': 3,
    'n_hidden_layer': 3,
    'clip_norm': 5.0,
    'anneal_max': 1.0,
    'anneal_bias': 6000,
    'batch_size': 128,
    'n_epochs': 10,
}

# %%
def build_vocab(index_from=4):
    PARAMS['word2idx'] = tf.keras.datasets.imdb.get_word_index()
    PARAMS['word2idx'] = {k: (v + index_from) for k, v in PARAMS['word2idx'].items()}
    PARAMS['word2idx']['<pad>'] = 0
    PARAMS['word2idx']['<start>'] = 1
    PARAMS['word2idx']['<unk>'] = 2
    PARAMS['word2idx']['<end>'] = 3
    PARAMS['idx2word'] = {i: w for w, i in PARAMS['word2idx'].items()}

    
def load_data(index_from=4):
    (X_train, _), (X_test, _) = tf.contrib.keras.datasets.imdb.load_data(
        num_words=PARAMS['vocab_size'], index_from=index_from)
    return (X_train, X_test)

# %%
word2idx = build_vocab()
X = np.concatenate(load_data())

X = np.concatenate((
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='post', padding='post'),
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='pre', padding='post')))

enc_inp = X[:, 1:]
dec_inp = X
dec_out = np.concatenate([X[:, 1:], np.full([X.shape[0], 1], PARAMS['word2idx']['<end>'])], 1)

# %%
def kl_w_fn(global_step):
    return PARAMS['anneal_max'] * tf.sigmoid((10 / PARAMS['anneal_bias']) * (
        tf.to_float(global_step) - tf.constant(PARAMS['anneal_bias'] / 2)))


def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, PARAMS['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    return tf.nn.rnn_cell.GRUCell(PARAMS['rnn_size'],
                                  kernel_initializer=tf.orthogonal_initializer())


def cnn_block(x, dilation_rate, pad_sz):
    pad = tf.zeros([tf.shape(x)[0], pad_sz, x.get_shape()[-1].value])
    x =  tf.layers.conv1d(inputs = tf.concat([pad, x, pad], 1),
                          filters = PARAMS['cnn_size'],
                          kernel_size = PARAMS['kernel_sz'],
                          dilation_rate = dilation_rate)
    x = x[:, :-pad_sz, :]
    x = tf.nn.relu(x)
    return x


def cnn_forward(x, output_proj):
    for i in range(PARAMS['n_hidden_layer']):
        dilation_rate = 2 ** i
        pad_sz = (PARAMS['kernel_sz'] - 1) * dilation_rate
        x += cnn_block(x, dilation_rate, pad_sz)
        logits = output_proj(x)
    return logits


def autoregressive(embedding, z, input_proj, output_proj):
    batch_sz = tf.shape(z)[0]
    
    def cond(i, x, temp):
        return i < PARAMS['max_len']

    def body(i, x, temp):
        sos = tf.fill([batch_sz, 1], PARAMS['word2idx']['<start>'])
        x = tf.concat([sos, x[:, :-1]], 1)
        
        x = tf.nn.embedding_lookup(embedding, x)
        x = input_proj(tf.concat([x, z], -1))
        logits = cnn_forward(x, output_proj)
        ids = tf.argmax(logits, -1, output_type=tf.int32)[:, i]
        ids = tf.expand_dims(ids, -1)

        temp = tf.concat([temp[:, 1:], ids], -1)

        x = tf.concat([temp[:, -(i+1):], temp[:, :-(i+1)]], -1)
        x = tf.reshape(x, [batch_sz, PARAMS['max_len']])
        i += 1
        return i, x, temp
    
    x = tf.zeros([batch_sz, PARAMS['max_len']], tf.int32)
    _, res, _ = tf.while_loop(cond, body, [tf.constant(0), x, x])
    
    return res

# %%
def forward(inputs, labels, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    enc_seq_len = tf.count_nonzero(inputs, 1, dtype=tf.int32)
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('Encoder'):
        embedding = tf.get_variable('lookup_table', [PARAMS['vocab_size'],
                                                     PARAMS['embed_dims']])
        x = tf.nn.embedding_lookup(embedding, inputs)
        
        _, enc_state = tf.nn.dynamic_rnn(rnn_cell(), x, enc_seq_len, dtype=tf.float32)
        
        z_mean = tf.layers.dense(enc_state, PARAMS['latent_size'])
        z_var = tf.layers.dense(enc_state, PARAMS['latent_size'])
        
    posterior = tf.contrib.distributions.MultivariateNormalDiag(z_mean, z_var)
    prior = tf.contrib.distributions.MultivariateNormalDiag(tf.zeros_like(z_mean),
                                                            tf.ones_like(z_var))
        
    with tf.variable_scope('Decoder'):
        input_proj = tf.layers.Dense(PARAMS['cnn_size'], tf.nn.relu)
        output_proj = tf.layers.Dense(PARAMS['vocab_size'])
        z = tf.tile(tf.expand_dims(posterior.sample(), 1), [1, PARAMS['max_len'], 1])
        
        if is_training:
            dec_inp = tf.nn.embedding_lookup(embedding, labels['dec_inp'])
            x = input_proj(tf.concat([dec_inp, z], -1))
            logits = cnn_forward(x, output_proj)
            return logits, posterior, prior
        else:
            return autoregressive(embedding, z, input_proj, output_proj)

# %%
def model_fn(features, labels, mode):
    logits_or_ids = forward(features, labels, mode)        
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
        
    if mode == tf.estimator.ModeKeys.TRAIN:
        logits, posterior, prior = logits_or_ids
        
        out_dist = tf.distributions.Categorical(logits)
        
        global_step = tf.train.get_global_step()
        
        nll_loss = - tf.reduce_sum(out_dist.log_prob(labels['dec_out']))
        
        kl_w = kl_w_fn(global_step)
        
        kl_loss = tf.reduce_sum(tf.distributions.kl_divergence(posterior, prior))
        
        loss_op = nll_loss + kl_w * kl_loss
        
        train_op = tf.train.AdamOptimizer().apply_gradients(
            clip_grads(loss_op),
            global_step = global_step)
        
        lth = tf.train.LoggingTensorHook(
            {'nll_loss': nll_loss, 'kl_w': kl_w, 'kl_loss': kl_loss}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
def inf_inp(test_strs):
    x = [[PARAMS['word2idx'].get(w, 2) for w in s.split()] for s in test_strs]
    x = tf.keras.preprocessing.sequence.pad_sequences(
        x, PARAMS['max_len'], truncating='post', padding='post')
    return x

def demo(test_strs, pred_ids):
    for s, pred in zip(test_strs, pred_ids):
        print('\nOriginal:', s)
        print('Reconstr:', ' '.join([PARAMS['idx2word'].get(idx, '<unk>') for idx in pred]))


test_strs = ['i love this film and i think it is one of the best films',
             'this movie is a waste of time and there is no point to watch it']

estimator = tf.estimator.Estimator(model_fn)

for _ in range(PARAMS['n_epochs']):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = enc_inp,
        y = {'dec_inp': dec_inp, 'dec_out': dec_out},
        batch_size = PARAMS['batch_size'],
        shuffle = True))
    
    pred_ids = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = inf_inp(test_strs),
        shuffle = False)))

    demo(test_strs, pred_ids)
    
    print()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1144dca20>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 17755.557, step = 1
# INFO:tensorflow:nll_loss = 17682.188, kl_w = 0.006692851, kl_loss = 10962.307
# INFO:tensorflow:global_step/sec: 1.8891
# INFO:tensorflow:loss = 11610.865, step = 101 (52.936 sec)
# INFO:tensorflow:nll_loss = 11578.313, kl_w = 0.007897083, kl_loss = 4121.9644 (52.936 sec)
# INFO:tensorflow:global_step/sec: 2.00544
# INFO:tensorflow:loss = 10914.337, step = 201 (49.864 sec)
# INFO:tensorflow:nll_loss = 10877.838, kl_w = 0.009315956, kl_loss = 3917.955 (49.864 sec)
# INFO:tensorflow:global_step/sec: 1.90282
# INFO:tensorflow:loss = 10314.255, step = 301 (52.554 sec)
# INFO:tensorflow:nll_loss = 10270.682, kl_w = 0.010986943, kl_loss = 3965.9429 (52.554 sec)
# INFO:tensorflow:global_step/sec: 1.8407
# INFO:tensorflow:loss = 9889.231, step = 401 (54.327 sec)
# INFO:tensorflow:nll_loss = 9830.643, kl_w = 0.012953726, kl_loss = 4522.969 (54.327 sec)
# INFO:tensorflow:global_step/sec: 1.8163
# INFO:tensorflow:loss = 9502.44, step = 501 (55.057 sec)
# INFO:tensorflow:nll_loss = 9436.623, kl_w = 0.015267149, kl_loss = 4311.051 (55.057 sec)
# INFO:tensorflow:global_step/sec: 1.82709
# INFO:tensorflow:loss = 9094.104, step = 601 (54.732 sec)
# INFO:tensorflow:nll_loss = 9010.799, kl_w = 0.01798621, kl_loss = 4631.566 (54.732 sec)
# INFO:tensorflow:global_step/sec: 1.77572
# INFO:tensorflow:loss = 9006.207, step = 701 (56.315 sec)
# INFO:tensorflow:nll_loss = 8904.521, kl_w = 0.021179108, kl_loss = 4801.2227 (56.315 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2104.4636.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this movie is one of all <unk> i am <unk> <unk> i <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is one of the worst movies i have ever seen that the best <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 9745.526, step = 783
# INFO:tensorflow:nll_loss = 9623.93, kl_w = 0.024205629, kl_loss = 5023.505
# INFO:tensorflow:global_step/sec: 1.95578
# INFO:tensorflow:loss = 8110.398, step = 883 (51.132 sec)
# INFO:tensorflow:nll_loss = 7972.1416, kl_w = 0.028470589, kl_loss = 4856.109 (51.132 sec)
# INFO:tensorflow:global_step/sec: 1.81495
# INFO:tensorflow:loss = 8307.367, step = 983 (55.098 sec)
# INFO:tensorflow:nll_loss = 8147.181, kl_w = 0.033461247, kl_loss = 4787.22 (55.098 sec)
# INFO:tensorflow:global_step/sec: 1.71316
# INFO:tensorflow:loss = 8080.206, step = 1083 (58.372 sec)
# INFO:tensorflow:nll_loss = 7883.0024, kl_w = 0.039291352, kl_loss = 5019.0137 (58.372 sec)
# INFO:tensorflow:global_step/sec: 1.80927
# INFO:tensorflow:loss = 8187.072, step = 1183 (55.271 sec)
# INFO:tensorflow:nll_loss = 7974.5073, kl_w = 0.04608883, kl_loss = 4612.0586 (55.271 sec)
# INFO:tensorflow:global_step/sec: 1.78287
# INFO:tensorflow:loss = 8944.45, step = 1283 (56.089 sec)
# INFO:tensorflow:nll_loss = 8702.241, kl_w = 0.053996176, kl_loss = 4485.671 (56.089 sec)
# INFO:tensorflow:global_step/sec: 1.84641
# INFO:tensorflow:loss = 8556.666, step = 1383 (54.159 sec)
# INFO:tensorflow:nll_loss = 8282.264, kl_w = 0.06317033, kl_loss = 4343.849 (54.159 sec)
# INFO:tensorflow:global_step/sec: 1.74391
# INFO:tensorflow:loss = 8835.108, step = 1483 (57.342 sec)
# INFO:tensorflow:nll_loss = 8520.773, kl_w = 0.07378165, kl_loss = 4260.335 (57.342 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2180.2292.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i have seen it <unk> br br this is <unk> and watch the <unk> <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is one of the movie i am not <unk> what the end it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1565 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 8308.304, step = 1565
# INFO:tensorflow:nll_loss = 7948.446, kl_w = 0.08368247, kl_loss = 4300.273
# INFO:tensorflow:global_step/sec: 1.88242
# INFO:tensorflow:loss = 8383.834, step = 1665 (53.124 sec)
# INFO:tensorflow:nll_loss = 7965.041, kl_w = 0.09738124, kl_loss = 4300.555 (53.124 sec)
# INFO:tensorflow:global_step/sec: 1.75947
# INFO:tensorflow:loss = 7985.9033, step = 1765 (56.836 sec)
# INFO:tensorflow:nll_loss = 7519.0537, kl_w = 0.11304584, kl_loss = 4129.7393 (56.836 sec)
# INFO:tensorflow:global_step/sec: 1.59929
# INFO:tensorflow:loss = 8045.7544, step = 1865 (62.528 sec)
# INFO:tensorflow:nll_loss = 7536.086, kl_w = 0.13086486, kl_loss = 3894.617 (62.528 sec)
# INFO:tensorflow:global_step/sec: 1.53943
# INFO:tensorflow:loss = 7848.4736, step = 1965 (64.959 sec)
# INFO:tensorflow:nll_loss = 7250.2017, kl_w = 0.15101443, kl_loss = 3961.6868 (64.959 sec)
# INFO:tensorflow:global_step/sec: 1.73917
# INFO:tensorflow:loss = 7708.9287, step = 2065 (57.499 sec)
# INFO:tensorflow:nll_loss = 7022.2373, kl_w = 0.17364664, kl_loss = 3954.5342 (57.499 sec)
# INFO:tensorflow:global_step/sec: 1.80313
# INFO:tensorflow:loss = 8725.202, step = 2165 (55.459 sec)
# INFO:tensorflow:nll_loss = 8027.962, kl_w = 0.19887616, kl_loss = 3505.8997 (55.459 sec)
# INFO:tensorflow:global_step/sec: 1.7478
# INFO:tensorflow:loss = 8693.917, step = 2265 (57.215 sec)
# INFO:tensorflow:nll_loss = 7913.172, kl_w = 0.22676536, kl_loss = 3442.963 (57.215 sec)
# INFO:tensorflow:Saving checkpoints for 2346 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2194.2625.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i love this film and i recommend it is a lot of <unk> <unk> <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this one is a bad movie for me the actors were <unk> it sucks <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2347 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 8426.693, step = 2347
# INFO:tensorflow:nll_loss = 7661.887, kl_w = 0.25161827, kl_loss = 3039.5479
# INFO:tensorflow:global_step/sec: 1.82895
# INFO:tensorflow:loss = 8603.323, step = 2447 (54.678 sec)
# INFO:tensorflow:nll_loss = 7803.9336, kl_w = 0.2842792, kl_loss = 2811.989 (54.678 sec)
# INFO:tensorflow:global_step/sec: 1.88272
# INFO:tensorflow:loss = 8154.515, step = 2547 (53.115 sec)
# INFO:tensorflow:nll_loss = 7272.268, kl_w = 0.31937042, kl_loss = 2762.4575 (53.115 sec)
# INFO:tensorflow:global_step/sec: 1.78238
# INFO:tensorflow:loss = 7914.1626, step = 2647 (56.104 sec)
# INFO:tensorflow:nll_loss = 6947.905, kl_w = 0.35663486, kl_loss = 2709.376 (56.104 sec)
# INFO:tensorflow:global_step/sec: 1.80391
# INFO:tensorflow:loss = 7764.6914, step = 2747 (55.435 sec)
# INFO:tensorflow:nll_loss = 6718.3203, kl_w = 0.39571938, kl_loss = 2644.2244 (55.436 sec)
# INFO:tensorflow:global_step/sec: 1.79841
# INFO:tensorflow:loss = 7898.467, step = 2847 (55.605 sec)
# INFO:tensorflow:nll_loss = 6783.879, kl_w = 0.43618327, kl_loss = 2555.3203 (55.605 sec)
# INFO:tensorflow:global_step/sec: 1.80338
# INFO:tensorflow:loss = 8757.445, step = 2947 (55.451 sec)
# INFO:tensorflow:nll_loss = 7688.2627, kl_w = 0.47751516, kl_loss = 2239.0557 (55.451 sec)
# INFO:tensorflow:global_step/sec: 1.69815
# INFO:tensorflow:loss = 8830.973, step = 3047 (58.887 sec)
# INFO:tensorflow:nll_loss = 7714.5767, kl_w = 0.5191573, kl_loss = 2150.401 (58.887 sec)
# INFO:tensorflow:Saving checkpoints for 3128 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2254.0933.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i love this movie and <unk> it is one of the worst movies of <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this film is worth a watch and if the <unk> it will be warned <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3129 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 8621.173, step = 3129
# INFO:tensorflow:nll_loss = 7459.351, kl_w = 0.55313194, kl_loss = 2100.4424
# INFO:tensorflow:global_step/sec: 1.67884
# INFO:tensorflow:loss = 8341.883, step = 3229 (59.566 sec)
# INFO:tensorflow:nll_loss = 7092.682, kl_w = 0.5938731, kl_loss = 2103.4817 (59.567 sec)
# INFO:tensorflow:global_step/sec: 1.71818
# INFO:tensorflow:loss = 8708.67, step = 3329 (58.201 sec)
# INFO:tensorflow:nll_loss = 7531.8955, kl_w = 0.6333619, kl_loss = 1857.9805 (58.201 sec)
# INFO:tensorflow:global_step/sec: 1.77881
# INFO:tensorflow:loss = 8812.982, step = 3429 (56.217 sec)
# INFO:tensorflow:nll_loss = 7606.7876, kl_w = 0.6711373, kl_loss = 1797.2397 (56.217 sec)
# INFO:tensorflow:global_step/sec: 1.78615
# INFO:tensorflow:loss = 8918.654, step = 3529 (55.986 sec)
# INFO:tensorflow:nll_loss = 7704.9873, kl_w = 0.7068222, kl_loss = 1717.0752 (55.987 sec)
# INFO:tensorflow:global_step/sec: 1.77398
# INFO:tensorflow:loss = 8876.972, step = 3629 (56.371 sec)
# INFO:tensorflow:nll_loss = 7722.027, kl_w = 0.7401343, kl_loss = 1560.4532 (56.371 sec)
# INFO:tensorflow:global_step/sec: 1.82852
# INFO:tensorflow:loss = 9025.774, step = 3729 (54.689 sec)
# INFO:tensorflow:nll_loss = 7897.8145, kl_w = 0.7708882, kl_loss = 1463.1953 (54.689 sec)
# INFO:tensorflow:global_step/sec: 1.842
# INFO:tensorflow:loss = 8650.28, step = 3829 (54.289 sec)
# INFO:tensorflow:nll_loss = 7537.4023, kl_w = 0.79899096, kl_loss = 1392.8538 (54.289 sec)
# INFO:tensorflow:Saving checkpoints for 3910 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2271.0798.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this movie is a great movie and i love and it is so many <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this film is a bad movie the movie was hard to watch it <unk> <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3911 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 9256.468, step = 3911
# INFO:tensorflow:nll_loss = 8121.6387, kl_w = 0.82004714, kl_loss = 1383.858
# INFO:tensorflow:global_step/sec: 1.74731
# INFO:tensorflow:loss = 8824.6, step = 4011 (57.232 sec)
# INFO:tensorflow:nll_loss = 7781.9995, kl_w = 0.84334546, kl_loss = 1236.2668 (57.232 sec)
# INFO:tensorflow:global_step/sec: 1.80763
# INFO:tensorflow:loss = 8876.012, step = 4111 (55.321 sec)
# INFO:tensorflow:nll_loss = 7879.674, kl_w = 0.8641271, kl_loss = 1152.9998 (55.321 sec)
# INFO:tensorflow:global_step/sec: 1.82499
# INFO:tensorflow:loss = 8493.4375, step = 4211 (54.795 sec)
# INFO:tensorflow:nll_loss = 7533.0596, kl_w = 0.88253593, kl_loss = 1088.2021 (54.795 sec)
# INFO:tensorflow:global_step/sec: 1.81909
# INFO:tensorflow:loss = 8432.538, step = 4311 (54.973 sec)
# INFO:tensorflow:nll_loss = 7535.965, kl_w = 0.89874285, kl_loss = 997.5858 (54.973 sec)
# INFO:tensorflow:global_step/sec: 1.9146
# INFO:tensorflow:loss = 8598.258, step = 4411 (52.230 sec)
# INFO:tensorflow:nll_loss = 7772.7705, kl_w = 0.9129343, kl_loss = 904.2131 (52.231 sec)
# INFO:tensorflow:global_step/sec: 1.92334
# INFO:tensorflow:loss = 8606.746, step = 4511 (51.993 sec)
# INFO:tensorflow:nll_loss = 7822.55, kl_w = 0.92530197, kl_loss = 847.50354 (51.992 sec)
# INFO:tensorflow:global_step/sec: 1.8997
# INFO:tensorflow:loss = 9237.353, step = 4611 (52.640 sec)
# INFO:tensorflow:nll_loss = 8551.577, kl_w = 0.93603605, kl_loss = 732.63794 (52.640 sec)
# INFO:tensorflow:Saving checkpoints for 4692 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2311.4697.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this is one of the best films i have ever seen in the end <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time if you are a lot of it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4693 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 8504.958, step = 4693
# INFO:tensorflow:nll_loss = 7848.2207, kl_w = 0.94374704, kl_loss = 695.88257
# INFO:tensorflow:global_step/sec: 2.0012
# INFO:tensorflow:loss = 8087.074, step = 4793 (49.971 sec)
# INFO:tensorflow:nll_loss = 7379.6997, kl_w = 0.95196813, kl_loss = 743.0653 (49.971 sec)
# INFO:tensorflow:global_step/sec: 1.91377
# INFO:tensorflow:loss = 8217.366, step = 4893 (52.253 sec)
# INFO:tensorflow:nll_loss = 7545.512, kl_w = 0.9590399, kl_loss = 700.5487 (52.253 sec)
# INFO:tensorflow:global_step/sec: 1.84071
# INFO:tensorflow:loss = 8081.1597, step = 4993 (54.327 sec)
# INFO:tensorflow:nll_loss = 7446.286, kl_w = 0.9651086, kl_loss = 657.82605 (54.327 sec)
# INFO:tensorflow:global_step/sec: 1.87009
# INFO:tensorflow:loss = 8423.358, step = 5093 (53.473 sec)
# INFO:tensorflow:nll_loss = 7923.7705, kl_w = 0.97030604, kl_loss = 514.87665 (53.473 sec)
# INFO:tensorflow:global_step/sec: 1.86482
# INFO:tensorflow:loss = 8700.064, step = 5193 (53.625 sec)
# INFO:tensorflow:nll_loss = 8210.528, kl_w = 0.97474945, kl_loss = 502.2173 (53.625 sec)
# INFO:tensorflow:global_step/sec: 1.74943
# INFO:tensorflow:loss = 8677.586, step = 5293 (57.161 sec)
# INFO:tensorflow:nll_loss = 8248.348, kl_w = 0.9785427, kl_loss = 438.65067 (57.161 sec)
# INFO:tensorflow:global_step/sec: 1.75062
# INFO:tensorflow:loss = 8883.281, step = 5393 (57.122 sec)
# INFO:tensorflow:nll_loss = 8471.322, kl_w = 0.9817768, kl_loss = 419.60565 (57.122 sec)
# INFO:tensorflow:Saving checkpoints for 5474 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2179.9597.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this movie is a great movie that i have seen films like this film <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is one of the worst movies i have ever seen i was very <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5475 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 7775.6787, step = 5475
# INFO:tensorflow:nll_loss = 7376.1035, kl_w = 0.98406756, kl_loss = 406.04425
# INFO:tensorflow:global_step/sec: 1.8989
# INFO:tensorflow:loss = 8137.967, step = 5575 (52.663 sec)
# INFO:tensorflow:nll_loss = 7728.5557, kl_w = 0.9864804, kl_loss = 415.0219 (52.663 sec)
# INFO:tensorflow:global_step/sec: 2.04305
# INFO:tensorflow:loss = 8192.084, step = 5675 (48.946 sec)
# INFO:tensorflow:nll_loss = 7779.9097, kl_w = 0.98853207, kl_loss = 416.95627 (48.946 sec)
# INFO:tensorflow:global_step/sec: 1.94388
# INFO:tensorflow:loss = 8027.647, step = 5775 (51.444 sec)
# INFO:tensorflow:nll_loss = 7629.53, kl_w = 0.9902755, kl_loss = 402.02682 (51.444 sec)
# INFO:tensorflow:global_step/sec: 1.82923
# INFO:tensorflow:loss = 8698.8545, step = 5875 (54.668 sec)
# INFO:tensorflow:nll_loss = 8367.804, kl_w = 0.9917561, kl_loss = 333.80286 (54.668 sec)
# INFO:tensorflow:global_step/sec: 1.83935
# INFO:tensorflow:loss = 8767.844, step = 5975 (54.367 sec)
# INFO:tensorflow:nll_loss = 8461.221, kl_w = 0.99301285, kl_loss = 308.78027 (54.367 sec)
# INFO:tensorflow:global_step/sec: 1.83502
# INFO:tensorflow:loss = 8586.492, step = 6075 (54.495 sec)
# INFO:tensorflow:nll_loss = 8313.93, kl_w = 0.9940791, kl_loss = 274.18542 (54.496 sec)
# INFO:tensorflow:global_step/sec: 1.75911
# INFO:tensorflow:loss = 8200.274, step = 6175 (56.847 sec)
# INFO:tensorflow:nll_loss = 7951.734, kl_w = 0.99498355, kl_loss = 249.79318 (56.847 sec)
# INFO:tensorflow:Saving checkpoints for 6256 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2028.8308.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this is a great movie but i have seen this movie is a must <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: i was a movie that i was surprised i was surprised i was surprised <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6257 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 8255.305, step = 6257
# INFO:tensorflow:nll_loss = 7993.762, kl_w = 0.9956215, kl_loss = 262.69257
# INFO:tensorflow:global_step/sec: 1.76739
# INFO:tensorflow:loss = 7996.2007, step = 6357 (56.582 sec)
# INFO:tensorflow:nll_loss = 7702.3374, kl_w = 0.9962913, kl_loss = 294.95703 (56.582 sec)
# INFO:tensorflow:global_step/sec: 1.91513
# INFO:tensorflow:loss = 7700.8677, step = 6457 (52.216 sec)
# INFO:tensorflow:nll_loss = 7433.0264, kl_w = 0.99685884, kl_loss = 268.68542 (52.216 sec)
# INFO:tensorflow:global_step/sec: 1.74725
# INFO:tensorflow:loss = 8249.932, step = 6557 (57.233 sec)
# INFO:tensorflow:nll_loss = 8044.2515, kl_w = 0.9973398, kl_loss = 206.22897 (57.233 sec)
# INFO:tensorflow:global_step/sec: 1.76425
# INFO:tensorflow:loss = 8388.477, step = 6657 (56.681 sec)
# INFO:tensorflow:nll_loss = 8191.8203, kl_w = 0.99774724, kl_loss = 197.1002 (56.681 sec)
# INFO:tensorflow:global_step/sec: 1.76179
# INFO:tensorflow:loss = 8211.575, step = 6757 (56.761 sec)
# INFO:tensorflow:nll_loss = 8034.3857, kl_w = 0.99809235, kl_loss = 177.52779 (56.761 sec)
# INFO:tensorflow:global_step/sec: 1.75526
# INFO:tensorflow:loss = 8460.937, step = 6857 (56.971 sec)
# INFO:tensorflow:nll_loss = 8287.465, kl_w = 0.99838483, kl_loss = 173.75241 (56.972 sec)
# INFO:tensorflow:global_step/sec: 1.82443
# INFO:tensorflow:loss = 8016.8994, step = 6957 (54.812 sec)
# INFO:tensorflow:nll_loss = 7836.2188, kl_w = 0.9986324, kl_loss = 180.92831 (54.811 sec)
# INFO:tensorflow:Saving checkpoints for 7038 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 1906.9077.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this is one of the worst movies i have ever seen i was not <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is not a bad movie it is not bad it is not <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7039 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:loss = 8598.666, step = 7039
# INFO:tensorflow:nll_loss = 8410.714, kl_w = 0.99880695, kl_loss = 188.17651
# INFO:tensorflow:global_step/sec: 1.80628
# INFO:tensorflow:loss = 8139.395, step = 7139 (55.364 sec)
# INFO:tensorflow:nll_loss = 7985.174, kl_w = 0.9989899, kl_loss = 154.37704 (55.364 sec)
# INFO:tensorflow:global_step/sec: 1.75739
# INFO:tensorflow:loss = 8082.747, step = 7239 (56.903 sec)
# INFO:tensorflow:nll_loss = 7932.9473, kl_w = 0.9991448, kl_loss = 149.9281 (56.903 sec)
# INFO:tensorflow:global_step/sec: 1.75794
# INFO:tensorflow:loss = 7621.553, step = 7339 (56.885 sec)
# INFO:tensorflow:nll_loss = 7456.841, kl_w = 0.999276, kl_loss = 164.83173 (56.885 sec)
# INFO:tensorflow:global_step/sec: 1.74637
# INFO:tensorflow:loss = 7888.068, step = 7439 (57.262 sec)
# INFO:tensorflow:nll_loss = 7699.214, kl_w = 0.999387, kl_loss = 188.96974 (57.262 sec)
# INFO:tensorflow:global_step/sec: 1.7341
# INFO:tensorflow:loss = 7929.8047, step = 7539 (57.667 sec)
# INFO:tensorflow:nll_loss = 7763.3457, kl_w = 0.99948114, kl_loss = 166.54556 (57.667 sec)
# INFO:tensorflow:global_step/sec: 1.82367
# INFO:tensorflow:loss = 8314.441, step = 7639 (54.834 sec)
# INFO:tensorflow:nll_loss = 8160.0166, kl_w = 0.9995608, kl_loss = 154.49287 (54.833 sec)
# INFO:tensorflow:global_step/sec: 1.77917
# INFO:tensorflow:loss = 8153.863, step = 7739 (56.206 sec)
# INFO:tensorflow:nll_loss = 8031.879, kl_w = 0.9996282, kl_loss = 122.02937 (56.206 sec)
# INFO:tensorflow:Saving checkpoints for 7820 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt.
# INFO:tensorflow:Loss for final step: 2009.4388.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp2t6hcyqd/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i am not a fan of the <unk> <unk> <unk> <unk> <unk> <unk> <unk> <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a great movie i have ever seen it was a <unk> on <end>
