# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# <img src="cnn_vae.png" width="300">

# %%
import tensorflow as tf
import numpy as np

# %%
PARAMS = {
    'max_len': 15,
    'vocab_size': 10000,
    'embed_dims': 128,
    'rnn_size': 128,
    'cnn_size': 128,
    'latent_size': 16,
    'kernel_sz': 3,
    'n_hidden_layer': 3,
    'clip_norm': 5.0,
    'anneal_max': 1.0,
    'anneal_bias': 6000,
    'batch_size': 128,
    'n_epochs': 10,
}

# %%
def build_vocab(index_from=4):
    PARAMS['word2idx'] = tf.keras.datasets.imdb.get_word_index()
    PARAMS['word2idx'] = {k: (v + index_from) for k, v in PARAMS['word2idx'].items()}
    PARAMS['word2idx']['<pad>'] = 0
    PARAMS['word2idx']['<start>'] = 1
    PARAMS['word2idx']['<unk>'] = 2
    PARAMS['word2idx']['<end>'] = 3
    PARAMS['idx2word'] = {i: w for w, i in PARAMS['word2idx'].items()}

    
def load_data(index_from=4):
    (X_train, _), (X_test, _) = tf.contrib.keras.datasets.imdb.load_data(
        num_words=PARAMS['vocab_size'], index_from=index_from)
    return (X_train, X_test)

# %%
word2idx = build_vocab()
X = np.concatenate(load_data())

X = np.concatenate((
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='post', padding='post'),
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='pre', padding='post')))

enc_inp = X[:, 1:]
dec_inp = X
dec_out = np.concatenate([X[:, 1:], np.full([X.shape[0], 1], PARAMS['word2idx']['<end>'])], 1)

# %%
def kl_w_fn(global_step):
    return PARAMS['anneal_max'] * tf.sigmoid((10 / PARAMS['anneal_bias']) * (
        tf.to_float(global_step) - tf.constant(PARAMS['anneal_bias'] / 2)))


def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, PARAMS['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    return tf.nn.rnn_cell.GRUCell(PARAMS['rnn_size'],
                                  kernel_initializer=tf.orthogonal_initializer())


def cnn_block(x, dilation_rate, pad_sz):
    pad = tf.zeros([tf.shape(x)[0], pad_sz, x.get_shape()[-1].value])
    x =  tf.layers.conv1d(inputs = tf.concat([pad, x, pad], 1),
                          filters = PARAMS['cnn_size'],
                          kernel_size = PARAMS['kernel_sz'],
                          dilation_rate = dilation_rate)
    x = x[:, :-pad_sz, :]
    x = tf.nn.relu(x)
    return x


def cnn_forward(x, output_proj):
    for i in range(PARAMS['n_hidden_layer']):
        dilation_rate = 2 ** i
        pad_sz = (PARAMS['kernel_sz'] - 1) * dilation_rate
        x += cnn_block(x, dilation_rate, pad_sz)
        logits = output_proj(x)
    return logits


def autoregressive(embedding, z, input_proj, output_proj):
    batch_sz = tf.shape(z)[0]
    
    def cond(i, x, temp):
        return i < PARAMS['max_len']

    def body(i, x, temp):
        sos = tf.fill([batch_sz, 1], PARAMS['word2idx']['<start>'])
        x = tf.concat([sos, x[:, :-1]], 1)
        
        x = tf.nn.embedding_lookup(embedding, x)
        x = input_proj(tf.concat([x, z], -1))
        logits = cnn_forward(x, output_proj)
        ids = tf.argmax(logits, -1, output_type=tf.int32)[:, i]
        ids = tf.expand_dims(ids, -1)

        temp = tf.concat([temp[:, 1:], ids], -1)

        x = tf.concat([temp[:, -(i+1):], temp[:, :-(i+1)]], -1)
        x = tf.reshape(x, [batch_sz, PARAMS['max_len']])
        i += 1
        return i, x, temp
    
    x = tf.zeros([batch_sz, PARAMS['max_len']], tf.int32)
    _, res, _ = tf.while_loop(cond, body, [tf.constant(0), x, x])
    
    return res

# %%
def forward(inputs, labels, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    enc_seq_len = tf.count_nonzero(inputs, 1, dtype=tf.int32)
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('Encoder'):
        embedding = tf.get_variable('lookup_table', [PARAMS['vocab_size'],
                                                     PARAMS['embed_dims']])
        x = tf.nn.embedding_lookup(embedding, inputs)
        
        _, enc_state = tf.nn.dynamic_rnn(rnn_cell(), x, enc_seq_len, dtype=tf.float32)
        
        z_mean = tf.layers.dense(enc_state, PARAMS['latent_size'])
        z_var = tf.layers.dense(enc_state, PARAMS['latent_size'])
        
    posterior = tf.contrib.distributions.MultivariateNormalDiag(z_mean, z_var)
    prior = tf.contrib.distributions.MultivariateNormalDiag(tf.zeros_like(z_mean),
                                                            tf.ones_like(z_var))
        
    with tf.variable_scope('Decoder'):
        input_proj = tf.layers.Dense(PARAMS['cnn_size'], tf.nn.relu)
        output_proj = tf.layers.Dense(PARAMS['vocab_size'])
        z = tf.tile(tf.expand_dims(posterior.sample(), 1), [1, PARAMS['max_len'], 1])
        
        if is_training:
            dec_inp = tf.nn.embedding_lookup(embedding, labels['dec_inp'])
            x = input_proj(tf.concat([dec_inp, z], -1))
            logits = cnn_forward(x, output_proj)
            return logits, posterior, prior
        else:
            return autoregressive(embedding, z, input_proj, output_proj)

# %%
def model_fn(features, labels, mode):
    logits_or_ids = forward(features, labels, mode)        
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
        
    if mode == tf.estimator.ModeKeys.TRAIN:
        logits, posterior, prior = logits_or_ids
        
        out_dist = tf.distributions.Categorical(logits)
        
        global_step = tf.train.get_global_step()
        
        nll_loss = - tf.reduce_sum(out_dist.log_prob(labels['dec_out']))
        
        kl_w = kl_w_fn(global_step)
        
        kl_loss = tf.reduce_sum(tf.distributions.kl_divergence(posterior, prior))
        
        loss_op = nll_loss + kl_w * kl_loss
        
        train_op = tf.train.AdamOptimizer().apply_gradients(
            clip_grads(loss_op),
            global_step = global_step)
        
        lth = tf.train.LoggingTensorHook(
            {'nll_loss': nll_loss, 'kl_w': kl_w, 'kl_loss': kl_loss}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
def inf_inp(test_strs):
    x = [[PARAMS['word2idx'].get(w, 2) for w in s.split()] for s in test_strs]
    x = tf.keras.preprocessing.sequence.pad_sequences(
        x, PARAMS['max_len'], truncating='post', padding='post')
    return x

def demo(test_strs, pred_ids):
    for s, pred in zip(test_strs, pred_ids):
        print('\nOriginal:', s)
        print('Reconstr:', ' '.join([PARAMS['idx2word'].get(idx, '<unk>') for idx in pred]))


test_strs = ['i love this film and i think it is one of the best films',
             'this movie is a waste of time and there is no point to watch it']

estimator = tf.estimator.Estimator(model_fn)

for _ in range(PARAMS['n_epochs']):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = enc_inp,
        y = {'dec_inp': dec_inp, 'dec_out': dec_out},
        batch_size = PARAMS['batch_size'],
        shuffle = True))
    
    pred_ids = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = inf_inp(test_strs),
        shuffle = False)))

    demo(test_strs, pred_ids)
    
    print()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1228829b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 17755.781, step = 1
# INFO:tensorflow:nll_loss = 17683.521, kl_w = 0.006692851, kl_loss = 10796.57
# INFO:tensorflow:global_step/sec: 1.90312
# INFO:tensorflow:loss = 11131.802, step = 101 (52.547 sec)
# INFO:tensorflow:nll_loss = 11101.229, kl_w = 0.007897083, kl_loss = 3871.4207 (52.547 sec)
# INFO:tensorflow:global_step/sec: 1.93254
# INFO:tensorflow:loss = 10498.9795, step = 201 (51.745 sec)
# INFO:tensorflow:nll_loss = 10461.249, kl_w = 0.009315956, kl_loss = 4050.058 (51.745 sec)
# INFO:tensorflow:global_step/sec: 1.95065
# INFO:tensorflow:loss = 9729.622, step = 301 (51.265 sec)
# INFO:tensorflow:nll_loss = 9687.377, kl_w = 0.010986943, kl_loss = 3845.0356 (51.265 sec)
# INFO:tensorflow:global_step/sec: 1.97254
# INFO:tensorflow:loss = 10230.502, step = 401 (50.696 sec)
# INFO:tensorflow:nll_loss = 10182.389, kl_w = 0.012953726, kl_loss = 3714.2117 (50.696 sec)
# INFO:tensorflow:global_step/sec: 1.98961
# INFO:tensorflow:loss = 9759.194, step = 501 (50.261 sec)
# INFO:tensorflow:nll_loss = 9695.52, kl_w = 0.015267149, kl_loss = 4170.6855 (50.261 sec)
# INFO:tensorflow:global_step/sec: 1.96744
# INFO:tensorflow:loss = 9389.618, step = 601 (50.828 sec)
# INFO:tensorflow:nll_loss = 9317.234, kl_w = 0.01798621, kl_loss = 4024.3945 (50.828 sec)
# INFO:tensorflow:global_step/sec: 1.86256
# INFO:tensorflow:loss = 9134.615, step = 701 (53.689 sec)
# INFO:tensorflow:nll_loss = 9049.746, kl_w = 0.021179108, kl_loss = 4007.204 (53.689 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 2340.6917.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i have seen this movie and <unk> i have seen the movie of my <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a movie of <unk> to watch it to be good of it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 9317.92, step = 783
# INFO:tensorflow:nll_loss = 9219.961, kl_w = 0.024205629, kl_loss = 4046.958
# INFO:tensorflow:global_step/sec: 2.05977
# INFO:tensorflow:loss = 8900.057, step = 883 (48.550 sec)
# INFO:tensorflow:nll_loss = 8777.604, kl_w = 0.028470589, kl_loss = 4301.034 (48.550 sec)
# INFO:tensorflow:global_step/sec: 2.04913
# INFO:tensorflow:loss = 8797.47, step = 983 (48.801 sec)
# INFO:tensorflow:nll_loss = 8661.531, kl_w = 0.033461247, kl_loss = 4062.5703 (48.801 sec)
# INFO:tensorflow:global_step/sec: 2.02708
# INFO:tensorflow:loss = 8374.174, step = 1083 (49.332 sec)
# INFO:tensorflow:nll_loss = 8208.387, kl_w = 0.039291352, kl_loss = 4219.4355 (49.332 sec)
# INFO:tensorflow:global_step/sec: 2.01737
# INFO:tensorflow:loss = 8181.936, step = 1183 (49.570 sec)
# INFO:tensorflow:nll_loss = 7980.6045, kl_w = 0.04608883, kl_loss = 4368.339 (49.570 sec)
# INFO:tensorflow:global_step/sec: 2.00853
# INFO:tensorflow:loss = 8001.5913, step = 1283 (49.788 sec)
# INFO:tensorflow:nll_loss = 7763.202, kl_w = 0.053996176, kl_loss = 4414.9287 (49.788 sec)
# INFO:tensorflow:global_step/sec: 1.9617
# INFO:tensorflow:loss = 7631.229, step = 1383 (50.976 sec)
# INFO:tensorflow:nll_loss = 7353.412, kl_w = 0.06317033, kl_loss = 4397.9043 (50.977 sec)
# INFO:tensorflow:global_step/sec: 1.88319
# INFO:tensorflow:loss = 8425.783, step = 1483 (53.101 sec)
# INFO:tensorflow:nll_loss = 8132.536, kl_w = 0.07378165, kl_loss = 3974.5234 (53.101 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 2139.832.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i have seen this movie and i saw it in the first time ever <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a movie that it should like to see <unk> on all costs <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1565 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 8304.142, step = 1565
# INFO:tensorflow:nll_loss = 7965.5894, kl_w = 0.08368247, kl_loss = 4045.672
# INFO:tensorflow:global_step/sec: 1.84314
# INFO:tensorflow:loss = 8314.334, step = 1665 (54.257 sec)
# INFO:tensorflow:nll_loss = 7937.172, kl_w = 0.09738124, kl_loss = 3873.0435 (54.257 sec)
# INFO:tensorflow:global_step/sec: 1.82314
# INFO:tensorflow:loss = 8087.853, step = 1765 (54.851 sec)
# INFO:tensorflow:nll_loss = 7645.732, kl_w = 0.11304584, kl_loss = 3910.9915 (54.851 sec)
# INFO:tensorflow:global_step/sec: 1.79764
# INFO:tensorflow:loss = 7689.3345, step = 1865 (55.628 sec)
# INFO:tensorflow:nll_loss = 7191.868, kl_w = 0.13086486, kl_loss = 3801.374 (55.628 sec)
# INFO:tensorflow:global_step/sec: 1.88225
# INFO:tensorflow:loss = 7934.692, step = 1965 (53.128 sec)
# INFO:tensorflow:nll_loss = 7374.876, kl_w = 0.15101443, kl_loss = 3707.0356 (53.128 sec)
# INFO:tensorflow:global_step/sec: 1.82003
# INFO:tensorflow:loss = 8578.858, step = 2065 (54.944 sec)
# INFO:tensorflow:nll_loss = 7959.17, kl_w = 0.17364664, kl_loss = 3568.6753 (54.944 sec)
# INFO:tensorflow:global_step/sec: 1.88575
# INFO:tensorflow:loss = 8676.932, step = 2165 (53.029 sec)
# INFO:tensorflow:nll_loss = 8006.752, kl_w = 0.19887616, kl_loss = 3369.8325 (53.029 sec)
# INFO:tensorflow:global_step/sec: 1.84008
# INFO:tensorflow:loss = 8787.967, step = 2265 (54.345 sec)
# INFO:tensorflow:nll_loss = 8082.8447, kl_w = 0.22676536, kl_loss = 3109.4775 (54.345 sec)
# INFO:tensorflow:Saving checkpoints for 2346 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 2255.2363.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think this movie and i think it is a <unk> of all <unk> <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this film is a lot of tv movies to be good if not recommended <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2347 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 8516.449, step = 2347
# INFO:tensorflow:nll_loss = 7762.942, kl_w = 0.25161827, kl_loss = 2994.6428
# INFO:tensorflow:global_step/sec: 1.97545
# INFO:tensorflow:loss = 8223.366, step = 2447 (50.623 sec)
# INFO:tensorflow:nll_loss = 7434.0605, kl_w = 0.2842792, kl_loss = 2776.5144 (50.622 sec)
# INFO:tensorflow:global_step/sec: 1.82733
# INFO:tensorflow:loss = 7816.757, step = 2547 (54.724 sec)
# INFO:tensorflow:nll_loss = 6917.408, kl_w = 0.31937042, kl_loss = 2816.005 (54.724 sec)
# INFO:tensorflow:global_step/sec: 1.94634
# INFO:tensorflow:loss = 8443.568, step = 2647 (51.379 sec)
# INFO:tensorflow:nll_loss = 7546.3545, kl_w = 0.35663486, kl_loss = 2515.7761 (51.379 sec)
# INFO:tensorflow:global_step/sec: 1.88025
# INFO:tensorflow:loss = 8709.393, step = 2747 (53.184 sec)
# INFO:tensorflow:nll_loss = 7708.0464, kl_w = 0.39571938, kl_loss = 2530.4458 (53.184 sec)
# INFO:tensorflow:global_step/sec: 1.86854
# INFO:tensorflow:loss = 8877.915, step = 2847 (53.518 sec)
# INFO:tensorflow:nll_loss = 7927.035, kl_w = 0.43618327, kl_loss = 2180.0002 (53.518 sec)
# INFO:tensorflow:global_step/sec: 1.75411
# INFO:tensorflow:loss = 8885.709, step = 2947 (57.009 sec)
# INFO:tensorflow:nll_loss = 7915.8745, kl_w = 0.47751516, kl_loss = 2031.002 (57.009 sec)
# INFO:tensorflow:global_step/sec: 1.85079
# INFO:tensorflow:loss = 7970.3184, step = 3047 (54.032 sec)
# INFO:tensorflow:nll_loss = 6978.256, kl_w = 0.5191573, kl_loss = 1910.9089 (54.032 sec)
# INFO:tensorflow:Saving checkpoints for 3128 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 2108.5527.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think the movie is i think of this film is one of those <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a lot of movie that it shows it to come out to <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3129 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 9184.401, step = 3129
# INFO:tensorflow:nll_loss = 8147.0435, kl_w = 0.55313194, kl_loss = 1875.426
# INFO:tensorflow:global_step/sec: 1.83267
# INFO:tensorflow:loss = 8368.413, step = 3229 (54.567 sec)
# INFO:tensorflow:nll_loss = 7348.293, kl_w = 0.5938731, kl_loss = 1717.7412 (54.566 sec)
# INFO:tensorflow:global_step/sec: 1.86836
# INFO:tensorflow:loss = 8518.303, step = 3329 (53.523 sec)
# INFO:tensorflow:nll_loss = 7456.273, kl_w = 0.6333619, kl_loss = 1676.8137 (53.524 sec)
# INFO:tensorflow:global_step/sec: 1.76338
# INFO:tensorflow:loss = 8091.8564, step = 3429 (56.709 sec)
# INFO:tensorflow:nll_loss = 7042.331, kl_w = 0.6711373, kl_loss = 1563.8018 (56.709 sec)
# INFO:tensorflow:global_step/sec: 1.70596
# INFO:tensorflow:loss = 8444.698, step = 3529 (58.618 sec)
# INFO:tensorflow:nll_loss = 7376.6533, kl_w = 0.7068222, kl_loss = 1511.0521 (58.618 sec)
# INFO:tensorflow:global_step/sec: 1.77755
# INFO:tensorflow:loss = 8992.268, step = 3629 (56.257 sec)
# INFO:tensorflow:nll_loss = 7998.629, kl_w = 0.7401343, kl_loss = 1342.5115 (56.257 sec)
# INFO:tensorflow:global_step/sec: 1.79358
# INFO:tensorflow:loss = 9069.189, step = 3729 (55.754 sec)
# INFO:tensorflow:nll_loss = 8103.619, kl_w = 0.7708882, kl_loss = 1252.5427 (55.754 sec)
# INFO:tensorflow:global_step/sec: 1.75417
# INFO:tensorflow:loss = 9185.366, step = 3829 (57.007 sec)
# INFO:tensorflow:nll_loss = 8306.66, kl_w = 0.79899096, kl_loss = 1099.7698 (57.008 sec)
# INFO:tensorflow:Saving checkpoints for 3910 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 2132.0552.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i have seen this movie i have seen the movie and <unk> <unk> <unk> <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a movie that i would recommend to see it to be missed <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3911 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 8712.088, step = 3911
# INFO:tensorflow:nll_loss = 7878.97, kl_w = 0.82004714, kl_loss = 1015.9391
# INFO:tensorflow:global_step/sec: 1.79699
# INFO:tensorflow:loss = 8628.348, step = 4011 (55.650 sec)
# INFO:tensorflow:nll_loss = 7792.302, kl_w = 0.84334546, kl_loss = 991.3441 (55.650 sec)
# INFO:tensorflow:global_step/sec: 1.8631
# INFO:tensorflow:loss = 8779.722, step = 4111 (53.675 sec)
# INFO:tensorflow:nll_loss = 8003.4487, kl_w = 0.8641271, kl_loss = 898.3317 (53.675 sec)
# INFO:tensorflow:global_step/sec: 1.83282
# INFO:tensorflow:loss = 8908.077, step = 4211 (54.560 sec)
# INFO:tensorflow:nll_loss = 8140.7817, kl_w = 0.88253593, kl_loss = 869.42114 (54.560 sec)
# INFO:tensorflow:global_step/sec: 1.83371
# INFO:tensorflow:loss = 8261.744, step = 4311 (54.534 sec)
# INFO:tensorflow:nll_loss = 7540.4966, kl_w = 0.89874285, kl_loss = 802.50757 (54.534 sec)
# INFO:tensorflow:global_step/sec: 1.82668
# INFO:tensorflow:loss = 8391.452, step = 4411 (54.744 sec)
# INFO:tensorflow:nll_loss = 7694.4233, kl_w = 0.9129343, kl_loss = 763.50354 (54.744 sec)
# INFO:tensorflow:global_step/sec: 1.73076
# INFO:tensorflow:loss = 8408.583, step = 4511 (57.778 sec)
# INFO:tensorflow:nll_loss = 7779.869, kl_w = 0.92530197, kl_loss = 679.46924 (57.778 sec)
# INFO:tensorflow:global_step/sec: 1.7637
# INFO:tensorflow:loss = 8980.964, step = 4611 (56.699 sec)
# INFO:tensorflow:nll_loss = 8421.106, kl_w = 0.93603605, kl_loss = 598.1153 (56.700 sec)
# INFO:tensorflow:Saving checkpoints for 4692 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 2290.818.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i have to see this movie and i give it a 2 out of <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: i would give it a chance to see it a waste of time instead <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4693 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 8549.752, step = 4693
# INFO:tensorflow:nll_loss = 8062.417, kl_w = 0.94374704, kl_loss = 516.38257
# INFO:tensorflow:global_step/sec: 1.78308
# INFO:tensorflow:loss = 8882.977, step = 4793 (56.084 sec)
# INFO:tensorflow:nll_loss = 8373.875, kl_w = 0.95196813, kl_loss = 534.7885 (56.084 sec)
# INFO:tensorflow:global_step/sec: 1.94771
# INFO:tensorflow:loss = 8540.644, step = 4893 (51.343 sec)
# INFO:tensorflow:nll_loss = 8080.4, kl_w = 0.9590399, kl_loss = 479.9005 (51.343 sec)
# INFO:tensorflow:global_step/sec: 1.98558
# INFO:tensorflow:loss = 8860.667, step = 4993 (50.362 sec)
# INFO:tensorflow:nll_loss = 8445.045, kl_w = 0.9651086, kl_loss = 430.6481 (50.362 sec)
# INFO:tensorflow:global_step/sec: 1.99745
# INFO:tensorflow:loss = 8209.384, step = 5093 (50.064 sec)
# INFO:tensorflow:nll_loss = 7749.4473, kl_w = 0.97030604, kl_loss = 474.01135 (50.064 sec)
# INFO:tensorflow:global_step/sec: 1.83924
# INFO:tensorflow:loss = 8240.924, step = 5193 (54.370 sec)
# INFO:tensorflow:nll_loss = 7827.508, kl_w = 0.97474945, kl_loss = 424.125 (54.370 sec)
# INFO:tensorflow:global_step/sec: 1.86602
# INFO:tensorflow:loss = 8034.9795, step = 5293 (53.590 sec)
# INFO:tensorflow:nll_loss = 7653.711, kl_w = 0.9785427, kl_loss = 389.62903 (53.590 sec)
# INFO:tensorflow:global_step/sec: 1.74542
# INFO:tensorflow:loss = 8761.365, step = 5393 (57.293 sec)
# INFO:tensorflow:nll_loss = 8391.694, kl_w = 0.9817768, kl_loss = 376.53302 (57.292 sec)
# INFO:tensorflow:Saving checkpoints for 5474 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 2138.9294.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this is a great film and the acting is good and the ending is <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a good movie but it is not worth a look like it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5475 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 8446.697, step = 5475
# INFO:tensorflow:nll_loss = 8117.8604, kl_w = 0.98406756, kl_loss = 334.16138
# INFO:tensorflow:global_step/sec: 2.04582
# INFO:tensorflow:loss = 8561.883, step = 5575 (48.881 sec)
# INFO:tensorflow:nll_loss = 8220.549, kl_w = 0.9864804, kl_loss = 346.01147 (48.881 sec)
# INFO:tensorflow:global_step/sec: 2.00537
# INFO:tensorflow:loss = 8088.159, step = 5675 (49.866 sec)
# INFO:tensorflow:nll_loss = 7776.6533, kl_w = 0.98853207, kl_loss = 315.11948 (49.866 sec)
# INFO:tensorflow:global_step/sec: 1.89606
# INFO:tensorflow:loss = 7966.259, step = 5775 (52.741 sec)
# INFO:tensorflow:nll_loss = 7658.665, kl_w = 0.9902755, kl_loss = 310.6142 (52.741 sec)
# INFO:tensorflow:global_step/sec: 1.80751
# INFO:tensorflow:loss = 7859.498, step = 5875 (55.324 sec)
# INFO:tensorflow:nll_loss = 7570.68, kl_w = 0.9917561, kl_loss = 291.21854 (55.325 sec)
# INFO:tensorflow:global_step/sec: 1.87165
# INFO:tensorflow:loss = 8074.4272, step = 5975 (53.429 sec)
# INFO:tensorflow:nll_loss = 7798.9307, kl_w = 0.99301285, kl_loss = 277.43484 (53.429 sec)
# INFO:tensorflow:global_step/sec: 1.83124
# INFO:tensorflow:loss = 8277.078, step = 6075 (54.608 sec)
# INFO:tensorflow:nll_loss = 8029.5474, kl_w = 0.9940791, kl_loss = 249.00528 (54.608 sec)
# INFO:tensorflow:global_step/sec: 1.88281
# INFO:tensorflow:loss = 8623.049, step = 6175 (53.112 sec)
# INFO:tensorflow:nll_loss = 8409.375, kl_w = 0.99498355, kl_loss = 214.75066 (53.112 sec)
# INFO:tensorflow:Saving checkpoints for 6256 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 2135.005.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i would recommend this movie and i think it was a great movie for <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: i would not recommend this movie to anyone with a good movie br br <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6257 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 8193.919, step = 6257
# INFO:tensorflow:nll_loss = 7978.014, kl_w = 0.9956215, kl_loss = 216.85446
# INFO:tensorflow:global_step/sec: 1.89914
# INFO:tensorflow:loss = 8192.489, step = 6357 (52.657 sec)
# INFO:tensorflow:nll_loss = 7993.5195, kl_w = 0.9962913, kl_loss = 199.71031 (52.657 sec)
# INFO:tensorflow:global_step/sec: 1.90426
# INFO:tensorflow:loss = 8280.261, step = 6457 (52.514 sec)
# INFO:tensorflow:nll_loss = 8072.155, kl_w = 0.99685884, kl_loss = 208.76212 (52.513 sec)
# INFO:tensorflow:global_step/sec: 1.88103
# INFO:tensorflow:loss = 8059.3457, step = 6557 (53.162 sec)
# INFO:tensorflow:nll_loss = 7875.086, kl_w = 0.9973398, kl_loss = 184.7511 (53.163 sec)
# INFO:tensorflow:global_step/sec: 1.87736
# INFO:tensorflow:loss = 7926.177, step = 6657 (53.266 sec)
# INFO:tensorflow:nll_loss = 7735.5947, kl_w = 0.99774724, kl_loss = 191.01242 (53.266 sec)
# INFO:tensorflow:global_step/sec: 1.89327
# INFO:tensorflow:loss = 7908.3955, step = 6757 (52.818 sec)
# INFO:tensorflow:nll_loss = 7732.8613, kl_w = 0.99809235, kl_loss = 175.86978 (52.818 sec)
# INFO:tensorflow:global_step/sec: 1.89883
# INFO:tensorflow:loss = 7822.19, step = 6857 (52.664 sec)
# INFO:tensorflow:nll_loss = 7634.291, kl_w = 0.99838483, kl_loss = 188.20279 (52.664 sec)
# INFO:tensorflow:global_step/sec: 1.90187
# INFO:tensorflow:loss = 8374.203, step = 6957 (52.580 sec)
# INFO:tensorflow:nll_loss = 8214.308, kl_w = 0.9986324, kl_loss = 160.11444 (52.580 sec)
# INFO:tensorflow:Saving checkpoints for 7038 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 1932.5488.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think this movie is a must see for anyone who loves the film <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a great movie to watch it if you want to see it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7039 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:loss = 7862.971, step = 7039
# INFO:tensorflow:nll_loss = 7709.5083, kl_w = 0.99880695, kl_loss = 153.64621
# INFO:tensorflow:global_step/sec: 2.02572
# INFO:tensorflow:loss = 8136.9326, step = 7139 (49.366 sec)
# INFO:tensorflow:nll_loss = 7984.3364, kl_w = 0.9989899, kl_loss = 152.75049 (49.366 sec)
# INFO:tensorflow:global_step/sec: 2.04457
# INFO:tensorflow:loss = 8322.919, step = 7239 (48.910 sec)
# INFO:tensorflow:nll_loss = 8198.499, kl_w = 0.9991448, kl_loss = 124.52596 (48.910 sec)
# INFO:tensorflow:global_step/sec: 2.02239
# INFO:tensorflow:loss = 8102.1084, step = 7339 (49.446 sec)
# INFO:tensorflow:nll_loss = 7982.6865, kl_w = 0.999276, kl_loss = 119.50818 (49.446 sec)
# INFO:tensorflow:global_step/sec: 2.01082
# INFO:tensorflow:loss = 8545.577, step = 7439 (49.731 sec)
# INFO:tensorflow:nll_loss = 8433.879, kl_w = 0.999387, kl_loss = 111.76698 (49.731 sec)
# INFO:tensorflow:global_step/sec: 1.99893
# INFO:tensorflow:loss = 7841.6094, step = 7539 (50.027 sec)
# INFO:tensorflow:nll_loss = 7707.616, kl_w = 0.99948114, kl_loss = 134.06273 (50.027 sec)
# INFO:tensorflow:global_step/sec: 1.96249
# INFO:tensorflow:loss = 7774.6973, step = 7639 (50.956 sec)
# INFO:tensorflow:nll_loss = 7650.4785, kl_w = 0.9995608, kl_loss = 124.27313 (50.956 sec)
# INFO:tensorflow:global_step/sec: 1.82792
# INFO:tensorflow:loss = 8020.0444, step = 7739 (54.707 sec)
# INFO:tensorflow:nll_loss = 7881.218, kl_w = 0.9996282, kl_loss = 138.87837 (54.707 sec)
# INFO:tensorflow:Saving checkpoints for 7820 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt.
# INFO:tensorflow:Loss for final step: 1926.9485.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpp4mlok89/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i have seen this movie in the theater and i have to say that <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a very good movie that is a <unk> of a <end> who <end>
