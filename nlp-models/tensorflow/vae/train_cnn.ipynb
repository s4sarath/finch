# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# <img src="cnn_vae.png" width="300">

# %%
import tensorflow as tf
import numpy as np

# %%
PARAMS = {
    'max_len': 15,
    'embed_dims': 128,
    'rnn_size': 128,
    'cnn_size': 128,
    'latent_size': 16,
    'kernel_sz': 3,
    'n_hidden_layer': 3,
    'num_sampled': 1000,
    'clip_norm': 5.0,
    'anneal_max': 1.0,
    'anneal_bias': 6000,
    'batch_size': 128,
    'n_epochs': 10,
}

# %%
def build_vocab(index_from=4):
    PARAMS['word2idx'] = tf.keras.datasets.imdb.get_word_index()
    PARAMS['word2idx'] = {k: (v + index_from) for k, v in PARAMS['word2idx'].items()}
    PARAMS['word2idx']['<pad>'] = 0
    PARAMS['word2idx']['<start>'] = 1
    PARAMS['word2idx']['<unk>'] = 2
    PARAMS['word2idx']['<end>'] = 3
    
    PARAMS['idx2word'] = {i: w for w, i in PARAMS['word2idx'].items()}
    
    PARAMS['vocab_size'] = len(PARAMS['word2idx'])

    
def load_data(index_from=4):
    (X_train, _), (X_test, _) = tf.contrib.keras.datasets.imdb.load_data(
        num_words=None, index_from=index_from)
    return (X_train, X_test)

# %%
word2idx = build_vocab()
X = np.concatenate(load_data())

X = np.concatenate((
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='post', padding='post'),
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='pre', padding='post')))

enc_inp = X[:, 1:]
dec_inp = X
dec_out = np.concatenate([X[:, 1:], np.full([X.shape[0], 1], PARAMS['word2idx']['<end>'])], 1)

# %%
def reparam_trick(z_mean, z_logvar):
    gaussian = tf.truncated_normal(tf.shape(z_logvar))
    z = z_mean + tf.exp(0.5 * z_logvar) * gaussian
    return z


def kl_w_fn(global_step):
    return PARAMS['anneal_max'] * tf.sigmoid((10 / PARAMS['anneal_bias']) * (
        tf.to_float(global_step) - tf.constant(PARAMS['anneal_bias'] / 2)))


def kl_loss_fn(mean, gamma):
    return 0.5 * tf.reduce_sum(
        tf.exp(gamma) + tf.square(mean) - 1 - gamma) / tf.to_float(tf.shape(mean)[0])


def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, PARAMS['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    return tf.nn.rnn_cell.GRUCell(PARAMS['rnn_size'],
                                  kernel_initializer=tf.orthogonal_initializer())


def cnn_block(x, dilation_rate, pad_sz):
    pad = tf.zeros([tf.shape(x)[0], pad_sz, x.get_shape()[-1].value])
    x =  tf.layers.conv1d(inputs = tf.concat([pad, x, pad], 1),
                          filters = PARAMS['cnn_size'],
                          kernel_size = PARAMS['kernel_sz'],
                          dilation_rate = dilation_rate)
    x = x[:, :-pad_sz, :]
    x = tf.nn.relu(x)
    return x


def cnn_forward(x, output_proj):
    for i in range(PARAMS['n_hidden_layer']):
        dilation_rate = 2 ** i
        pad_sz = (PARAMS['kernel_sz'] - 1) * dilation_rate
        x += cnn_block(x, dilation_rate, pad_sz)
        logits = output_proj(x)
    return logits, x


def autoregressive(embedding, init_state, output_proj):
    def cond(i, x, temp):
        return i < PARAMS['max_len']

    def body(i, x, temp):
        sos = tf.fill([tf.shape(init_state)[0], 1], PARAMS['word2idx']['<start>'])
        x = tf.concat([sos, x[:, :-1]], 1)
        
        x = tf.nn.embedding_lookup(embedding, x)
        x += init_state
        logits = cnn_forward(x, output_proj)[0]
        ids = tf.argmax(logits, -1, output_type=tf.int32)[:, i]
        ids = tf.expand_dims(ids, -1)

        temp = tf.concat([temp[:, 1:], ids], -1)

        x = tf.concat([temp[:, -(i+1):], temp[:, :-(i+1)]], -1)
        x = tf.reshape(x, [tf.shape(init_state)[0], PARAMS['max_len']])
        i += 1
        return i, x, temp
    
    x = tf.zeros([tf.shape(init_state)[0], PARAMS['max_len']], tf.int32)
    _, res, _ = tf.while_loop(cond, body, [tf.constant(0), x, x])
    
    return res

# %%
def forward(inputs, labels, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    enc_seq_len = tf.count_nonzero(inputs, 1, dtype=tf.int32)
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('Encoder'):
        embedding = tf.get_variable('lookup_table', [len(PARAMS['word2idx']), PARAMS['embed_dims']])
        x = tf.nn.embedding_lookup(embedding, inputs)
        
        _, enc_state = tf.nn.dynamic_rnn(rnn_cell(), x, enc_seq_len, dtype=tf.float32)
        
        z_mean = tf.layers.dense(enc_state, PARAMS['latent_size'])
        z_logvar = tf.layers.dense(enc_state, PARAMS['latent_size'])
        
    z = reparam_trick(z_mean, z_logvar)
        
    with tf.variable_scope('Decoder'):
        output_proj = tf.layers.Dense(len(PARAMS['word2idx']), _scope='decoder/output_proj')
        init_state = tf.layers.dense(z, PARAMS['cnn_size'], tf.nn.relu)
        init_state = tf.tile(tf.expand_dims(init_state, 1), [1, PARAMS['max_len'], 1])
        
        if is_training:
            dec_inp = tf.nn.embedding_lookup(embedding, labels['dec_inp'])
            x = dec_inp + init_state
            logits, x = cnn_forward(x, output_proj)
            return x, logits, (z_mean, z_logvar)
        else:
            return autoregressive(embedding, init_state, output_proj)

# %%
def model_fn(features, labels, mode):
    logits_or_ids = forward(features, labels, mode)        
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
        
    if mode == tf.estimator.ModeKeys.TRAIN:
        cnn_output, logits, (z_mean, z_logvar) = logits_or_ids
        
        global_step = tf.train.get_global_step()
        
        with tf.variable_scope('Decoder/decoder/output_proj', reuse=True):
            _weights = tf.transpose(tf.get_variable('kernel'))
            _biases = tf.get_variable('bias')
        
        mask = tf.reshape(tf.to_float(tf.sign(labels['dec_out'])), [-1])
        
        nll_loss = tf.reduce_sum(mask * tf.nn.sampled_softmax_loss(
            weights = _weights,
            biases = _biases,
            labels = tf.reshape(labels['dec_out'], [-1, 1]),
            inputs = tf.reshape(cnn_output, [-1, PARAMS['cnn_size']]),
            num_sampled = PARAMS['num_sampled'],
            num_classes = PARAMS['vocab_size'],
        )) / tf.to_float(tf.shape(features)[0])
        
        kl_w = kl_w_fn(global_step)
        
        kl_loss = kl_loss_fn(z_mean, z_logvar)
        
        loss_op = nll_loss + kl_w * kl_loss
        
        train_op = tf.train.AdamOptimizer().apply_gradients(
            clip_grads(loss_op),
            global_step = global_step)
        
        lth = tf.train.LoggingTensorHook(
            {'nll_loss': nll_loss, 'kl_w': kl_w, 'kl_loss': kl_loss}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
def inf_inp(test_strs):
    x = [[PARAMS['word2idx'].get(w, 2) for w in s.split()] for s in test_strs]
    x = tf.keras.preprocessing.sequence.pad_sequences(
        x, PARAMS['max_len'], truncating='post', padding='post')
    return x

def demo(test_strs, pred_ids):
    for s, pred in zip(test_strs, pred_ids):
        print('\nOriginal:', s)
        print('Reconstr:', ' '.join([PARAMS['idx2word'].get(idx, '<unk>') for idx in pred]))


test_strs = ['i love this film and i think it is one of the best films',
             'this movie is a waste of time and there is no point to watch it']

estimator = tf.estimator.Estimator(model_fn)

for _ in range(PARAMS['n_epochs']):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = enc_inp,
        y = {'dec_inp': dec_inp, 'dec_out': dec_out},
        batch_size = PARAMS['batch_size'],
        shuffle = True))
    
    pred_ids = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = inf_inp(test_strs),
        shuffle = False)))

    demo(test_strs, pred_ids)
    
    print()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x11dd64400>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt.
# INFO:tensorflow:loss = 156.6495, step = 1
# INFO:tensorflow:nll_loss = 156.6495, kl_w = 0.006692851, kl_loss = 4.3360153e-05
# INFO:tensorflow:global_step/sec: 3.18421
# INFO:tensorflow:loss = 86.62854, step = 101 (31.406 sec)
# INFO:tensorflow:nll_loss = 86.62731, kl_w = 0.007897083, kl_loss = 0.15521131 (31.406 sec)
# INFO:tensorflow:global_step/sec: 3.22002
# INFO:tensorflow:loss = 97.04167, step = 201 (31.056 sec)
# INFO:tensorflow:nll_loss = 97.00179, kl_w = 0.009315956, kl_loss = 4.2806926 (31.056 sec)
# INFO:tensorflow:global_step/sec: 3.24036
# INFO:tensorflow:loss = 74.72797, step = 301 (30.861 sec)
# INFO:tensorflow:nll_loss = 74.523056, kl_w = 0.010986943, kl_loss = 18.65032 (30.861 sec)
# INFO:tensorflow:global_step/sec: 3.2539
# INFO:tensorflow:loss = 77.87877, step = 401 (30.732 sec)
# INFO:tensorflow:nll_loss = 77.57339, kl_w = 0.012953726, kl_loss = 23.575077 (30.732 sec)
# INFO:tensorflow:global_step/sec: 3.24106
# INFO:tensorflow:loss = 95.425064, step = 501 (30.854 sec)
# INFO:tensorflow:nll_loss = 95.03569, kl_w = 0.015267149, kl_loss = 25.50418 (30.854 sec)
# INFO:tensorflow:global_step/sec: 3.07443
# INFO:tensorflow:loss = 66.79816, step = 601 (32.527 sec)
# INFO:tensorflow:nll_loss = 66.241135, kl_w = 0.01798621, kl_loss = 30.96952 (32.527 sec)
# INFO:tensorflow:global_step/sec: 3.00828
# INFO:tensorflow:loss = 69.83747, step = 701 (33.241 sec)
# INFO:tensorflow:nll_loss = 69.14241, kl_w = 0.021179108, kl_loss = 32.818386 (33.241 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt.
# INFO:tensorflow:Loss for final step: 66.85568.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i was this movie i was the movie br br the movie is a <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a movie movie and email that i have been email and <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt.
# INFO:tensorflow:loss = 60.29004, step = 783
# INFO:tensorflow:nll_loss = 59.47081, kl_w = 0.024205629, kl_loss = 33.844498
# INFO:tensorflow:global_step/sec: 3.11588
# INFO:tensorflow:loss = 58.496525, step = 883 (32.095 sec)
# INFO:tensorflow:nll_loss = 57.53557, kl_w = 0.028470589, kl_loss = 33.75262 (32.095 sec)
# INFO:tensorflow:global_step/sec: 2.84799
# INFO:tensorflow:loss = 61.124294, step = 983 (35.113 sec)
# INFO:tensorflow:nll_loss = 59.98628, kl_w = 0.033461247, kl_loss = 34.01001 (35.113 sec)
# INFO:tensorflow:global_step/sec: 2.89843
# INFO:tensorflow:loss = 61.081966, step = 1083 (34.501 sec)
# INFO:tensorflow:nll_loss = 59.75407, kl_w = 0.039291352, kl_loss = 33.796143 (34.501 sec)
# INFO:tensorflow:global_step/sec: 2.93985
# INFO:tensorflow:loss = 59.4197, step = 1183 (34.015 sec)
# INFO:tensorflow:loss = 51.078247, step = 6557 (31.966 sec)
# INFO:tensorflow:nll_loss = 46.65972, kl_w = 0.9973398, kl_loss = 4.4303117 (31.966 sec)
# INFO:tensorflow:global_step/sec: 3.1856
# INFO:tensorflow:loss = 50.751266, step = 6657 (31.391 sec)
# INFO:tensorflow:nll_loss = 46.428734, kl_w = 0.99774724, kl_loss = 4.3322935 (31.390 sec)
# INFO:tensorflow:global_step/sec: 2.94444
# INFO:tensorflow:loss = 54.7277, step = 6757 (33.963 sec)
# INFO:tensorflow:nll_loss = 50.601944, kl_w = 0.99809235, kl_loss = 4.133642 (33.964 sec)
# INFO:tensorflow:global_step/sec: 3.02448
# INFO:tensorflow:loss = 55.50539, step = 6857 (33.062 sec)
# INFO:tensorflow:nll_loss = 50.98034, kl_w = 0.99838483, kl_loss = 4.5323725 (33.062 sec)
# INFO:tensorflow:global_step/sec: 3.1137
# INFO:tensorflow:loss = 50.53897, step = 6957 (32.116 sec)
# INFO:tensorflow:nll_loss = 46.393013, kl_w = 0.9986324, kl_loss = 4.1516347 (32.116 sec)
# INFO:tensorflow:Saving checkpoints for 7038 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt.
# INFO:tensorflow:Loss for final step: 52.481445.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this movie is bad but i was very impressed by the original and the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a great movie i don't know what to be about it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7039 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt.
# INFO:tensorflow:loss = 48.616436, step = 7039
# INFO:tensorflow:nll_loss = 44.53655, kl_w = 0.99880695, kl_loss = 4.084759
# INFO:tensorflow:global_step/sec: 3.04321
# INFO:tensorflow:loss = 47.586998, step = 7139 (32.861 sec)
# INFO:tensorflow:nll_loss = 43.516968, kl_w = 0.9989899, kl_loss = 4.0741453 (32.861 sec)
# INFO:tensorflow:global_step/sec: 3.14652
# INFO:tensorflow:loss = 48.15903, step = 7239 (31.781 sec)
# INFO:tensorflow:nll_loss = 44.427864, kl_w = 0.9991448, kl_loss = 3.7343607 (31.782 sec)
# INFO:tensorflow:global_step/sec: 3.05483
# INFO:tensorflow:loss = 52.287605, step = 7339 (32.736 sec)
# INFO:tensorflow:nll_loss = 48.5309, kl_w = 0.999276, kl_loss = 3.7594266 (32.735 sec)
# INFO:tensorflow:global_step/sec: 3.07354
# INFO:tensorflow:loss = 51.340454, step = 7439 (32.535 sec)
# INFO:tensorflow:nll_loss = 47.350098, kl_w = 0.999387, kl_loss = 3.9928036 (32.535 sec)
# INFO:tensorflow:global_step/sec: 3.0962
# INFO:tensorflow:loss = 48.13484, step = 7539 (32.298 sec)
# INFO:tensorflow:nll_loss = 44.29383, kl_w = 0.99948114, kl_loss = 3.8430028 (32.297 sec)
# INFO:tensorflow:global_step/sec: 3.0824
# INFO:tensorflow:loss = 49.72584, step = 7639 (32.442 sec)
# INFO:tensorflow:nll_loss = 45.85737, kl_w = 0.9995608, kl_loss = 3.8701746 (32.442 sec)
# INFO:tensorflow:global_step/sec: 2.96098
# INFO:tensorflow:loss = 48.632256, step = 7739 (33.773 sec)
# INFO:tensorflow:nll_loss = 44.77324, kl_w = 0.9996282, kl_loss = 3.8604531 (33.773 sec)
# INFO:tensorflow:Saving checkpoints for 7820 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt.
# INFO:tensorflow:Loss for final step: 50.64791.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpiw3a1iw1/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i was very impressed with this movie and i have seen the best movie <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a complete waste of time and it was a bit harsh <end>
