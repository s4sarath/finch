# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# ![alt text](vae.png)

# %%
import tensorflow as tf
import numpy as np

# %%
PARAMS = {
    'max_len': 15,
    'embed_dims': 128,
    'rnn_size': 128,
    'latent_size': 16,
    'beam_width': 5,
    'num_sampled': 1000,
    'clip_norm': 5.0,
    'anneal_max': 1.0,
    'anneal_bias': 6000,
    'batch_size': 128,
    'n_epochs': 10,
}

# %%
def build_vocab(index_from=4):
    PARAMS['word2idx'] = tf.keras.datasets.imdb.get_word_index()
    PARAMS['word2idx'] = {k: (v + index_from) for k, v in PARAMS['word2idx'].items()}
    PARAMS['word2idx']['<pad>'] = 0
    PARAMS['word2idx']['<start>'] = 1
    PARAMS['word2idx']['<unk>'] = 2
    PARAMS['word2idx']['<end>'] = 3
    
    PARAMS['idx2word'] = {i: w for w, i in PARAMS['word2idx'].items()}
    
    PARAMS['vocab_size'] = len(PARAMS['word2idx'])

    
def load_data(index_from=4):
    (X_train, _), (X_test, _) = tf.contrib.keras.datasets.imdb.load_data(
        num_words=None, index_from=index_from)
    return (X_train, X_test)

# %%
word2idx = build_vocab()
X = np.concatenate(load_data())

X = np.concatenate((
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='post', padding='post'),
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='pre', padding='post')))

enc_inp = X[:, 1:]
dec_inp = X
dec_out = np.concatenate([X[:, 1:], np.full([X.shape[0], 1], PARAMS['word2idx']['<end>'])], 1)

# %%
def reparam_trick(z_mean, z_logvar):
    gaussian = tf.truncated_normal(tf.shape(z_logvar))
    z = z_mean + tf.exp(0.5 * z_logvar) * gaussian
    return z


def kl_w_fn(global_step):
    return PARAMS['anneal_max'] * tf.sigmoid((10 / PARAMS['anneal_bias']) * (
        tf.to_float(global_step) - tf.constant(PARAMS['anneal_bias'] / 2)))


def kl_loss_fn(mean, gamma):
    return 0.5 * tf.reduce_sum(
        tf.exp(gamma) + tf.square(mean) - 1 - gamma) / tf.to_float(tf.shape(mean)[0])

# %%
def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, PARAMS['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    return tf.nn.rnn_cell.GRUCell(PARAMS['rnn_size'],
                                  kernel_initializer=tf.orthogonal_initializer())


def forward(inputs, labels, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    enc_seq_len = tf.count_nonzero(inputs, 1, dtype=tf.int32)
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('Encoder'):
        embedding = tf.get_variable('lookup_table', [len(PARAMS['word2idx']), PARAMS['embed_dims']])
        x = tf.nn.embedding_lookup(embedding, inputs)
        
        _, enc_state = tf.nn.dynamic_rnn(rnn_cell(), x, enc_seq_len, dtype=tf.float32)
        
        z_mean = tf.layers.dense(enc_state, PARAMS['latent_size'])
        z_logvar = tf.layers.dense(enc_state, PARAMS['latent_size'])
        
    z = reparam_trick(z_mean, z_logvar)
        
    with tf.variable_scope('Decoder'):
        init_state = tf.layers.dense(z, PARAMS['rnn_size'], tf.nn.elu)
        output_proj = tf.layers.Dense(len(PARAMS['word2idx']), _scope='decoder/output_proj')
        dec_cell = rnn_cell()
        
        if is_training:
            dec_seq_len = tf.count_nonzero(labels['dec_out'], 1, dtype=tf.int32)
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = tf.nn.embedding_lookup(embedding, labels['dec_inp']),
                sequence_length = dec_seq_len)
            decoder = tf.contrib.seq2seq.BasicDecoder(
                cell = dec_cell,
                helper = helper,
                initial_state = init_state)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = tf.reduce_max(dec_seq_len))
            rnn_output = decoder_output.rnn_output
            
            return rnn_output, output_proj(rnn_output), (z_mean, z_logvar)
        else:
            decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                cell = dec_cell,
                embedding = embedding,
                start_tokens = tf.tile(tf.constant([PARAMS['word2idx']['<start>']], tf.int32),
                                       [batch_sz]),
                end_token = PARAMS['word2idx']['<end>'],
                initial_state = tf.contrib.seq2seq.tile_batch(init_state, PARAMS['beam_width']),
                beam_width = PARAMS['beam_width'],
                output_layer = output_proj)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder)
            
            return decoder_output.predicted_ids[:, :, 0]

# %%
def model_fn(features, labels, mode):
    logits_or_ids = forward(features, labels, mode)        
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
        
    if mode == tf.estimator.ModeKeys.TRAIN:
        rnn_output, logits, (z_mean, z_logvar) = logits_or_ids
        
        global_step = tf.train.get_global_step()
        
        with tf.variable_scope('Decoder/decoder/output_proj', reuse=True):
            _weights = tf.transpose(tf.get_variable('kernel'))
            _biases = tf.get_variable('bias')
        
        mask = tf.reshape(tf.to_float(tf.sign(labels['dec_out'])), [-1])
        
        nll_loss = tf.reduce_sum(mask * tf.nn.sampled_softmax_loss(
            weights = _weights,
            biases = _biases,
            labels = tf.reshape(labels['dec_out'], [-1, 1]),
            inputs = tf.reshape(rnn_output, [-1, PARAMS['rnn_size']]),
            num_sampled = PARAMS['num_sampled'],
            num_classes = PARAMS['vocab_size'],
        )) / tf.to_float(tf.shape(features)[0])
        
        kl_w = kl_w_fn(global_step)
        
        kl_loss = kl_loss_fn(z_mean, z_logvar)
        
        loss_op = nll_loss + kl_w * kl_loss
        
        train_op = tf.train.AdamOptimizer().apply_gradients(
            clip_grads(loss_op),
            global_step = global_step)
        
        lth = tf.train.LoggingTensorHook(
            {'nll_loss': nll_loss, 'kl_w': kl_w, 'kl_loss': kl_loss}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
def inf_inp(test_strs):
    x = [[PARAMS['word2idx'].get(w, 2) for w in s.split()] for s in test_strs]
    x = tf.keras.preprocessing.sequence.pad_sequences(
        x, PARAMS['max_len'], truncating='post', padding='post')
    return x

def demo(test_strs, pred_ids):
    for s, pred in zip(test_strs, pred_ids):
        print('\nOriginal:', s)
        print('Reconstr:', ' '.join([PARAMS['idx2word'].get(idx, '<unk>') for idx in pred]))


test_strs = ['i love this film and i think it is one of the best films',
             'this movie is a waste of time and there is no point to watch it']

estimator = tf.estimator.Estimator(model_fn)

for _ in range(PARAMS['n_epochs']):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = enc_inp,
        y = {'dec_inp': dec_inp, 'dec_out': dec_out},
        batch_size = PARAMS['batch_size'],
        shuffle = True))

    pred_ids = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = inf_inp(test_strs),
        shuffle = False)))

    demo(test_strs, pred_ids)
    print()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x119065518>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 157.40466, step = 1
# INFO:tensorflow:nll_loss = 157.40466, kl_w = 0.006692851, kl_loss = 4.5854915e-05
# INFO:tensorflow:global_step/sec: 3.17278
# INFO:tensorflow:loss = 90.830986, step = 101 (31.519 sec)
# INFO:tensorflow:nll_loss = 89.97844, kl_w = 0.007897083, kl_loss = 107.956894 (31.519 sec)
# INFO:tensorflow:global_step/sec: 3.28734
# INFO:tensorflow:loss = 86.71699, step = 201 (30.420 sec)
# INFO:tensorflow:nll_loss = 86.30669, kl_w = 0.009315956, kl_loss = 44.042492 (30.420 sec)
# INFO:tensorflow:global_step/sec: 3.05611
# INFO:tensorflow:loss = 85.34654, step = 301 (32.721 sec)
# INFO:tensorflow:nll_loss = 84.87699, kl_w = 0.010986943, kl_loss = 42.73745 (32.722 sec)
# INFO:tensorflow:global_step/sec: 3.02684
# INFO:tensorflow:loss = 83.49508, step = 401 (33.038 sec)
# INFO:tensorflow:nll_loss = 82.98968, kl_w = 0.012953726, kl_loss = 39.015778 (33.038 sec)
# INFO:tensorflow:global_step/sec: 3.02203
# INFO:tensorflow:loss = 82.40323, step = 501 (33.090 sec)
# INFO:tensorflow:nll_loss = 81.92747, kl_w = 0.015267149, kl_loss = 31.162266 (33.089 sec)
# INFO:tensorflow:global_step/sec: 3.16004
# INFO:tensorflow:loss = 78.391, step = 601 (31.645 sec)
# INFO:tensorflow:nll_loss = 77.91635, kl_w = 0.01798621, kl_loss = 26.389627 (31.645 sec)
# INFO:tensorflow:global_step/sec: 2.84144
# INFO:tensorflow:loss = 77.2003, step = 701 (35.194 sec)
# INFO:tensorflow:nll_loss = 76.732864, kl_w = 0.021179108, kl_loss = 22.070696 (35.194 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 76.52757.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this movie is the movie of the movie of the movie and <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: i saw this movie is the movie of the movie of the movie and <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 81.80494, step = 783
# INFO:tensorflow:nll_loss = 81.35384, kl_w = 0.024205629, kl_loss = 18.63609
# INFO:tensorflow:global_step/sec: 3.01713
# INFO:tensorflow:loss = 72.49308, step = 883 (33.145 sec)
# INFO:tensorflow:nll_loss = 71.99393, kl_w = 0.028470589, kl_loss = 17.532246 (33.145 sec)
# INFO:tensorflow:global_step/sec: 2.93863
# INFO:tensorflow:loss = 71.35343, step = 983 (34.029 sec)
# INFO:tensorflow:nll_loss = 70.87622, kl_w = 0.033461247, kl_loss = 14.26169 (34.030 sec)
# INFO:tensorflow:global_step/sec: 3.07393
# INFO:tensorflow:loss = 69.48078, step = 1083 (32.531 sec)
# INFO:tensorflow:nll_loss = 68.9174, kl_w = 0.039291352, kl_loss = 14.3386965 (32.531 sec)
# INFO:tensorflow:global_step/sec: 3.09395
# INFO:tensorflow:loss = 68.77092, step = 1183 (32.321 sec)
# INFO:tensorflow:nll_loss = 68.16273, kl_w = 0.04608883, kl_loss = 13.196162 (32.321 sec)
# INFO:tensorflow:global_step/sec: 3.06664
# INFO:tensorflow:loss = 74.333206, step = 1283 (32.609 sec)
# INFO:tensorflow:nll_loss = 73.72288, kl_w = 0.053996176, kl_loss = 11.303114 (32.609 sec)
# INFO:tensorflow:global_step/sec: 3.20837
# INFO:tensorflow:loss = 71.78819, step = 1383 (31.168 sec)
# INFO:tensorflow:nll_loss = 71.11617, kl_w = 0.06317033, kl_loss = 10.6381855 (31.168 sec)
# INFO:tensorflow:global_step/sec: 2.93165
# INFO:tensorflow:loss = 70.355034, step = 1483 (34.111 sec)
# INFO:tensorflow:nll_loss = 69.449875, kl_w = 0.07378165, kl_loss = 12.268048 (34.111 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 67.10242.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i have seen the worst movie i have seen the time of the time <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: it is a good movie to be a good movie br br 10 10 <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1565 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 67.939445, step = 1565
# INFO:tensorflow:nll_loss = 66.79234, kl_w = 0.08368247, kl_loss = 13.707808
# INFO:tensorflow:global_step/sec: 3.0013
# INFO:tensorflow:loss = 67.71056, step = 1665 (33.320 sec)
# INFO:tensorflow:nll_loss = 66.26897, kl_w = 0.09738124, kl_loss = 14.803606 (33.320 sec)
# INFO:tensorflow:global_step/sec: 3.04326
# INFO:tensorflow:loss = 63.30639, step = 1765 (32.859 sec)
# INFO:tensorflow:nll_loss = 61.576202, kl_w = 0.11304584, kl_loss = 15.305189 (32.860 sec)
# INFO:tensorflow:global_step/sec: 3.0722
# INFO:tensorflow:loss = 60.358154, step = 1865 (32.550 sec)
# INFO:tensorflow:nll_loss = 58.375877, kl_w = 0.13086486, kl_loss = 15.147516 (32.550 sec)
# INFO:tensorflow:global_step/sec: 3.02948
# INFO:tensorflow:loss = 60.347267, step = 1965 (33.010 sec)
# INFO:tensorflow:nll_loss = 58.087128, kl_w = 0.15101443, kl_loss = 14.966368 (33.010 sec)
# INFO:tensorflow:global_step/sec: 3.10808
# INFO:tensorflow:loss = 63.986713, step = 2065 (32.173 sec)
# INFO:tensorflow:nll_loss = 61.630173, kl_w = 0.17364664, kl_loss = 13.57089 (32.174 sec)
# INFO:tensorflow:global_step/sec: 2.95402
# INFO:tensorflow:loss = 62.97592, step = 2165 (33.852 sec)
# INFO:tensorflow:nll_loss = 60.454117, kl_w = 0.19887616, kl_loss = 12.680283 (33.852 sec)
# INFO:tensorflow:global_step/sec: 3.08222
# INFO:tensorflow:loss = 62.404377, step = 2265 (32.444 sec)
# INFO:tensorflow:nll_loss = 59.62514, kl_w = 0.22676536, kl_loss = 12.256002 (32.444 sec)
# INFO:tensorflow:Saving checkpoints for 2346 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 62.869072.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i give this one of this movie and this is a great movie and <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: it is a great film and not to watch your time for the movie <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2347 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 61.702316, step = 2347
# INFO:tensorflow:nll_loss = 58.79332, kl_w = 0.25161827, kl_loss = 11.561149
# INFO:tensorflow:global_step/sec: 2.86506
# INFO:tensorflow:loss = 61.359386, step = 2447 (34.904 sec)
# INFO:tensorflow:nll_loss = 58.032555, kl_w = 0.2842792, kl_loss = 11.702694 (34.904 sec)
# INFO:tensorflow:global_step/sec: 3.05993
# INFO:tensorflow:loss = 62.121765, step = 2547 (32.681 sec)
# INFO:tensorflow:nll_loss = 58.650654, kl_w = 0.31937042, kl_loss = 10.868604 (32.681 sec)
# INFO:tensorflow:global_step/sec: 3.09222
# INFO:tensorflow:loss = 62.51836, step = 2647 (32.339 sec)
# INFO:tensorflow:nll_loss = 58.737965, kl_w = 0.35663486, kl_loss = 10.6001835 (32.339 sec)
# INFO:tensorflow:global_step/sec: 3.13788
# INFO:tensorflow:loss = 59.901947, step = 2747 (31.869 sec)
# INFO:tensorflow:nll_loss = 55.639046, kl_w = 0.39571938, kl_loss = 10.772537 (31.869 sec)
# INFO:tensorflow:global_step/sec: 3.13782
# INFO:tensorflow:loss = 60.10884, step = 2847 (31.869 sec)
# INFO:tensorflow:nll_loss = 55.633247, kl_w = 0.43618327, kl_loss = 10.260807 (31.869 sec)
# INFO:tensorflow:global_step/sec: 3.01218
# INFO:tensorflow:loss = 58.795868, step = 2947 (33.199 sec)
# INFO:tensorflow:nll_loss = 54.302994, kl_w = 0.47751516, kl_loss = 9.40886 (33.199 sec)
# INFO:tensorflow:global_step/sec: 3.03803
# INFO:tensorflow:loss = 57.77285, step = 3047 (32.916 sec)
# INFO:tensorflow:nll_loss = 52.851257, kl_w = 0.5191573, kl_loss = 9.479963 (32.916 sec)
# INFO:tensorflow:Saving checkpoints for 3128 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 63.337692.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i watched this film on the movie i have ever seen in this one <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a waste of time and watch this movie at all time and <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3129 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 59.613686, step = 3129
# INFO:tensorflow:nll_loss = 54.668835, kl_w = 0.55313194, kl_loss = 8.939732
# INFO:tensorflow:global_step/sec: 2.93586
# INFO:tensorflow:loss = 61.439903, step = 3229 (34.063 sec)
# INFO:tensorflow:nll_loss = 56.754395, kl_w = 0.5938731, kl_loss = 7.8897448 (34.063 sec)
# INFO:tensorflow:global_step/sec: 2.94759
# INFO:tensorflow:loss = 61.10573, step = 3329 (33.926 sec)
# INFO:tensorflow:nll_loss = 56.37469, kl_w = 0.6333619, kl_loss = 7.4697204 (33.926 sec)
# INFO:tensorflow:global_step/sec: 2.9222
# INFO:tensorflow:loss = 62.391808, step = 3429 (34.220 sec)
# INFO:tensorflow:nll_loss = 57.295094, kl_w = 0.6711373, kl_loss = 7.594146 (34.220 sec)
# INFO:tensorflow:global_step/sec: 2.96394
# INFO:tensorflow:loss = 62.325993, step = 3529 (33.740 sec)
# INFO:tensorflow:nll_loss = 57.528465, kl_w = 0.7068222, kl_loss = 6.7874594 (33.740 sec)
# INFO:tensorflow:global_step/sec: 2.97109
# INFO:tensorflow:loss = 59.17262, step = 3629 (33.657 sec)
# INFO:tensorflow:nll_loss = 54.217056, kl_w = 0.7401343, kl_loss = 6.6954923 (33.657 sec)
# INFO:tensorflow:global_step/sec: 3.03747
# INFO:tensorflow:loss = 59.14831, step = 3729 (32.922 sec)
# INFO:tensorflow:nll_loss = 54.000076, kl_w = 0.7708882, kl_loss = 6.678318 (32.922 sec)
# INFO:tensorflow:global_step/sec: 2.89081
# INFO:tensorflow:loss = 59.742912, step = 3829 (34.592 sec)
# INFO:tensorflow:nll_loss = 54.794197, kl_w = 0.79899096, kl_loss = 6.1937056 (34.592 sec)
# INFO:tensorflow:Saving checkpoints for 3910 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 59.151176.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this movie at the worst movie i have ever seen in the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time if you want to see a movie <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3911 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 57.417366, step = 3911
# INFO:tensorflow:nll_loss = 52.59764, kl_w = 0.82004714, kl_loss = 5.8773756
# INFO:tensorflow:global_step/sec: 2.98915
# INFO:tensorflow:loss = 57.309673, step = 4011 (33.456 sec)
# INFO:tensorflow:nll_loss = 52.42621, kl_w = 0.84334546, kl_loss = 5.790586 (33.455 sec)
# INFO:tensorflow:global_step/sec: 3.07125
# INFO:tensorflow:loss = 56.854713, step = 4111 (32.560 sec)
# INFO:tensorflow:nll_loss = 51.99527, kl_w = 0.8641271, kl_loss = 5.6235294 (32.560 sec)
# INFO:tensorflow:global_step/sec: 2.97962
# INFO:tensorflow:loss = 57.710796, step = 4211 (33.561 sec)
# INFO:tensorflow:nll_loss = 52.969776, kl_w = 0.88253593, kl_loss = 5.3720427 (33.561 sec)
# INFO:tensorflow:global_step/sec: 2.88034
# INFO:tensorflow:loss = 61.620502, step = 4311 (34.719 sec)
# INFO:tensorflow:nll_loss = 57.419724, kl_w = 0.89874285, kl_loss = 4.674061 (34.719 sec)
# INFO:tensorflow:global_step/sec: 2.87392
# INFO:tensorflow:loss = 61.64417, step = 4411 (34.795 sec)
# INFO:tensorflow:nll_loss = 57.330853, kl_w = 0.9129343, kl_loss = 4.7246723 (34.795 sec)
# INFO:tensorflow:global_step/sec: 2.94973
# INFO:tensorflow:loss = 61.96004, step = 4511 (33.902 sec)
# INFO:tensorflow:nll_loss = 57.79836, kl_w = 0.92530197, kl_loss = 4.4976487 (33.902 sec)
# INFO:tensorflow:global_step/sec: 3.05756
# INFO:tensorflow:loss = 59.619534, step = 4611 (32.706 sec)
# INFO:tensorflow:nll_loss = 55.239914, kl_w = 0.93603605, kl_loss = 4.6789 (32.706 sec)
# INFO:tensorflow:Saving checkpoints for 4692 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 57.501835.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: and i love this movie is one of the worst movies i've ever seen <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a must see if you want to be a fan of <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4693 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 60.99565, step = 4693
# INFO:tensorflow:nll_loss = 56.67337, kl_w = 0.94374704, kl_loss = 4.579913
# INFO:tensorflow:global_step/sec: 2.80207
# INFO:tensorflow:loss = 60.007652, step = 4793 (35.689 sec)
# INFO:tensorflow:nll_loss = 56.22683, kl_w = 0.95196813, kl_loss = 3.9715834 (35.689 sec)
# INFO:tensorflow:global_step/sec: 2.8112
# INFO:tensorflow:loss = 58.842514, step = 4893 (35.572 sec)
# INFO:tensorflow:nll_loss = 55.106506, kl_w = 0.9590399, kl_loss = 3.8955693 (35.572 sec)
# INFO:tensorflow:global_step/sec: 3.00994
# INFO:tensorflow:loss = 58.89876, step = 4993 (33.224 sec)
# INFO:tensorflow:nll_loss = 55.200943, kl_w = 0.9651086, kl_loss = 3.8315053 (33.224 sec)
# INFO:tensorflow:global_step/sec: 3.1695
# INFO:tensorflow:loss = 56.50543, step = 5093 (31.550 sec)
# INFO:tensorflow:nll_loss = 52.44768, kl_w = 0.97030604, kl_loss = 4.1819253 (31.550 sec)
# INFO:tensorflow:global_step/sec: 2.71561
# INFO:tensorflow:loss = 58.10353, step = 5193 (36.824 sec)
# INFO:tensorflow:nll_loss = 54.01696, kl_w = 0.97474945, kl_loss = 4.1924305 (36.824 sec)
# INFO:tensorflow:global_step/sec: 2.70876
# INFO:tensorflow:loss = 56.694443, step = 5293 (36.917 sec)
# INFO:tensorflow:nll_loss = 52.818096, kl_w = 0.9785427, kl_loss = 3.9613466 (36.918 sec)
# INFO:tensorflow:global_step/sec: 2.8718
# INFO:tensorflow:loss = 59.747543, step = 5393 (34.821 sec)
# INFO:tensorflow:nll_loss = 56.021843, kl_w = 0.9817768, kl_loss = 3.7948537 (34.821 sec)
# INFO:tensorflow:Saving checkpoints for 5474 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 61.11123.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i can't believe that this is one of the best movies i have ever <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time if you want to see this movie <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5475 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 58.367317, step = 5475
# INFO:tensorflow:nll_loss = 54.49482, kl_w = 0.98406756, kl_loss = 3.9351935
# INFO:tensorflow:global_step/sec: 2.89563
# INFO:tensorflow:loss = 53.483494, step = 5575 (34.538 sec)
# INFO:tensorflow:nll_loss = 49.647816, kl_w = 0.9864804, kl_loss = 3.8882456 (34.537 sec)
# INFO:tensorflow:global_step/sec: 2.85007
# INFO:tensorflow:loss = 53.094948, step = 5675 (35.085 sec)
# INFO:tensorflow:nll_loss = 49.344124, kl_w = 0.98853207, kl_loss = 3.794336 (35.085 sec)
# INFO:tensorflow:global_step/sec: 2.8071
# INFO:tensorflow:loss = 52.078224, step = 5775 (35.625 sec)
# INFO:tensorflow:nll_loss = 48.30413, kl_w = 0.9902755, kl_loss = 3.8111556 (35.625 sec)
# INFO:tensorflow:global_step/sec: 2.95983
# INFO:tensorflow:loss = 57.796352, step = 5875 (33.785 sec)
# INFO:tensorflow:nll_loss = 54.472305, kl_w = 0.9917561, kl_loss = 3.3516784 (33.785 sec)
# INFO:tensorflow:global_step/sec: 2.91504
# INFO:tensorflow:loss = 60.134163, step = 5975 (34.304 sec)
# INFO:tensorflow:nll_loss = 56.853226, kl_w = 0.99301285, kl_loss = 3.304022 (34.304 sec)
# INFO:tensorflow:global_step/sec: 2.57207
# INFO:tensorflow:loss = 57.061817, step = 6075 (38.879 sec)
# INFO:tensorflow:nll_loss = 53.69393, kl_w = 0.9940791, kl_loss = 3.3879447 (38.879 sec)
# INFO:tensorflow:global_step/sec: 2.88541
# INFO:tensorflow:loss = 59.13662, step = 6175 (34.657 sec)
# INFO:tensorflow:nll_loss = 55.84224, kl_w = 0.99498355, kl_loss = 3.3109915 (34.657 sec)
# INFO:tensorflow:Saving checkpoints for 6256 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 55.606598.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this is one of my favorite movies i have ever seen in this one <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time to watch this movie br br 10 <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6257 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 52.860653, step = 6257
# INFO:tensorflow:nll_loss = 49.23375, kl_w = 0.9956215, kl_loss = 3.6428542
# INFO:tensorflow:global_step/sec: 3.07788
# INFO:tensorflow:loss = 57.041534, step = 6357 (32.491 sec)
# INFO:tensorflow:nll_loss = 53.864777, kl_w = 0.9962913, kl_loss = 3.1885824 (32.491 sec)
# INFO:tensorflow:global_step/sec: 2.82295
# INFO:tensorflow:loss = 57.58011, step = 6457 (35.424 sec)
# INFO:tensorflow:nll_loss = 54.23829, kl_w = 0.99685884, kl_loss = 3.3523493 (35.424 sec)
# INFO:tensorflow:global_step/sec: 2.72949
# INFO:tensorflow:loss = 55.47619, step = 6557 (36.637 sec)
# INFO:tensorflow:nll_loss = 52.305473, kl_w = 0.9973398, kl_loss = 3.179173 (36.637 sec)
# INFO:tensorflow:global_step/sec: 2.83527
# INFO:tensorflow:loss = 56.467827, step = 6657 (35.270 sec)
# INFO:tensorflow:nll_loss = 53.2976, kl_w = 0.99774724, kl_loss = 3.1773868 (35.269 sec)
# INFO:tensorflow:global_step/sec: 3.09932
# INFO:tensorflow:loss = 54.523056, step = 6757 (32.265 sec)
# INFO:tensorflow:nll_loss = 51.091072, kl_w = 0.99809235, kl_loss = 3.4385438 (32.265 sec)
# INFO:tensorflow:global_step/sec: 3.0332
# INFO:tensorflow:loss = 53.5045, step = 6857 (32.969 sec)
# INFO:tensorflow:nll_loss = 49.98471, kl_w = 0.99838483, kl_loss = 3.5254858 (32.969 sec)
# INFO:tensorflow:global_step/sec: 2.98595
# INFO:tensorflow:loss = 52.896954, step = 6957 (33.490 sec)
# INFO:tensorflow:nll_loss = 49.217236, kl_w = 0.9986324, kl_loss = 3.6847577 (33.490 sec)
# INFO:tensorflow:Saving checkpoints for 7038 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 54.943295.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think that this is one of the best movies i have ever seen <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is one of the worst movies i've ever seen and i have seen <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7039 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:loss = 56.955563, step = 7039
# INFO:tensorflow:nll_loss = 53.519234, kl_w = 0.99880695, kl_loss = 3.440435
# INFO:tensorflow:global_step/sec: 2.88623
# INFO:tensorflow:loss = 53.932114, step = 7139 (34.649 sec)
# INFO:tensorflow:nll_loss = 50.74141, kl_w = 0.9989899, kl_loss = 3.1939325 (34.648 sec)
# INFO:tensorflow:global_step/sec: 2.83628
# INFO:tensorflow:loss = 55.08818, step = 7239 (35.257 sec)
# INFO:tensorflow:nll_loss = 51.72616, kl_w = 0.9991448, kl_loss = 3.3648996 (35.258 sec)
# INFO:tensorflow:global_step/sec: 2.89682
# INFO:tensorflow:loss = 52.075344, step = 7339 (34.521 sec)
# INFO:tensorflow:nll_loss = 48.509727, kl_w = 0.999276, kl_loss = 3.5682008 (34.520 sec)
# INFO:tensorflow:global_step/sec: 2.9367
# INFO:tensorflow:loss = 51.618446, step = 7439 (34.052 sec)
# INFO:tensorflow:nll_loss = 48.247395, kl_w = 0.999387, kl_loss = 3.3731208 (34.052 sec)
# INFO:tensorflow:global_step/sec: 2.80006
# INFO:tensorflow:loss = 52.742844, step = 7539 (35.713 sec)
# INFO:tensorflow:nll_loss = 49.32448, kl_w = 0.99948114, kl_loss = 3.4201381 (35.714 sec)
# INFO:tensorflow:global_step/sec: 3.15174
# INFO:tensorflow:loss = 55.68722, step = 7639 (31.729 sec)
# INFO:tensorflow:nll_loss = 52.68635, kl_w = 0.9995608, kl_loss = 3.0021892 (31.728 sec)
# INFO:tensorflow:global_step/sec: 3.17731
# INFO:tensorflow:loss = 54.859898, step = 7739 (31.473 sec)
# INFO:tensorflow:nll_loss = 51.756283, kl_w = 0.9996282, kl_loss = 3.1047695 (31.473 sec)
# INFO:tensorflow:Saving checkpoints for 7820 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt.
# INFO:tensorflow:Loss for final step: 55.091526.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpgmez5mla/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this movie for a few years ago i have seen this one <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is one of the worst movies i've ever seen br br 9 10 <end>
