# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)

# %%
import tensorflow as tf
import numpy as np

# %%
PARAMS = {
    'max_len': 15,
    'embed_dims': 128,
    'rnn_size': 128,
    'hidden_dim': 128,
    'num_heads': 4,
    'latent_size': 16,
    'n_hidden_layer': 1,
    'num_sampled': 1000,
    'clip_norm': 5.0,
    'anneal_max': 1.0,
    'anneal_bias': 6000,
    'batch_size': 128,
    'n_epochs': 10,
}

# %%
def build_vocab(index_from=4):
    PARAMS['word2idx'] = tf.keras.datasets.imdb.get_word_index()
    PARAMS['word2idx'] = {k: (v + index_from) for k, v in PARAMS['word2idx'].items()}
    PARAMS['word2idx']['<pad>'] = 0
    PARAMS['word2idx']['<start>'] = 1
    PARAMS['word2idx']['<unk>'] = 2
    PARAMS['word2idx']['<end>'] = 3
    
    PARAMS['idx2word'] = {i: w for w, i in PARAMS['word2idx'].items()}
    
    PARAMS['vocab_size'] = len(PARAMS['word2idx'])

    
def load_data(index_from=4):
    (X_train, _), (X_test, _) = tf.contrib.keras.datasets.imdb.load_data(
        num_words=None, index_from=index_from)
    return (X_train, X_test)

# %%
word2idx = build_vocab()
X = np.concatenate(load_data())

X = np.concatenate((
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='post', padding='post'),
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='pre', padding='post')))

enc_inp = X[:, 1:]
dec_inp = X
dec_out = np.concatenate([X[:, 1:], np.full([X.shape[0], 1], PARAMS['word2idx']['<end>'])], 1)

# %%
def reparam_trick(z_mean, z_logvar):
    gaussian = tf.truncated_normal(tf.shape(z_logvar))
    z = z_mean + tf.exp(0.5 * z_logvar) * gaussian
    return z


def kl_w_fn(global_step):
    return PARAMS['anneal_max'] * tf.sigmoid((10 / PARAMS['anneal_bias']) * (
        tf.to_float(global_step) - tf.constant(PARAMS['anneal_bias'] / 2)))


def kl_loss_fn(mean, gamma):
    return 0.5 * tf.reduce_sum(
        tf.exp(gamma) + tf.square(mean) - 1 - gamma) / tf.to_float(tf.shape(mean)[0])


def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, PARAMS['clip_norm'])
    return zip(clipped_grads, variables)


def rnn_cell():
    return tf.nn.rnn_cell.GRUCell(PARAMS['rnn_size'],
                                  kernel_initializer=tf.orthogonal_initializer())


def embed_seq(x, vocab_sz, embed_dim, name, zero_pad=False, scale=False):
    embedding = tf.get_variable(name, [vocab_sz, embed_dim])
    if zero_pad:
        embedding = tf.concat([tf.zeros([1, embed_dim]), embedding[1:, :]], 0)
    x = tf.nn.embedding_lookup(embedding, x)
    if scale:
        x = x * np.sqrt(embed_dim)
    return x


def position_embedding(inputs):
    T = inputs.get_shape().as_list()[1]
    x = tf.range(T)                            # (T)
    x = tf.expand_dims(x, 0)                   # (1, T)
    x = tf.tile(x, [tf.shape(inputs)[0], 1])   # (N, T)
    return embed_seq(x, T, PARAMS['hidden_dim'], 'position_embedding')


def layer_norm(inputs, epsilon=1e-8):
    mean, variance = tf.nn.moments(inputs, [-1], keep_dims=True)
    normalized = (inputs - mean) / (tf.sqrt(variance + epsilon))
    
    params_shape = inputs.get_shape()[-1:]
    gamma = tf.get_variable('gamma', params_shape, tf.float32, tf.ones_initializer())
    beta = tf.get_variable('beta', params_shape, tf.float32, tf.zeros_initializer())
    
    return gamma * normalized + beta


def self_attention(inputs, is_training):
    num_units = PARAMS['hidden_dim']
    num_heads = PARAMS['num_heads']
    T_q = T_k = inputs.get_shape()[1].value

    Q_K_V = tf.layers.dense(inputs, 3*num_units)
    Q, K, V = tf.split(Q_K_V, 3, -1)
    Q_ = tf.concat(tf.split(Q, num_heads, axis=2), 0)                         
    K_ = tf.concat(tf.split(K, num_heads, axis=2), 0)                        
    V_ = tf.concat(tf.split(V, num_heads, axis=2), 0)                         

    align = tf.matmul(Q_, K_, transpose_b=True)                               
    align = align / np.sqrt(K_.get_shape().as_list()[-1])

    paddings = tf.fill(tf.shape(align), float('-inf'))         
    lower_tri = tf.ones([T_q, T_k])                                                
    lower_tri = tf.linalg.LinearOperatorLowerTriangular(lower_tri).to_dense()      
    masks = tf.tile(tf.expand_dims(lower_tri,0), [tf.shape(align)[0],1,1])       
    align = tf.where(tf.equal(masks, 0), paddings, align)               

    align = tf.nn.softmax(align)                                                  
    align = tf.layers.dropout(align, 0.1, training=is_training)           
    x = tf.matmul(align, V_)                                                 
    x = tf.concat(tf.split(x, num_heads, axis=0), 2)              
    x += inputs                                                                
    x = layer_norm(x)                                                 
    return x


def ffn(inputs, activation=tf.nn.relu):
    x = tf.layers.conv1d(inputs, 4*PARAMS['hidden_dim'], 1, activation=activation)
    x = tf.layers.conv1d(x, PARAMS['hidden_dim'], 1)
    x += inputs
    x = layer_norm(x)
    return x


def attn_forward(x, output_proj, is_training):
    x += position_embedding(x)
    x = tf.layers.dropout(x, 0.1, training=is_training)
    for i in range(PARAMS['n_hidden_layer']):
        with tf.variable_scope('attn_%d'%i):
            x = self_attention(x, is_training)
        with tf.variable_scope('ffn_%d'%i):
            x = ffn(x)
    return output_proj(x), x


def autoregressive(embedding, init_state, output_proj):
    def cond(i, x, temp):
        return i < PARAMS['max_len']

    def body(i, x, temp):
        sos = tf.fill([tf.shape(init_state)[0], 1], PARAMS['word2idx']['<start>'])
        x = tf.concat([sos, x[:, :-1]], 1)
        
        x = tf.nn.embedding_lookup(embedding, x)
        x += init_state
        logits = attn_forward(x, output_proj, is_training=False)[0]
        ids = tf.argmax(logits, -1, output_type=tf.int32)[:, i]
        ids = tf.expand_dims(ids, -1)

        temp = tf.concat([temp[:, 1:], ids], -1)

        x = tf.concat([temp[:, -(i+1):], temp[:, :-(i+1)]], -1)
        x = tf.reshape(x, [tf.shape(init_state)[0], PARAMS['max_len']])
        i += 1
        return i, x, temp
    
    x = tf.zeros([tf.shape(init_state)[0], PARAMS['max_len']], tf.int32)
    _, res, _ = tf.while_loop(cond, body, [tf.constant(0), x, x])
    
    return res

# %%
def forward(inputs, labels, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    enc_seq_len = tf.count_nonzero(inputs, 1, dtype=tf.int32)
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('Encoder'):
        embedding = tf.get_variable('lookup_table', [len(PARAMS['word2idx']), PARAMS['embed_dims']])
        x = tf.nn.embedding_lookup(embedding, inputs)
        
        _, enc_state = tf.nn.dynamic_rnn(rnn_cell(), x, enc_seq_len, dtype=tf.float32)
        
        z_mean = tf.layers.dense(enc_state, PARAMS['latent_size'])
        z_logvar = tf.layers.dense(enc_state, PARAMS['latent_size'])
        
    z = reparam_trick(z_mean, z_logvar)
        
    with tf.variable_scope('Decoder'):
        output_proj = tf.layers.Dense(len(PARAMS['word2idx']), _scope='decoder/output_proj')
        init_state = tf.layers.dense(z, PARAMS['hidden_dim'], tf.nn.relu)
        init_state = tf.tile(tf.expand_dims(init_state, 1), [1, PARAMS['max_len'], 1])
        
        if is_training:
            dec_inp = tf.nn.embedding_lookup(embedding, labels['dec_inp'])
            x = dec_inp + init_state
            logits, x = attn_forward(x, output_proj, is_training)
            return x, logits, (z_mean, z_logvar)
        else:
            return autoregressive(embedding, init_state, output_proj)

# %%
def model_fn(features, labels, mode):
    logits_or_ids = forward(features, labels, mode)        
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
        
    if mode == tf.estimator.ModeKeys.TRAIN:
        attn_output, logits, (z_mean, z_logvar) = logits_or_ids
        
        global_step = tf.train.get_global_step()
        
        with tf.variable_scope('Decoder/decoder/output_proj', reuse=True):
            _weights = tf.transpose(tf.get_variable('kernel'))
            _biases = tf.get_variable('bias')
        
        mask = tf.reshape(tf.to_float(tf.sign(labels['dec_out'])), [-1])
        
        nll_loss = tf.reduce_sum(mask * tf.nn.sampled_softmax_loss(
            weights = _weights,
            biases = _biases,
            labels = tf.reshape(labels['dec_out'], [-1, 1]),
            inputs = tf.reshape(attn_output, [-1, PARAMS['hidden_dim']]),
            num_sampled = PARAMS['num_sampled'],
            num_classes = PARAMS['vocab_size'],
        )) / tf.to_float(tf.shape(features)[0])
        
        kl_w = kl_w_fn(global_step)
        
        kl_loss = kl_loss_fn(z_mean, z_logvar)
        
        loss_op = nll_loss + kl_w * kl_loss
        
        train_op = tf.train.AdamOptimizer().apply_gradients(
            clip_grads(loss_op),
            global_step = global_step)
        
        lth = tf.train.LoggingTensorHook(
            {'nll_loss': nll_loss, 'kl_w': kl_w, 'kl_loss': kl_loss}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
def inf_inp(test_strs):
    x = [[PARAMS['word2idx'].get(w, 2) for w in s.split()] for s in test_strs]
    x = tf.keras.preprocessing.sequence.pad_sequences(
        x, PARAMS['max_len'], truncating='post', padding='post')
    return x

def demo(test_strs, pred_ids):
    for s, pred in zip(test_strs, pred_ids):
        print('\nOriginal:', s)
        print('Reconstr:', ' '.join([PARAMS['idx2word'].get(idx, '<unk>') for idx in pred]))


test_strs = ['i love this film and i think it is one of the best films',
             'this movie is a waste of time and there is no point to watch it']

estimator = tf.estimator.Estimator(model_fn)

for _ in range(PARAMS['n_epochs']):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = enc_inp,
        y = {'dec_inp': dec_inp, 'dec_out': dec_out},
        batch_size = PARAMS['batch_size'],
        shuffle = True))
    
    pred_ids = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = inf_inp(test_strs),
        shuffle = False)))

    demo(test_strs, pred_ids)
    
    print()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1149d6c18>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 155.08357, step = 1
# INFO:tensorflow:nll_loss = 155.08357, kl_w = 0.006692851, kl_loss = 4.5455134e-05
# INFO:tensorflow:global_step/sec: 2.69132
# INFO:tensorflow:loss = 86.58098, step = 101 (37.158 sec)
# INFO:tensorflow:nll_loss = 86.53421, kl_w = 0.007897083, kl_loss = 5.922057 (37.157 sec)
# INFO:tensorflow:global_step/sec: 2.71752
# INFO:tensorflow:loss = 78.569954, step = 201 (36.798 sec)
# INFO:tensorflow:nll_loss = 78.45598, kl_w = 0.009315956, kl_loss = 12.234191 (36.798 sec)
# INFO:tensorflow:global_step/sec: 2.67425
# INFO:tensorflow:loss = 73.87829, step = 301 (37.394 sec)
# INFO:tensorflow:nll_loss = 73.61029, kl_w = 0.010986943, kl_loss = 24.392174 (37.394 sec)
# INFO:tensorflow:global_step/sec: 2.73253
# INFO:tensorflow:loss = 67.54834, step = 401 (36.596 sec)
# INFO:tensorflow:nll_loss = 67.1347, kl_w = 0.012953726, kl_loss = 31.932064 (36.596 sec)
# INFO:tensorflow:global_step/sec: 2.77511
# INFO:tensorflow:loss = 63.855583, step = 501 (36.034 sec)
# INFO:tensorflow:nll_loss = 63.29767, kl_w = 0.015267149, kl_loss = 36.54345 (36.034 sec)
# INFO:tensorflow:global_step/sec: 2.88196
# INFO:tensorflow:loss = 62.57232, step = 601 (34.699 sec)
# INFO:tensorflow:nll_loss = 61.87507, kl_w = 0.01798621, kl_loss = 38.765846 (34.699 sec)
# INFO:tensorflow:global_step/sec: 2.82343
# INFO:tensorflow:loss = 58.864117, step = 701 (35.418 sec)
# INFO:tensorflow:nll_loss = 58.03741, kl_w = 0.021179108, kl_loss = 39.03399 (35.418 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 63.308525.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i don't see this movie and i was a good film and the movie <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a good than for starters and it is a movie it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 59.107555, step = 783
# INFO:tensorflow:nll_loss = 58.16594, kl_w = 0.024205629, kl_loss = 38.900764
# INFO:tensorflow:global_step/sec: 2.7611
# INFO:tensorflow:loss = 52.26131, step = 883 (36.218 sec)
# INFO:tensorflow:nll_loss = 51.088696, kl_w = 0.028470589, kl_loss = 41.18689 (36.218 sec)
# INFO:tensorflow:global_step/sec: 2.81041
# INFO:tensorflow:loss = 59.63522, step = 983 (35.582 sec)
# INFO:tensorflow:nll_loss = 58.34262, kl_w = 0.033461247, kl_loss = 38.629707 (35.582 sec)
# INFO:tensorflow:global_step/sec: 2.72424
# INFO:tensorflow:loss = 59.644714, step = 1083 (36.708 sec)
# INFO:tensorflow:nll_loss = 58.139236, kl_w = 0.039291352, kl_loss = 38.315765 (36.708 sec)
# INFO:tensorflow:global_step/sec: 2.7868
# INFO:tensorflow:loss = 57.671345, step = 1183 (35.883 sec)
# INFO:tensorflow:nll_loss = 55.963715, kl_w = 0.04608883, kl_loss = 37.05082 (35.883 sec)
# INFO:tensorflow:global_step/sec: 2.85393
# INFO:tensorflow:loss = 53.899048, step = 1283 (35.040 sec)
# INFO:tensorflow:nll_loss = 51.887806, kl_w = 0.053996176, kl_loss = 37.247826 (35.040 sec)
# INFO:tensorflow:global_step/sec: 2.82048
# INFO:tensorflow:loss = 53.088844, step = 1383 (35.455 sec)
# INFO:tensorflow:nll_loss = 50.818714, kl_w = 0.06317033, kl_loss = 35.93666 (35.455 sec)
# INFO:tensorflow:global_step/sec: 2.88519
# INFO:tensorflow:loss = 52.583645, step = 1483 (34.659 sec)
# INFO:tensorflow:nll_loss = 49.97514, kl_w = 0.07378165, kl_loss = 35.354393 (34.659 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 50.360195.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this film and it really enjoyed it is the worst film of <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a lot of all of all films but it has been <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1565 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 47.280743, step = 1565
# INFO:tensorflow:nll_loss = 44.37349, kl_w = 0.08368247, kl_loss = 34.7415
# INFO:tensorflow:global_step/sec: 2.7786
# INFO:tensorflow:loss = 45.706383, step = 1665 (35.991 sec)
# INFO:tensorflow:nll_loss = 42.453697, kl_w = 0.09738124, kl_loss = 33.40158 (35.990 sec)
# INFO:tensorflow:global_step/sec: 2.79706
# INFO:tensorflow:loss = 47.302338, step = 1765 (35.752 sec)
# INFO:tensorflow:nll_loss = 43.642548, kl_w = 0.11304584, kl_loss = 32.374374 (35.752 sec)
# INFO:tensorflow:global_step/sec: 2.51433
# INFO:tensorflow:loss = 47.56509, step = 1865 (39.772 sec)
# INFO:tensorflow:nll_loss = 43.56723, kl_w = 0.13086486, kl_loss = 30.549526 (39.771 sec)
# INFO:tensorflow:global_step/sec: 2.76286
# INFO:tensorflow:loss = 54.259804, step = 1965 (36.195 sec)
# INFO:tensorflow:nll_loss = 50.03901, kl_w = 0.15101443, kl_loss = 27.949612 (36.195 sec)
# INFO:tensorflow:global_step/sec: 2.84585
# INFO:tensorflow:loss = 55.250816, step = 2065 (35.139 sec)
# INFO:tensorflow:nll_loss = 50.759415, kl_w = 0.17364664, kl_loss = 25.865168 (35.139 sec)
# INFO:tensorflow:global_step/sec: 2.82468
# INFO:tensorflow:loss = 53.189766, step = 2165 (35.403 sec)
# INFO:tensorflow:nll_loss = 48.175682, kl_w = 0.19887616, kl_loss = 25.21209 (35.403 sec)
# INFO:tensorflow:global_step/sec: 2.75724
# INFO:tensorflow:loss = 51.80909, step = 2265 (36.268 sec)
# INFO:tensorflow:nll_loss = 46.42247, kl_w = 0.22676536, kl_loss = 23.754147 (36.268 sec)
# INFO:tensorflow:Saving checkpoints for 2346 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 52.42141.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i love this movie and it was one of all it is the best <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time and one of people have seen it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2347 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 48.93006, step = 2347
# INFO:tensorflow:nll_loss = 43.06196, kl_w = 0.25161827, kl_loss = 23.321459
# INFO:tensorflow:global_step/sec: 2.64609
# INFO:tensorflow:loss = 49.267227, step = 2447 (37.795 sec)
# INFO:tensorflow:nll_loss = 43.044155, kl_w = 0.2842792, kl_loss = 21.890705 (37.794 sec)
# INFO:tensorflow:global_step/sec: 2.6665
# INFO:tensorflow:loss = 53.567398, step = 2547 (37.500 sec)
# INFO:tensorflow:nll_loss = 47.290516, kl_w = 0.31937042, kl_loss = 19.653921 (37.501 sec)
# INFO:tensorflow:global_step/sec: 2.65614
# INFO:tensorflow:loss = 53.25959, step = 2647 (37.649 sec)
# INFO:tensorflow:nll_loss = 46.623337, kl_w = 0.35663486, kl_loss = 18.607979 (37.649 sec)
# INFO:tensorflow:global_step/sec: 2.78982
# INFO:tensorflow:loss = 52.615395, step = 2747 (35.845 sec)
# INFO:tensorflow:nll_loss = 45.488037, kl_w = 0.39571938, kl_loss = 18.011139 (35.845 sec)
# INFO:tensorflow:global_step/sec: 2.67542
# INFO:tensorflow:loss = 53.062656, step = 2847 (37.377 sec)
# INFO:tensorflow:nll_loss = 45.71318, kl_w = 0.43618327, kl_loss = 16.849512 (37.377 sec)
# INFO:tensorflow:global_step/sec: 2.78945
# INFO:tensorflow:loss = 52.809357, step = 2947 (35.849 sec)
# INFO:tensorflow:nll_loss = 45.195206, kl_w = 0.47751516, kl_loss = 15.945358 (35.849 sec)
# INFO:tensorflow:global_step/sec: 2.77133
# INFO:tensorflow:loss = 52.15798, step = 3047 (36.084 sec)
# INFO:tensorflow:nll_loss = 44.391994, kl_w = 0.5191573, kl_loss = 14.958835 (36.084 sec)
# INFO:tensorflow:Saving checkpoints for 3128 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 50.12448.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i loved this movie because it was it is about the best films of <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a few years ago that is nothing to see it to <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3129 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 57.34903, step = 3129
# INFO:tensorflow:nll_loss = 49.195023, kl_w = 0.55313194, kl_loss = 14.741527
# INFO:tensorflow:global_step/sec: 2.65613
# INFO:tensorflow:loss = 53.22147, step = 3229 (37.650 sec)
# INFO:tensorflow:nll_loss = 45.217422, kl_w = 0.5938731, kl_loss = 13.477705 (37.650 sec)
# INFO:tensorflow:global_step/sec: 2.72518
# INFO:tensorflow:loss = 50.597755, step = 3329 (36.695 sec)
# INFO:tensorflow:nll_loss = 42.33819, kl_w = 0.6333619, kl_loss = 13.040834 (36.695 sec)
# INFO:tensorflow:global_step/sec: 2.85604
# INFO:tensorflow:loss = 50.48148, step = 3429 (35.013 sec)
# INFO:tensorflow:nll_loss = 42.2425, kl_w = 0.6711373, kl_loss = 12.276146 (35.013 sec)
# INFO:tensorflow:global_step/sec: 2.72474
# INFO:tensorflow:loss = 53.142776, step = 3529 (36.702 sec)
# INFO:tensorflow:nll_loss = 45.28577, kl_w = 0.7068222, kl_loss = 11.115957 (36.703 sec)
# INFO:tensorflow:global_step/sec: 2.77643
# INFO:tensorflow:loss = 57.71045, step = 3629 (36.016 sec)
# INFO:tensorflow:nll_loss = 49.52842, kl_w = 0.7401343, kl_loss = 11.054789 (36.016 sec)
# INFO:tensorflow:global_step/sec: 2.78571
# INFO:tensorflow:loss = 56.180305, step = 3729 (35.897 sec)
# INFO:tensorflow:nll_loss = 48.659523, kl_w = 0.7708882, kl_loss = 9.755994 (35.898 sec)
# INFO:tensorflow:global_step/sec: 2.79362
# INFO:tensorflow:loss = 57.89097, step = 3829 (35.796 sec)
# INFO:tensorflow:nll_loss = 50.673016, kl_w = 0.79899096, kl_loss = 9.033837 (35.796 sec)
# INFO:tensorflow:Saving checkpoints for 3910 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 53.79992.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i can't wait for this movie i recommend it to the best of all <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a great film if you are going to be avoided at all <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3911 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 51.337765, step = 3911
# INFO:tensorflow:nll_loss = 44.403908, kl_w = 0.82004714, kl_loss = 8.455439
# INFO:tensorflow:global_step/sec: 2.61919
# INFO:tensorflow:loss = 54.190014, step = 4011 (38.181 sec)
# INFO:tensorflow:nll_loss = 47.157063, kl_w = 0.84334546, kl_loss = 8.339349 (38.181 sec)
# INFO:tensorflow:global_step/sec: 2.73312
# INFO:tensorflow:loss = 51.72422, step = 4111 (36.588 sec)
# INFO:tensorflow:nll_loss = 44.643234, kl_w = 0.8641271, kl_loss = 8.194383 (36.588 sec)
# INFO:tensorflow:global_step/sec: 2.9888
# INFO:tensorflow:loss = 51.30763, step = 4211 (33.458 sec)
# INFO:tensorflow:nll_loss = 44.649033, kl_w = 0.88253593, kl_loss = 7.544845 (33.459 sec)
# INFO:tensorflow:global_step/sec: 2.98448
# INFO:tensorflow:loss = 52.997665, step = 4311 (33.506 sec)
# INFO:tensorflow:nll_loss = 46.370667, kl_w = 0.89874285, kl_loss = 7.373631 (33.506 sec)
# INFO:tensorflow:global_step/sec: 2.99303
# INFO:tensorflow:loss = 53.652573, step = 4411 (33.411 sec)
# INFO:tensorflow:nll_loss = 47.153854, kl_w = 0.9129343, kl_loss = 7.118495 (33.411 sec)
# INFO:tensorflow:global_step/sec: 2.98307
# INFO:tensorflow:loss = 55.125595, step = 4511 (33.522 sec)
# INFO:tensorflow:nll_loss = 49.212708, kl_w = 0.92530197, kl_loss = 6.3902254 (33.523 sec)
# INFO:tensorflow:global_step/sec: 2.80644
# INFO:tensorflow:loss = 55.167183, step = 4611 (35.633 sec)
# INFO:tensorflow:nll_loss = 49.612164, kl_w = 0.93603605, kl_loss = 5.934621 (35.633 sec)
# INFO:tensorflow:Saving checkpoints for 4692 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 55.873154.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think i think this is one of the worst movies of the movie <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is a great film that should be seen by any other than that <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4693 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 53.94361, step = 4693
# INFO:tensorflow:nll_loss = 48.52894, kl_w = 0.94374704, kl_loss = 5.7374215
# INFO:tensorflow:global_step/sec: 2.41653
# INFO:tensorflow:loss = 52.79452, step = 4793 (41.383 sec)
# INFO:tensorflow:nll_loss = 46.956726, kl_w = 0.95196813, kl_loss = 6.1323423 (41.383 sec)
# INFO:tensorflow:global_step/sec: 2.64329
# INFO:tensorflow:loss = 47.636368, step = 4893 (37.832 sec)
# INFO:tensorflow:nll_loss = 42.059578, kl_w = 0.9590399, kl_loss = 5.814973 (37.831 sec)
# INFO:tensorflow:global_step/sec: 2.88371
# INFO:tensorflow:loss = 47.890068, step = 4993 (34.677 sec)
# INFO:tensorflow:nll_loss = 42.37507, kl_w = 0.9651086, kl_loss = 5.714381 (34.678 sec)
# INFO:tensorflow:global_step/sec: 2.67658
# INFO:tensorflow:loss = 51.273155, step = 5093 (37.361 sec)
# INFO:tensorflow:nll_loss = 46.035866, kl_w = 0.97030604, kl_loss = 5.3975625 (37.361 sec)
# INFO:tensorflow:global_step/sec: 2.53543
# INFO:tensorflow:loss = 53.911156, step = 5193 (39.441 sec)
# INFO:tensorflow:nll_loss = 48.800926, kl_w = 0.97474945, kl_loss = 5.242606 (39.441 sec)
# INFO:tensorflow:global_step/sec: 2.51611
# INFO:tensorflow:loss = 51.789593, step = 5293 (39.744 sec)
# INFO:tensorflow:nll_loss = 47.533142, kl_w = 0.9785427, kl_loss = 4.349786 (39.744 sec)
# INFO:tensorflow:global_step/sec: 2.49861
# INFO:tensorflow:loss = 52.467224, step = 5393 (40.022 sec)
# INFO:tensorflow:nll_loss = 48.223732, kl_w = 0.9817768, kl_loss = 4.322257 (40.022 sec)
# INFO:tensorflow:Saving checkpoints for 5474 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 56.938663.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i would have to say this movie is a masterpiece of the movie industry <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time and it is not worth watching it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5475 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 50.121258, step = 5475
# INFO:tensorflow:nll_loss = 45.868782, kl_w = 0.98406756, kl_loss = 4.3213234
# INFO:tensorflow:global_step/sec: 2.45145
# INFO:tensorflow:loss = 49.174717, step = 5575 (40.794 sec)
# INFO:tensorflow:nll_loss = 45.288185, kl_w = 0.9864804, kl_loss = 3.9397964 (40.794 sec)
# INFO:tensorflow:global_step/sec: 2.25579
# INFO:tensorflow:loss = 49.580997, step = 5675 (44.330 sec)
# INFO:tensorflow:nll_loss = 45.755054, kl_w = 0.98853207, kl_loss = 3.8703265 (44.330 sec)
# INFO:tensorflow:global_step/sec: 2.68419
# INFO:tensorflow:loss = 51.03319, step = 5775 (37.255 sec)
# INFO:tensorflow:nll_loss = 47.213287, kl_w = 0.9902755, kl_loss = 3.857416 (37.255 sec)
# INFO:tensorflow:global_step/sec: 2.77854
# INFO:tensorflow:loss = 48.852047, step = 5875 (35.990 sec)
# INFO:tensorflow:nll_loss = 44.521133, kl_w = 0.9917561, kl_loss = 4.3669124 (35.990 sec)
# INFO:tensorflow:global_step/sec: 2.75472
# INFO:tensorflow:loss = 47.63391, step = 5975 (36.301 sec)
# INFO:tensorflow:nll_loss = 43.459934, kl_w = 0.99301285, kl_loss = 4.203348 (36.301 sec)
# INFO:tensorflow:global_step/sec: 2.85203
# INFO:tensorflow:loss = 48.74792, step = 6075 (35.063 sec)
# INFO:tensorflow:nll_loss = 44.57513, kl_w = 0.9940791, kl_loss = 4.197644 (35.063 sec)
# INFO:tensorflow:global_step/sec: 2.58202
# INFO:tensorflow:loss = 47.711895, step = 6175 (38.730 sec)
# INFO:tensorflow:nll_loss = 43.768517, kl_w = 0.99498355, kl_loss = 3.9632583 (38.729 sec)
# INFO:tensorflow:Saving checkpoints for 6256 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 51.789867.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think this movie was a great movie i think of the same name <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is one of the worst films i have ever seen i can <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6257 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 48.007046, step = 6257
# INFO:tensorflow:nll_loss = 44.1988, kl_w = 0.9956215, kl_loss = 3.824994
# INFO:tensorflow:global_step/sec: 2.6524
# INFO:tensorflow:loss = 50.01928, step = 6357 (37.703 sec)
# INFO:tensorflow:nll_loss = 46.785606, kl_w = 0.9962913, kl_loss = 3.2457108 (37.703 sec)
# INFO:tensorflow:global_step/sec: 2.80407
# INFO:tensorflow:loss = 49.399162, step = 6457 (35.662 sec)
# INFO:tensorflow:nll_loss = 46.391167, kl_w = 0.99685884, kl_loss = 3.0174732 (35.663 sec)
# INFO:tensorflow:global_step/sec: 2.73847
# INFO:tensorflow:loss = 51.37745, step = 6557 (36.517 sec)
# INFO:tensorflow:nll_loss = 48.260574, kl_w = 0.9973398, kl_loss = 3.1251879 (36.517 sec)
# INFO:tensorflow:global_step/sec: 2.75015
# INFO:tensorflow:loss = 48.929096, step = 6657 (36.362 sec)
# INFO:tensorflow:nll_loss = 45.55645, kl_w = 0.99774724, kl_loss = 3.3802614 (36.362 sec)
# INFO:tensorflow:global_step/sec: 2.70356
# INFO:tensorflow:loss = 46.60707, step = 6757 (36.988 sec)
# INFO:tensorflow:nll_loss = 43.20234, kl_w = 0.99809235, kl_loss = 3.4112394 (36.988 sec)
# INFO:tensorflow:global_step/sec: 2.61918
# INFO:tensorflow:loss = 47.227757, step = 6857 (38.180 sec)
# INFO:tensorflow:nll_loss = 43.79518, kl_w = 0.99838483, kl_loss = 3.4381285 (38.180 sec)
# INFO:tensorflow:global_step/sec: 2.54898
# INFO:tensorflow:loss = 49.141964, step = 6957 (39.231 sec)
# INFO:tensorflow:nll_loss = 45.822403, kl_w = 0.9986324, kl_loss = 3.3241072 (39.231 sec)
# INFO:tensorflow:Saving checkpoints for 7038 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 47.412262.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i thought this movie was the best thing i have ever seen it was <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: i have to admit that i had to add to this movie but it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7039 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:loss = 43.92316, step = 7039
# INFO:tensorflow:nll_loss = 40.546055, kl_w = 0.99880695, kl_loss = 3.3811383
# INFO:tensorflow:global_step/sec: 2.75758
# INFO:tensorflow:loss = 47.367035, step = 7139 (36.265 sec)
# INFO:tensorflow:nll_loss = 44.697754, kl_w = 0.9989899, kl_loss = 2.6719785 (36.264 sec)
# INFO:tensorflow:global_step/sec: 2.71011
# INFO:tensorflow:loss = 46.67629, step = 7239 (36.899 sec)
# INFO:tensorflow:nll_loss = 44.158882, kl_w = 0.9991448, kl_loss = 2.5195627 (36.899 sec)
# INFO:tensorflow:global_step/sec: 2.55041
# INFO:tensorflow:loss = 49.08699, step = 7339 (39.210 sec)
# INFO:tensorflow:nll_loss = 46.70365, kl_w = 0.999276, kl_loss = 2.385067 (39.210 sec)
# INFO:tensorflow:global_step/sec: 2.78327
# INFO:tensorflow:loss = 48.558743, step = 7439 (35.929 sec)
# INFO:tensorflow:nll_loss = 46.014732, kl_w = 0.999387, kl_loss = 2.545569 (35.929 sec)
# INFO:tensorflow:global_step/sec: 2.72908
# INFO:tensorflow:loss = 45.55864, step = 7539 (36.642 sec)
# INFO:tensorflow:nll_loss = 42.59519, kl_w = 0.99948114, kl_loss = 2.9649916 (36.642 sec)
# INFO:tensorflow:global_step/sec: 2.78602
# INFO:tensorflow:loss = 45.781925, step = 7639 (35.894 sec)
# INFO:tensorflow:nll_loss = 42.98141, kl_w = 0.9995608, kl_loss = 2.8017435 (35.894 sec)
# INFO:tensorflow:global_step/sec: 2.94303
# INFO:tensorflow:loss = 45.208084, step = 7739 (33.979 sec)
# INFO:tensorflow:nll_loss = 42.29354, kl_w = 0.9996282, kl_loss = 2.915629 (33.979 sec)
# INFO:tensorflow:Saving checkpoints for 7820 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt.
# INFO:tensorflow:Loss for final step: 47.960526.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmputg9rhga/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this movie in the theater and i was surprised to see this <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is one of the best horror movies ever made it is a good <end>
