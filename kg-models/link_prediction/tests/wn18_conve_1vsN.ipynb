# %% [markdown]
# ![alt text](../utils/conve.png)

# %%
from tqdm import tqdm
import tensorflow as tf
import numpy as np
import sklearn
import pprint
import itertools

import os, sys
sys.path.append(os.path.dirname(os.getcwd()))

from data import WN18

# %%
class Config:
    n_epochs = 70
    batch_size = 128
    embed_dim = 200

# %%
"""
e: entity
s: subject
p: predicate
o: object
"""

def read_triples(path):
    triples = []
    with open(path, 'rt') as f:
        for line in f.readlines():
            s, p, o = line.split()
            triples += [(s.strip(), p.strip(), o.strip())]
    return triples


def load_triple():
    WN18.download()
    triples_tr = read_triples('../data/WN18/wn18/train.txt')
    triples_va = read_triples('../data/WN18/wn18/valid.txt')
    triples_te = read_triples('../data/WN18/wn18/test.txt')
    
    triples_all = triples_tr + triples_va + triples_te
    
    return triples_all, triples_tr, triples_va, triples_te


def build_vocab(triples):
    params = {}
    
    e_set = {s for (s, p, o) in triples} | {o for (s, p, o) in triples}
    p_set = {p for (s, p, o) in triples}

    params['e_vocab_size'] = len(e_set)
    params['p_vocab_size'] = len(p_set)

    e2idx = {e: idx for idx, e in enumerate(sorted(e_set))}
    p2idx = {p: idx for idx, p in enumerate(sorted(p_set))}
    
    return e2idx, p2idx, params


def build_multi_label(triples_tr):
    s2p2o = {}
    for (_s, _p, _o) in triples_tr:
        s, p, o = e2idx[_s], p2idx[_p], e2idx[_o] 
        if s not in s2p2o:
            s2p2o[s] = {p: [o]}
        if p not in s2p2o[s]:
            s2p2o[s][p] = [o]
        if o not in s2p2o[s][p]:
            s2p2o[s][p].append(o)
    return s2p2o


def next_train_batch(triples_tr, e2idx, p2idx, s2p2o):
    for i in range(0, len(triples_tr), Config.batch_size):
        _triples_tr = triples_tr[i : i+Config.batch_size]
        x_s = np.asarray([e2idx[s] for (s, p, o) in _triples_tr], dtype=np.int32)
        x_p = np.asarray([p2idx[p] for (s, p, o) in _triples_tr], dtype=np.int32)
        y = []
        for (_s, _p, _o) in _triples_tr:
            s, p, o = e2idx[_s], p2idx[_p], e2idx[_o] 
            temp = np.zeros([len(e2idx)])
            temp[s2p2o[s][p]] = 1.
            y.append(temp)
        y = np.asarray(y)
        yield x_s, x_p, y


def train_input_fn(triples_tr, e2idx, p2idx, s2p2o):
    dataset = tf.data.Dataset.from_generator(
        lambda: next_train_batch(sklearn.utils.shuffle(triples_tr),
                                 e2idx,
                                 p2idx,
                                 s2p2o),
        (tf.int32, tf.int32, tf.float32),
        (tf.TensorShape([None]),
         tf.TensorShape([None]),
         tf.TensorShape([None, len(e2idx)])))
    iterator = dataset.make_one_shot_iterator()
    x_s, x_p, y = iterator.get_next()
    return {'s': x_s, 'p': x_p}, y

# %%
def o_next_batch(eval_triples,
                 entity_to_idx, 
                 predicate_to_idx):
    for _i, (s, p, o) in enumerate(eval_triples):
        s_idx, p_idx = entity_to_idx[s], predicate_to_idx[p]
        yield np.atleast_1d(s_idx), np.atleast_1d(p_idx)


def o_input_fn(eval_triples,
               entity_to_idx, 
               predicate_to_idx):
    dataset = tf.data.Dataset.from_generator(
        lambda: o_next_batch(eval_triples,
                             entity_to_idx, 
                             predicate_to_idx),
        (tf.int32, tf.int32),
        (tf.TensorShape([None,]),
         tf.TensorShape([None,])))
    iterator = dataset.make_one_shot_iterator()
    s, p = iterator.get_next()
    return {'s': s, 'p': p}


def evaluate_rank(model,
                  valid_triples,
                  test_triples,
                  all_triples,
                  entity_to_idx,
                  predicate_to_idx):

    for eval_name, eval_triples in [('test', test_triples)]:
        _scores_o = list(model.predict(
            lambda: o_input_fn(eval_triples,
                               entity_to_idx, 
                               predicate_to_idx)))

        ScoresO = np.reshape(_scores_o, [len(eval_triples), len(entity_to_idx)])
        ranks_o, filtered_ranks_o = [], []
    
        for _i, ((s, p, o), scores_o) in enumerate(zip(eval_triples, ScoresO)):
            s_idx, p_idx, o_idx = entity_to_idx[s], predicate_to_idx[p], entity_to_idx[o]

            ranks_o += [1 + np.sum(scores_o > scores_o[o_idx])]
            
            filtered_scores_o = scores_o.copy()
            rm_idx_o = [entity_to_idx[fo] for (fs, fp, fo) in all_triples if fs == s and fp == p and fo != o]
            filtered_scores_o[rm_idx_o] = - np.inf
            
            filtered_ranks_o += [1 + np.sum(filtered_scores_o > filtered_scores_o[o_idx])]

        for setting_name, setting_ranks in [('Raw', ranks_o), ('Filtered', filtered_ranks_o)]:
            mean_rank = np.mean(setting_ranks)
            print('[{}] {} Mean Rank: {}'.format(eval_name, setting_name, mean_rank))
            for k in [1, 3, 5, 10]:
                hits_at_k = np.mean(np.asarray(setting_ranks) <= k) * 100
                print('[{}] {} Hits@{}: {}'.format(eval_name, setting_name, k, hits_at_k))

# %%
def alt_concat(x1_x2):
    return tf.concat(x1_x2, 1)


def forward(features, mode, params):
    batch_sz = tf.shape(features['s'])[0]
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    
    e_embed = tf.get_variable('e_embed',
                              [params['e_vocab_size'], Config.embed_dim],
                              initializer=tf.contrib.layers.xavier_initializer())
    p_embed = tf.get_variable('p_embed',
                              [params['p_vocab_size'], Config.embed_dim],
                              initializer=tf.contrib.layers.xavier_initializer())
    
    s = tf.nn.embedding_lookup(e_embed, features['s'])
    p = tf.nn.embedding_lookup(p_embed, features['p'])
    
    x = tf.map_fn(alt_concat, [tf.reshape(s, [10, batch_sz, 20, 1]),
                               tf.reshape(p, [10, batch_sz, 20, 1]),], dtype=tf.float32)
    x = tf.reshape(x, [batch_sz, 20, 20, 1])
    
    x = tf.layers.dropout(x, 0.2, training=is_training)
    x = tf.layers.conv2d(x, 32, (3,3), activation=tf.nn.elu)
    
    x = tf.layers.flatten(x)
    x = tf.layers.dropout(x, 0.5, training=is_training)
    x = tf.layers.dense(x, Config.embed_dim, tf.nn.elu)
    
    logits = tf.matmul(x, e_embed, transpose_b=True)
    return logits
    
    
def model_fn(features, labels, mode, params):
    logits = forward(features, mode, params)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        tf.logging.info('\n'+pprint.pformat(tf.trainable_variables()))
        
        global_step = tf.train.get_global_step()
        
        loss_op = tf.reduce_sum(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits,
                                                                        labels=labels))
        
        lr = {'start': 3e-3, 'end': 8e-4, 'steps': Config.n_epochs * 1100}
        lr_op = tf.train.exponential_decay(lr['start'],
                                           global_step,
                                           lr['steps'],
                                           lr['end']/lr['start'])
        
        train_op = tf.train.AdamOptimizer(lr_op).minimize(loss_op,
                                                          global_step = global_step)
        
        lth = tf.train.LoggingTensorHook({'lr': lr_op,}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(mode = mode,
                                          loss = loss_op,
                                          train_op = train_op,
                                          training_hooks = [lth])
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions = tf.sigmoid(logits))

# %%
triples_all, triples_tr, triples_va, triples_te = load_triple()
e2idx, p2idx, params = build_vocab(triples_all)
s2p2o = build_multi_label(triples_tr)

model = tf.estimator.Estimator(model_fn,
                               model_dir = './ConvE',
                               config = tf.estimator.RunConfig(keep_checkpoint_max=1),
                               params = params)

for n_epoch in range(Config.n_epochs):
    model.train(lambda: train_input_fn(triples_tr, e2idx, p2idx, s2p2o))
    evaluate_rank(model,
                  triples_va,
                  triples_te,
                  triples_all,
                  e2idx,
                  p2idx,)
# Out:
# Files Already Downloaded
# INFO:tensorflow:Using config: {'_model_dir': './ConvE', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 1, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1162ba0f0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 3632580.2, step = 1
# INFO:tensorflow:lr = 0.003
# INFO:tensorflow:global_step/sec: 2.45108
# INFO:tensorflow:loss = 19138.836, step = 101 (40.799 sec)
# INFO:tensorflow:lr = 0.002994855 (40.799 sec)
# INFO:tensorflow:global_step/sec: 2.5016
# INFO:tensorflow:loss = 11970.084, step = 201 (39.974 sec)
# INFO:tensorflow:lr = 0.0029897182 (39.974 sec)
# INFO:tensorflow:global_step/sec: 2.52134
# INFO:tensorflow:loss = 7515.1777, step = 301 (39.661 sec)
# INFO:tensorflow:lr = 0.0029845906 (39.661 sec)
# INFO:tensorflow:global_step/sec: 2.39976
# INFO:tensorflow:loss = 9869.114, step = 401 (41.671 sec)
# INFO:tensorflow:lr = 0.0029794718 (41.671 sec)
# INFO:tensorflow:global_step/sec: 2.43097
# INFO:tensorflow:loss = 6620.976, step = 501 (41.136 sec)
# INFO:tensorflow:lr = 0.0029743616 (41.136 sec)
# INFO:tensorflow:global_step/sec: 2.44526
# INFO:tensorflow:loss = 7082.0483, step = 601 (40.895 sec)
# INFO:tensorflow:lr = 0.0029692606 (40.895 sec)
# INFO:tensorflow:global_step/sec: 2.47775
# INFO:tensorflow:loss = 6250.7397, step = 701 (40.359 sec)
# INFO:tensorflow:lr = 0.0029641679 (40.359 sec)
# INFO:tensorflow:global_step/sec: 2.57387
# INFO:tensorflow:loss = 5953.5923, step = 801 (38.852 sec)
# INFO:tensorflow:lr = 0.002959084 (38.852 sec)
# INFO:tensorflow:global_step/sec: 2.39013
# INFO:tensorflow:loss = 6093.35, step = 901 (41.839 sec)
# INFO:tensorflow:lr = 0.002954009 (41.839 sec)
# INFO:tensorflow:global_step/sec: 2.40156
# INFO:tensorflow:loss = 4709.2686, step = 1001 (41.640 sec)
# INFO:tensorflow:lr = 0.0029489426 (41.639 sec)
# INFO:tensorflow:global_step/sec: 2.53685
# INFO:tensorflow:loss = 4087.0962, step = 1101 (39.419 sec)
# INFO:tensorflow:lr = 0.0029438848 (39.419 sec)
# INFO:tensorflow:Saving checkpoints for 1106 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 43.491028.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-1106
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 13603.094
# [test] Raw Hits@1: 2.1
# [test] Raw Hits@3: 3.7800000000000002
# [test] Raw Hits@5: 4.82
# [test] Raw Hits@10: 5.72
# [test] Filtered Mean Rank: 13587.4162
# [test] Filtered Hits@1: 2.26
# [test] Filtered Hits@3: 3.94
# [test] Filtered Hits@5: 4.9399999999999995
# [test] Filtered Hits@10: 5.800000000000001
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-1106
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1107 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 4694.419, step = 1107
# INFO:tensorflow:lr = 0.0029435814
# INFO:tensorflow:global_step/sec: 2.51346
# INFO:tensorflow:loss = 3531.7393, step = 1207 (39.787 sec)
# INFO:tensorflow:lr = 0.0029385332 (39.787 sec)
# INFO:tensorflow:global_step/sec: 2.47375
# INFO:tensorflow:loss = 3593.7559, step = 1307 (40.425 sec)
# INFO:tensorflow:lr = 0.0029334931 (40.425 sec)
# INFO:tensorflow:global_step/sec: 2.43579
# INFO:tensorflow:loss = 3375.1443, step = 1407 (41.055 sec)
# INFO:tensorflow:lr = 0.0029284619 (41.055 sec)
# INFO:tensorflow:global_step/sec: 2.52777
# INFO:tensorflow:loss = 3443.2803, step = 1507 (39.560 sec)
# INFO:tensorflow:lr = 0.0029234395 (39.560 sec)
# INFO:tensorflow:global_step/sec: 2.53005
# INFO:tensorflow:loss = 3082.883, step = 1607 (39.525 sec)
# INFO:tensorflow:lr = 0.0029184255 (39.525 sec)
# INFO:tensorflow:global_step/sec: 2.55847
# INFO:tensorflow:loss = 2991.1758, step = 1707 (39.086 sec)
# INFO:tensorflow:lr = 0.00291342 (39.086 sec)
# INFO:tensorflow:global_step/sec: 2.43714
# INFO:tensorflow:loss = 3240.8025, step = 1807 (41.032 sec)
# INFO:tensorflow:lr = 0.0029084233 (41.032 sec)
# INFO:tensorflow:global_step/sec: 2.4844
# INFO:tensorflow:loss = 2905.8684, step = 1907 (40.251 sec)
# INFO:tensorflow:lr = 0.0029034351 (40.251 sec)
# INFO:tensorflow:global_step/sec: 2.42901
# INFO:tensorflow:loss = 2342.1167, step = 2007 (41.169 sec)
# INFO:tensorflow:lr = 0.0028984554 (41.169 sec)
# INFO:tensorflow:global_step/sec: 2.52882
# INFO:tensorflow:loss = 2981.0293, step = 2107 (39.544 sec)
# INFO:tensorflow:lr = 0.0028934844 (39.544 sec)
# INFO:tensorflow:global_step/sec: 2.53409
# INFO:tensorflow:loss = 2478.7026, step = 2207 (39.462 sec)
# INFO:tensorflow:lr = 0.0028885216 (39.462 sec)
# INFO:tensorflow:Saving checkpoints for 2212 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 96.18264.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-2212
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 7339.1688
# [test] Raw Hits@1: 10.14
# [test] Raw Hits@3: 12.5
# [test] Raw Hits@5: 13.52
# [test] Raw Hits@10: 15.260000000000002
# [test] Filtered Mean Rank: 7323.2852
# [test] Filtered Hits@1: 10.5
# [test] Filtered Hits@3: 12.72
# [test] Filtered Hits@5: 13.900000000000002
# [test] Filtered Hits@10: 15.6
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-2212
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2213 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 2005.5598, step = 2213
# INFO:tensorflow:lr = 0.002888224
# INFO:tensorflow:global_step/sec: 2.51049
# INFO:tensorflow:loss = 1711.5111, step = 2313 (39.834 sec)
# INFO:tensorflow:lr = 0.0028832706 (39.834 sec)
# INFO:tensorflow:global_step/sec: 2.49556
# INFO:tensorflow:loss = 2095.296, step = 2413 (40.071 sec)
# INFO:tensorflow:lr = 0.0028783255 (40.071 sec)
# INFO:tensorflow:global_step/sec: 2.50688
# INFO:tensorflow:loss = 1940.656, step = 2513 (39.890 sec)
# INFO:tensorflow:lr = 0.002873389 (39.890 sec)
# INFO:tensorflow:global_step/sec: 2.44534
# INFO:tensorflow:loss = 2254.8508, step = 2613 (40.894 sec)
# INFO:tensorflow:lr = 0.002868461 (40.894 sec)
# INFO:tensorflow:global_step/sec: 2.46283
# INFO:tensorflow:loss = 1645.2058, step = 2713 (40.604 sec)
# INFO:tensorflow:lr = 0.0028635412 (40.603 sec)
# INFO:tensorflow:global_step/sec: 2.43861
# INFO:tensorflow:loss = 1773.3077, step = 2813 (41.007 sec)
# INFO:tensorflow:lr = 0.00285863 (41.008 sec)
# INFO:tensorflow:global_step/sec: 2.48947
# INFO:tensorflow:loss = 1790.2424, step = 2913 (40.169 sec)
# INFO:tensorflow:lr = 0.0028537272 (40.169 sec)
# INFO:tensorflow:global_step/sec: 2.51159
# INFO:tensorflow:loss = 1613.5806, step = 3013 (39.815 sec)
# INFO:tensorflow:lr = 0.0028488326 (39.815 sec)
# INFO:tensorflow:global_step/sec: 2.49576
# INFO:tensorflow:loss = 1339.8951, step = 3113 (40.069 sec)
# INFO:tensorflow:lr = 0.0028439467 (40.069 sec)
# INFO:tensorflow:global_step/sec: 2.39696
# INFO:tensorflow:loss = 1446.3441, step = 3213 (41.719 sec)
# INFO:tensorflow:lr = 0.002839069 (41.719 sec)
# INFO:tensorflow:global_step/sec: 2.43242
# INFO:tensorflow:loss = 1470.4309, step = 3313 (41.110 sec)
# INFO:tensorflow:lr = 0.0028341997 (41.110 sec)
# INFO:tensorflow:Saving checkpoints for 3318 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.3976793.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-3318
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 3872.8006
# [test] Raw Hits@1: 14.540000000000001
# [test] Raw Hits@3: 18.6
# [test] Raw Hits@5: 20.46
# [test] Raw Hits@10: 22.88
# [test] Filtered Mean Rank: 3856.8558
# [test] Filtered Hits@1: 15.7
# [test] Filtered Hits@3: 19.32
# [test] Filtered Hits@5: 21.240000000000002
# [test] Filtered Hits@10: 23.7
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-3318
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3319 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 1287.9447, step = 3319
# INFO:tensorflow:lr = 0.0028339077
# INFO:tensorflow:global_step/sec: 2.38114
# INFO:tensorflow:loss = 1073.3326, step = 3419 (41.998 sec)
# INFO:tensorflow:lr = 0.0028290474 (41.998 sec)
# INFO:tensorflow:global_step/sec: 2.42305
# INFO:tensorflow:loss = 1595.7488, step = 3519 (41.270 sec)
# INFO:tensorflow:lr = 0.0028241954 (41.270 sec)
# INFO:tensorflow:global_step/sec: 2.49973
# INFO:tensorflow:loss = 1022.49023, step = 3619 (40.005 sec)
# INFO:tensorflow:lr = 0.0028193516 (40.005 sec)
# INFO:tensorflow:global_step/sec: 2.47534
# INFO:tensorflow:loss = 979.51776, step = 3719 (40.398 sec)
# INFO:tensorflow:lr = 0.0028145162 (40.398 sec)
# INFO:tensorflow:global_step/sec: 2.45086
# INFO:tensorflow:loss = 1086.0248, step = 3819 (40.802 sec)
# INFO:tensorflow:lr = 0.0028096891 (40.802 sec)
# INFO:tensorflow:global_step/sec: 2.51627
# INFO:tensorflow:loss = 991.1798, step = 3919 (39.741 sec)
# INFO:tensorflow:lr = 0.0028048703 (39.741 sec)
# INFO:tensorflow:global_step/sec: 2.48367
# INFO:tensorflow:loss = 886.9885, step = 4019 (40.263 sec)
# INFO:tensorflow:lr = 0.0028000595 (40.263 sec)
# INFO:tensorflow:global_step/sec: 2.46715
# INFO:tensorflow:loss = 962.83716, step = 4119 (40.533 sec)
# INFO:tensorflow:lr = 0.0027952571 (40.532 sec)
# INFO:tensorflow:global_step/sec: 2.44211
# INFO:tensorflow:loss = 988.5431, step = 4219 (40.948 sec)
# INFO:tensorflow:lr = 0.002790463 (40.948 sec)
# INFO:tensorflow:global_step/sec: 2.37909
# INFO:tensorflow:loss = 868.06256, step = 4319 (42.033 sec)
# INFO:tensorflow:lr = 0.002785677 (42.033 sec)
# INFO:tensorflow:global_step/sec: 2.34689
# INFO:tensorflow:loss = 920.0078, step = 4419 (42.609 sec)
# INFO:tensorflow:lr = 0.0027808994 (42.609 sec)
# INFO:tensorflow:Saving checkpoints for 4424 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.9989595.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-4424
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 2385.3516
# [test] Raw Hits@1: 16.919999999999998
# [test] Raw Hits@3: 22.14
# [test] Raw Hits@5: 24.7
# [test] Raw Hits@10: 28.34
# [test] Filtered Mean Rank: 2369.3814
# [test] Filtered Hits@1: 18.88
# [test] Filtered Hits@3: 23.28
# [test] Filtered Hits@5: 25.759999999999998
# [test] Filtered Hits@10: 29.38
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-4424
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4425 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 685.4049, step = 4425
# INFO:tensorflow:lr = 0.002780613
# INFO:tensorflow:global_step/sec: 2.20895
# INFO:tensorflow:loss = 748.9159, step = 4525 (45.271 sec)
# INFO:tensorflow:lr = 0.002775844 (45.271 sec)
# INFO:tensorflow:global_step/sec: 2.33507
# INFO:tensorflow:loss = 795.2369, step = 4625 (42.825 sec)
# INFO:tensorflow:lr = 0.002771083 (42.825 sec)
# INFO:tensorflow:global_step/sec: 2.39746
# INFO:tensorflow:loss = 799.9131, step = 4725 (41.712 sec)
# INFO:tensorflow:lr = 0.0027663305 (41.713 sec)
# INFO:tensorflow:global_step/sec: 2.45787
# INFO:tensorflow:loss = 729.86053, step = 4825 (40.685 sec)
# INFO:tensorflow:lr = 0.0027615859 (40.685 sec)
# INFO:tensorflow:global_step/sec: 2.62803
# INFO:tensorflow:loss = 655.7368, step = 4925 (38.050 sec)
# INFO:tensorflow:lr = 0.0027568496 (38.050 sec)
# INFO:tensorflow:global_step/sec: 2.62739
# INFO:tensorflow:loss = 825.91986, step = 5025 (38.061 sec)
# INFO:tensorflow:lr = 0.0027521213 (38.060 sec)
# INFO:tensorflow:global_step/sec: 2.56979
# INFO:tensorflow:loss = 734.35156, step = 5125 (38.914 sec)
# INFO:tensorflow:lr = 0.0027474011 (38.914 sec)
# INFO:tensorflow:global_step/sec: 2.41769
# INFO:tensorflow:loss = 786.4298, step = 5225 (41.362 sec)
# INFO:tensorflow:lr = 0.002742689 (41.362 sec)
# INFO:tensorflow:global_step/sec: 2.41436
# INFO:tensorflow:loss = 643.875, step = 5325 (41.419 sec)
# INFO:tensorflow:lr = 0.0027379852 (41.419 sec)
# INFO:tensorflow:global_step/sec: 2.39419
# INFO:tensorflow:loss = 668.4885, step = 5425 (41.768 sec)
# INFO:tensorflow:lr = 0.0027332895 (41.768 sec)
# INFO:tensorflow:global_step/sec: 2.366
# INFO:tensorflow:loss = 708.2528, step = 5525 (42.265 sec)
# INFO:tensorflow:lr = 0.0027286015 (42.265 sec)
# INFO:tensorflow:Saving checkpoints for 5530 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 12.399934.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-5530
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 1687.5504
# [test] Raw Hits@1: 18.54
# [test] Raw Hits@3: 26.22
# [test] Raw Hits@5: 29.580000000000002
# [test] Raw Hits@10: 34.68
# [test] Filtered Mean Rank: 1671.5386
# [test] Filtered Hits@1: 21.279999999999998
# [test] Filtered Hits@3: 28.24
# [test] Filtered Hits@5: 31.5
# [test] Filtered Hits@10: 36.559999999999995
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-5530
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5531 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 633.02167, step = 5531
# INFO:tensorflow:lr = 0.0027283204
# INFO:tensorflow:global_step/sec: 2.49319
# INFO:tensorflow:loss = 582.7348, step = 5631 (40.111 sec)
# INFO:tensorflow:lr = 0.0027236412 (40.110 sec)
# INFO:tensorflow:global_step/sec: 2.36698
# INFO:tensorflow:loss = 524.49225, step = 5731 (42.248 sec)
# INFO:tensorflow:lr = 0.0027189697 (42.248 sec)
# INFO:tensorflow:global_step/sec: 2.47879
# INFO:tensorflow:loss = 437.7215, step = 5831 (40.342 sec)
# INFO:tensorflow:lr = 0.0027143066 (40.342 sec)
# INFO:tensorflow:global_step/sec: 2.41099
# INFO:tensorflow:loss = 549.6943, step = 5931 (41.477 sec)
# INFO:tensorflow:lr = 0.0027096514 (41.477 sec)
# INFO:tensorflow:global_step/sec: 2.54454
# INFO:tensorflow:loss = 592.3411, step = 6031 (39.300 sec)
# INFO:tensorflow:lr = 0.0027050038 (39.300 sec)
# INFO:tensorflow:global_step/sec: 2.3775
# INFO:tensorflow:loss = 485.65805, step = 6131 (42.061 sec)
# INFO:tensorflow:lr = 0.0027003644 (42.061 sec)
# INFO:tensorflow:global_step/sec: 2.38882
# INFO:tensorflow:loss = 556.9731, step = 6231 (41.862 sec)
# INFO:tensorflow:lr = 0.0026957332 (41.862 sec)
# INFO:tensorflow:global_step/sec: 2.4132
# INFO:tensorflow:loss = 666.74036, step = 6331 (41.439 sec)
# INFO:tensorflow:lr = 0.00269111 (41.439 sec)
# INFO:tensorflow:global_step/sec: 2.37051
# INFO:tensorflow:loss = 541.0228, step = 6431 (42.185 sec)
# INFO:tensorflow:lr = 0.0026864943 (42.185 sec)
# INFO:tensorflow:global_step/sec: 2.3481
# INFO:tensorflow:loss = 635.68365, step = 6531 (42.587 sec)
# INFO:tensorflow:lr = 0.0026818865 (42.588 sec)
# INFO:tensorflow:global_step/sec: 2.30501
# INFO:tensorflow:loss = 496.05606, step = 6631 (43.384 sec)
# INFO:tensorflow:lr = 0.002677287 (43.384 sec)
# INFO:tensorflow:Saving checkpoints for 6636 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.6747546.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-6636
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 1244.4464
# [test] Raw Hits@1: 20.06
# [test] Raw Hits@3: 28.62
# [test] Raw Hits@5: 32.82
# [test] Raw Hits@10: 38.46
# [test] Filtered Mean Rank: 1228.4344
# [test] Filtered Hits@1: 23.599999999999998
# [test] Filtered Hits@3: 31.36
# [test] Filtered Hits@5: 35.14
# [test] Filtered Hits@10: 40.46
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-6636
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6637 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 383.41153, step = 6637
# INFO:tensorflow:lr = 0.0026770113
# INFO:tensorflow:global_step/sec: 2.29639
# INFO:tensorflow:loss = 363.6444, step = 6737 (43.548 sec)
# INFO:tensorflow:lr = 0.0026724199 (43.548 sec)
# INFO:tensorflow:global_step/sec: 2.44735
# INFO:tensorflow:loss = 418.88715, step = 6837 (40.860 sec)
# INFO:tensorflow:lr = 0.0026678366 (40.860 sec)
# INFO:tensorflow:global_step/sec: 2.48911
# INFO:tensorflow:loss = 488.6551, step = 6937 (40.175 sec)
# INFO:tensorflow:lr = 0.0026632608 (40.175 sec)
# INFO:tensorflow:global_step/sec: 2.49008
# INFO:tensorflow:loss = 505.24628, step = 7037 (40.159 sec)
# INFO:tensorflow:lr = 0.0026586931 (40.159 sec)
# INFO:tensorflow:global_step/sec: 2.41789
# INFO:tensorflow:loss = 386.32645, step = 7137 (41.358 sec)
# INFO:tensorflow:lr = 0.0026541334 (41.359 sec)
# INFO:tensorflow:global_step/sec: 2.42206
# INFO:tensorflow:loss = 385.61725, step = 7237 (41.287 sec)
# INFO:tensorflow:lr = 0.0026495813 (41.287 sec)
# INFO:tensorflow:global_step/sec: 2.42393
# INFO:tensorflow:loss = 414.38147, step = 7337 (41.255 sec)
# INFO:tensorflow:lr = 0.002645037 (41.255 sec)
# INFO:tensorflow:global_step/sec: 2.41793
# INFO:tensorflow:loss = 431.54657, step = 7437 (41.358 sec)
# INFO:tensorflow:lr = 0.0026405004 (41.358 sec)
# INFO:tensorflow:global_step/sec: 2.34929
# INFO:tensorflow:loss = 493.13504, step = 7537 (42.566 sec)
# INFO:tensorflow:lr = 0.0026359716 (42.566 sec)
# INFO:tensorflow:global_step/sec: 2.45002
# INFO:tensorflow:loss = 421.00378, step = 7637 (40.816 sec)
# INFO:tensorflow:lr = 0.0026314508 (40.816 sec)
# INFO:tensorflow:global_step/sec: 2.50249
# INFO:tensorflow:loss = 516.82697, step = 7737 (39.960 sec)
# INFO:tensorflow:lr = 0.0026269376 (39.960 sec)
# INFO:tensorflow:Saving checkpoints for 7742 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.5749636.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-7742
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 1014.2284
# [test] Raw Hits@1: 21.12
# [test] Raw Hits@3: 31.180000000000003
# [test] Raw Hits@5: 35.96
# [test] Raw Hits@10: 42.72
# [test] Filtered Mean Rank: 998.206
# [test] Filtered Hits@1: 25.040000000000003
# [test] Filtered Hits@3: 34.18
# [test] Filtered Hits@5: 39.2
# [test] Filtered Hits@10: 44.84
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-7742
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7743 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 277.07428, step = 7743
# INFO:tensorflow:lr = 0.002626667
# INFO:tensorflow:global_step/sec: 2.40158
# INFO:tensorflow:loss = 273.40787, step = 7843 (41.640 sec)
# INFO:tensorflow:lr = 0.002622162 (41.640 sec)
# INFO:tensorflow:global_step/sec: 2.34608
# INFO:tensorflow:loss = 300.67004, step = 7943 (42.624 sec)
# INFO:tensorflow:lr = 0.0026176649 (42.624 sec)
# INFO:tensorflow:global_step/sec: 2.41599
# INFO:tensorflow:loss = 315.93253, step = 8043 (41.391 sec)
# INFO:tensorflow:lr = 0.0026131752 (41.391 sec)
# INFO:tensorflow:global_step/sec: 2.40046
# INFO:tensorflow:loss = 286.4155, step = 8143 (41.659 sec)
# INFO:tensorflow:lr = 0.0026086934 (41.659 sec)
# INFO:tensorflow:global_step/sec: 2.35584
# INFO:tensorflow:loss = 311.31458, step = 8243 (42.448 sec)
# INFO:tensorflow:lr = 0.0026042194 (42.448 sec)
# INFO:tensorflow:global_step/sec: 2.46814
# INFO:tensorflow:loss = 375.1265, step = 8343 (40.516 sec)
# INFO:tensorflow:lr = 0.0025997527 (40.516 sec)
# INFO:tensorflow:global_step/sec: 2.36986
# INFO:tensorflow:loss = 370.90076, step = 8443 (42.197 sec)
# INFO:tensorflow:lr = 0.002595294 (42.197 sec)
# INFO:tensorflow:global_step/sec: 2.43223
# INFO:tensorflow:loss = 344.85114, step = 8543 (41.114 sec)
# INFO:tensorflow:lr = 0.0025908428 (41.114 sec)
# INFO:tensorflow:global_step/sec: 2.43558
# INFO:tensorflow:loss = 327.53958, step = 8643 (41.058 sec)
# INFO:tensorflow:lr = 0.0025863992 (41.058 sec)
# INFO:tensorflow:global_step/sec: 2.39561
# INFO:tensorflow:loss = 316.8403, step = 8743 (41.743 sec)
# INFO:tensorflow:lr = 0.0025819635 (41.743 sec)
# INFO:tensorflow:global_step/sec: 2.4166
# INFO:tensorflow:loss = 361.2926, step = 8843 (41.380 sec)
# INFO:tensorflow:lr = 0.002577535 (41.380 sec)
# INFO:tensorflow:Saving checkpoints for 8848 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.5932164.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-8848
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 875.645
# [test] Raw Hits@1: 22.5
# [test] Raw Hits@3: 33.42
# [test] Raw Hits@5: 38.879999999999995
# [test] Raw Hits@10: 45.92
# [test] Filtered Mean Rank: 859.6202
# [test] Filtered Hits@1: 26.840000000000003
# [test] Filtered Hits@3: 37.38
# [test] Filtered Hits@5: 42.22
# [test] Filtered Hits@10: 49.18
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-8848
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 8849 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 252.83313, step = 8849
# INFO:tensorflow:lr = 0.0025772697
# INFO:tensorflow:global_step/sec: 2.40224
# INFO:tensorflow:loss = 198.87656, step = 8949 (41.629 sec)
# INFO:tensorflow:lr = 0.0025728494 (41.629 sec)
# INFO:tensorflow:global_step/sec: 2.47769
# INFO:tensorflow:loss = 291.15607, step = 9049 (40.360 sec)
# INFO:tensorflow:lr = 0.0025684368 (40.360 sec)
# INFO:tensorflow:global_step/sec: 2.43173
# INFO:tensorflow:loss = 278.4416, step = 9149 (41.123 sec)
# INFO:tensorflow:lr = 0.0025640314 (41.123 sec)
# INFO:tensorflow:global_step/sec: 2.41366
# INFO:tensorflow:loss = 254.30644, step = 9249 (41.431 sec)
# INFO:tensorflow:lr = 0.0025596342 (41.431 sec)
# INFO:tensorflow:global_step/sec: 2.43742
# INFO:tensorflow:loss = 311.65125, step = 9349 (41.030 sec)
# INFO:tensorflow:lr = 0.002555244 (41.030 sec)
# INFO:tensorflow:global_step/sec: 2.45352
# INFO:tensorflow:loss = 345.474, step = 9449 (40.755 sec)
# INFO:tensorflow:lr = 0.0025508613 (40.755 sec)
# INFO:tensorflow:global_step/sec: 2.40713
# INFO:tensorflow:loss = 281.5777, step = 9549 (41.543 sec)
# INFO:tensorflow:lr = 0.0025464867 (41.543 sec)
# INFO:tensorflow:global_step/sec: 2.36018
# INFO:tensorflow:loss = 262.5926, step = 9649 (42.370 sec)
# INFO:tensorflow:lr = 0.002542119 (42.370 sec)
# INFO:tensorflow:global_step/sec: 2.29485
# INFO:tensorflow:loss = 273.75146, step = 9749 (43.576 sec)
# INFO:tensorflow:lr = 0.002537759 (43.576 sec)
# INFO:tensorflow:global_step/sec: 2.30649
# INFO:tensorflow:loss = 294.19138, step = 9849 (43.356 sec)
# INFO:tensorflow:lr = 0.0025334067 (43.356 sec)
# INFO:tensorflow:global_step/sec: 2.4094
# INFO:tensorflow:loss = 318.43884, step = 9949 (41.504 sec)
# INFO:tensorflow:lr = 0.0025290616 (41.504 sec)
# INFO:tensorflow:Saving checkpoints for 9954 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.9221904.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-9954
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 771.5756
# [test] Raw Hits@1: 22.900000000000002
# [test] Raw Hits@3: 34.9
# [test] Raw Hits@5: 40.6
# [test] Raw Hits@10: 47.760000000000005
# [test] Filtered Mean Rank: 755.5234
# [test] Filtered Hits@1: 27.860000000000003
# [test] Filtered Hits@3: 38.84
# [test] Filtered Hits@5: 44.72
# [test] Filtered Hits@10: 50.46000000000001
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-9954
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9955 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 172.78088, step = 9955
# INFO:tensorflow:lr = 0.002528801
# INFO:tensorflow:global_step/sec: 2.56035
# INFO:tensorflow:loss = 234.6776, step = 10055 (39.058 sec)
# INFO:tensorflow:lr = 0.002524464 (39.058 sec)
# INFO:tensorflow:global_step/sec: 2.3108
# INFO:tensorflow:loss = 186.88411, step = 10155 (43.275 sec)
# INFO:tensorflow:lr = 0.0025201342 (43.275 sec)
# INFO:tensorflow:global_step/sec: 2.34834
# INFO:tensorflow:loss = 174.87325, step = 10255 (42.583 sec)
# INFO:tensorflow:lr = 0.002515812 (42.584 sec)
# INFO:tensorflow:global_step/sec: 2.43254
# INFO:tensorflow:loss = 226.82605, step = 10355 (41.109 sec)
# INFO:tensorflow:lr = 0.0025114971 (41.109 sec)
# INFO:tensorflow:global_step/sec: 2.51422
# INFO:tensorflow:loss = 260.49866, step = 10455 (39.774 sec)
# INFO:tensorflow:lr = 0.0025071898 (39.774 sec)
# INFO:tensorflow:global_step/sec: 2.47211
# INFO:tensorflow:loss = 247.65085, step = 10555 (40.451 sec)
# INFO:tensorflow:lr = 0.0025028896 (40.451 sec)
# INFO:tensorflow:global_step/sec: 2.54594
# INFO:tensorflow:loss = 228.49867, step = 10655 (39.278 sec)
# INFO:tensorflow:lr = 0.002498597 (39.278 sec)
# INFO:tensorflow:global_step/sec: 2.43729
# INFO:tensorflow:loss = 222.5542, step = 10755 (41.029 sec)
# INFO:tensorflow:lr = 0.0024943117 (41.030 sec)
# INFO:tensorflow:global_step/sec: 2.51098
# INFO:tensorflow:loss = 206.13487, step = 10855 (39.825 sec)
# INFO:tensorflow:lr = 0.0024900336 (39.825 sec)
# INFO:tensorflow:global_step/sec: 2.56578
# INFO:tensorflow:loss = 298.48694, step = 10955 (38.975 sec)
# INFO:tensorflow:lr = 0.002485763 (38.974 sec)
# INFO:tensorflow:global_step/sec: 2.48102
# INFO:tensorflow:loss = 278.48718, step = 11055 (40.306 sec)
# INFO:tensorflow:lr = 0.0024814997 (40.307 sec)
# INFO:tensorflow:Saving checkpoints for 11060 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.8764467.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-11060
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 747.6386
# [test] Raw Hits@1: 23.82
# [test] Raw Hits@3: 35.38
# [test] Raw Hits@5: 41.24
# [test] Raw Hits@10: 48.42
# [test] Filtered Mean Rank: 731.5842
# [test] Filtered Hits@1: 29.080000000000002
# [test] Filtered Hits@3: 40.300000000000004
# [test] Filtered Hits@5: 45.04
# [test] Filtered Hits@10: 51.25999999999999
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-11060
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 11061 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 196.42267, step = 11061
# INFO:tensorflow:lr = 0.0024812443
# INFO:tensorflow:global_step/sec: 2.32198
# INFO:tensorflow:loss = 180.58589, step = 11161 (43.068 sec)
# INFO:tensorflow:lr = 0.0024769886 (43.067 sec)
# INFO:tensorflow:global_step/sec: 2.28157
# INFO:tensorflow:loss = 167.3472, step = 11261 (43.829 sec)
# INFO:tensorflow:lr = 0.0024727404 (43.830 sec)
# INFO:tensorflow:global_step/sec: 2.43614
# INFO:tensorflow:loss = 170.1587, step = 11361 (41.049 sec)
# INFO:tensorflow:lr = 0.0024684994 (41.049 sec)
# INFO:tensorflow:global_step/sec: 2.36342
# INFO:tensorflow:loss = 258.04752, step = 11461 (42.311 sec)
# INFO:tensorflow:lr = 0.0024642656 (42.311 sec)
# INFO:tensorflow:global_step/sec: 2.60736
# INFO:tensorflow:loss = 145.16351, step = 11561 (38.353 sec)
# INFO:tensorflow:lr = 0.0024600392 (38.353 sec)
# INFO:tensorflow:global_step/sec: 2.36576
# INFO:tensorflow:loss = 179.62177, step = 11661 (42.270 sec)
# INFO:tensorflow:lr = 0.0024558199 (42.270 sec)
# INFO:tensorflow:global_step/sec: 2.33404
# INFO:tensorflow:loss = 175.24794, step = 11761 (42.844 sec)
# INFO:tensorflow:lr = 0.0024516082 (42.844 sec)
# INFO:tensorflow:global_step/sec: 2.40882
# INFO:tensorflow:loss = 270.34464, step = 11861 (41.514 sec)
# INFO:tensorflow:lr = 0.0024474033 (41.514 sec)
# INFO:tensorflow:global_step/sec: 2.31694
# INFO:tensorflow:loss = 251.18535, step = 11961 (43.160 sec)
# INFO:tensorflow:lr = 0.0024432058 (43.160 sec)
# INFO:tensorflow:global_step/sec: 2.30846
# INFO:tensorflow:loss = 222.53421, step = 12061 (43.319 sec)
# INFO:tensorflow:lr = 0.0024390155 (43.319 sec)
# INFO:tensorflow:global_step/sec: 2.32478
# INFO:tensorflow:loss = 153.58418, step = 12161 (43.014 sec)
# INFO:tensorflow:lr = 0.0024348323 (43.014 sec)
# INFO:tensorflow:Saving checkpoints for 12166 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.7479689.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-12166
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 721.1682
# [test] Raw Hits@1: 23.919999999999998
# [test] Raw Hits@3: 36.94
# [test] Raw Hits@5: 42.699999999999996
# [test] Raw Hits@10: 50.12
# [test] Filtered Mean Rank: 705.1164
# [test] Filtered Hits@1: 29.599999999999998
# [test] Filtered Hits@3: 41.58
# [test] Filtered Hits@5: 46.86
# [test] Filtered Hits@10: 53.400000000000006
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-12166
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 12167 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 176.25966, step = 12167
# INFO:tensorflow:lr = 0.0024345815
# INFO:tensorflow:global_step/sec: 2.35864
# INFO:tensorflow:loss = 153.42838, step = 12267 (42.398 sec)
# INFO:tensorflow:lr = 0.002430406 (42.398 sec)
# INFO:tensorflow:global_step/sec: 2.39396
# INFO:tensorflow:loss = 131.09363, step = 12367 (41.772 sec)
# INFO:tensorflow:lr = 0.0024262376 (41.772 sec)
# INFO:tensorflow:global_step/sec: 2.41681
# INFO:tensorflow:loss = 168.36195, step = 12467 (41.377 sec)
# INFO:tensorflow:lr = 0.0024220764 (41.377 sec)
# INFO:tensorflow:global_step/sec: 2.37449
# INFO:tensorflow:loss = 119.763535, step = 12567 (42.114 sec)
# INFO:tensorflow:lr = 0.0024179223 (42.114 sec)
# INFO:tensorflow:global_step/sec: 2.36228
# INFO:tensorflow:loss = 169.70973, step = 12667 (42.332 sec)
# INFO:tensorflow:lr = 0.0024137753 (42.332 sec)
# INFO:tensorflow:global_step/sec: 2.40848
# INFO:tensorflow:loss = 149.13919, step = 12767 (41.520 sec)
# INFO:tensorflow:lr = 0.0024096353 (41.519 sec)
# INFO:tensorflow:global_step/sec: 2.41196
# INFO:tensorflow:loss = 180.62424, step = 12867 (41.460 sec)
# INFO:tensorflow:lr = 0.0024055026 (41.460 sec)
# INFO:tensorflow:global_step/sec: 2.39191
# INFO:tensorflow:loss = 295.43723, step = 12967 (41.807 sec)
# INFO:tensorflow:lr = 0.002401377 (41.807 sec)
# INFO:tensorflow:global_step/sec: 2.30388
# INFO:tensorflow:loss = 225.01158, step = 13067 (43.405 sec)
# INFO:tensorflow:lr = 0.0023972585 (43.405 sec)
# INFO:tensorflow:global_step/sec: 2.48815
# INFO:tensorflow:loss = 131.86105, step = 13167 (40.190 sec)
# INFO:tensorflow:lr = 0.002393147 (40.191 sec)
# INFO:tensorflow:global_step/sec: 2.53513
# INFO:tensorflow:loss = 175.79404, step = 13267 (39.447 sec)
# INFO:tensorflow:lr = 0.0023890424 (39.447 sec)
# INFO:tensorflow:Saving checkpoints for 13272 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.4440184.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-13272
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 701.73
# [test] Raw Hits@1: 25.44
# [test] Raw Hits@3: 38.66
# [test] Raw Hits@5: 43.68
# [test] Raw Hits@10: 51.25999999999999
# [test] Filtered Mean Rank: 685.6996
# [test] Filtered Hits@1: 31.5
# [test] Filtered Hits@3: 43.34
# [test] Filtered Hits@5: 47.94
# [test] Filtered Hits@10: 54.459999999999994
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-13272
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 13273 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 98.7788, step = 13273
# INFO:tensorflow:lr = 0.0023887965
# INFO:tensorflow:global_step/sec: 2.45849
# INFO:tensorflow:loss = 128.74889, step = 13373 (40.676 sec)
# INFO:tensorflow:lr = 0.0023846994 (40.676 sec)
# INFO:tensorflow:global_step/sec: 2.37118
# INFO:tensorflow:loss = 171.28537, step = 13473 (42.173 sec)
# INFO:tensorflow:lr = 0.0023806095 (42.173 sec)
# INFO:tensorflow:global_step/sec: 2.32042
# INFO:tensorflow:loss = 432.51044, step = 13573 (43.096 sec)
# INFO:tensorflow:lr = 0.0023765264 (43.096 sec)
# INFO:tensorflow:global_step/sec: 2.31575
# INFO:tensorflow:loss = 143.3574, step = 13673 (43.182 sec)
# INFO:tensorflow:lr = 0.0023724507 (43.182 sec)
# INFO:tensorflow:global_step/sec: 2.30982
# INFO:tensorflow:loss = 176.65228, step = 13773 (43.294 sec)
# INFO:tensorflow:lr = 0.0023683815 (43.294 sec)
# INFO:tensorflow:global_step/sec: 2.32235
# INFO:tensorflow:loss = 146.15347, step = 13873 (43.060 sec)
# INFO:tensorflow:lr = 0.0023643195 (43.060 sec)
# INFO:tensorflow:global_step/sec: 2.32792
# INFO:tensorflow:loss = 124.126045, step = 13973 (42.957 sec)
# INFO:tensorflow:lr = 0.0023602645 (42.957 sec)
# INFO:tensorflow:global_step/sec: 2.35953
# INFO:tensorflow:loss = 138.91489, step = 14073 (42.382 sec)
# INFO:tensorflow:lr = 0.0023562163 (42.381 sec)
# INFO:tensorflow:global_step/sec: 2.3236
# INFO:tensorflow:loss = 181.62553, step = 14173 (43.037 sec)
# INFO:tensorflow:lr = 0.0023521753 (43.037 sec)
# INFO:tensorflow:global_step/sec: 2.24201
# INFO:tensorflow:loss = 185.95245, step = 14273 (44.602 sec)
# INFO:tensorflow:lr = 0.002348141 (44.602 sec)
# INFO:tensorflow:global_step/sec: 2.38733
# INFO:tensorflow:loss = 220.73868, step = 14373 (41.889 sec)
# INFO:tensorflow:lr = 0.002344114 (41.889 sec)
# INFO:tensorflow:Saving checkpoints for 14378 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.4879731.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-14378
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 692.5688
# [test] Raw Hits@1: 25.8
# [test] Raw Hits@3: 38.800000000000004
# [test] Raw Hits@5: 44.440000000000005
# [test] Raw Hits@10: 51.18000000000001
# [test] Filtered Mean Rank: 676.5352
# [test] Filtered Hits@1: 31.480000000000004
# [test] Filtered Hits@3: 43.519999999999996
# [test] Filtered Hits@5: 47.92
# [test] Filtered Hits@10: 54.17999999999999
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-14378
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 14379 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 137.82695, step = 14379
# INFO:tensorflow:lr = 0.0023438726
# INFO:tensorflow:global_step/sec: 2.30006
# INFO:tensorflow:loss = 108.80695, step = 14479 (43.479 sec)
# INFO:tensorflow:lr = 0.0023398525 (43.478 sec)
# INFO:tensorflow:global_step/sec: 2.29893
# INFO:tensorflow:loss = 176.29486, step = 14579 (43.499 sec)
# INFO:tensorflow:lr = 0.0023358394 (43.499 sec)
# INFO:tensorflow:global_step/sec: 2.31237
# INFO:tensorflow:loss = 153.19968, step = 14679 (43.245 sec)
# INFO:tensorflow:lr = 0.0023318331 (43.245 sec)
# INFO:tensorflow:global_step/sec: 2.43221
# INFO:tensorflow:loss = 106.59085, step = 14779 (41.115 sec)
# INFO:tensorflow:lr = 0.002327834 (41.115 sec)
# INFO:tensorflow:global_step/sec: 2.33657
# INFO:tensorflow:loss = 114.91332, step = 14879 (42.798 sec)
# INFO:tensorflow:lr = 0.0023238414 (42.798 sec)
# INFO:tensorflow:global_step/sec: 2.3034
# INFO:tensorflow:loss = 127.94005, step = 14979 (43.414 sec)
# INFO:tensorflow:lr = 0.0023198558 (43.414 sec)
# INFO:tensorflow:global_step/sec: 2.35405
# INFO:tensorflow:loss = 86.438324, step = 15079 (42.480 sec)
# INFO:tensorflow:lr = 0.002315877 (42.480 sec)
# INFO:tensorflow:global_step/sec: 2.32379
# INFO:tensorflow:loss = 148.85269, step = 15179 (43.033 sec)
# INFO:tensorflow:lr = 0.0023119051 (43.033 sec)
# INFO:tensorflow:global_step/sec: 2.35731
# INFO:tensorflow:loss = 132.30347, step = 15279 (42.421 sec)
# INFO:tensorflow:lr = 0.00230794 (42.422 sec)
# INFO:tensorflow:global_step/sec: 2.30797
# INFO:tensorflow:loss = 197.50015, step = 15379 (43.328 sec)
# INFO:tensorflow:lr = 0.0023039817 (43.328 sec)
# INFO:tensorflow:global_step/sec: 2.482
# INFO:tensorflow:loss = 155.5434, step = 15479 (40.290 sec)
# INFO:tensorflow:lr = 0.00230003 (40.290 sec)
# INFO:tensorflow:Saving checkpoints for 15484 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.9183002.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-15484
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 648.656
# [test] Raw Hits@1: 26.540000000000003
# [test] Raw Hits@3: 39.839999999999996
# [test] Raw Hits@5: 45.34
# [test] Raw Hits@10: 52.400000000000006
# [test] Filtered Mean Rank: 632.6338
# [test] Filtered Hits@1: 32.9
# [test] Filtered Hits@3: 45.1
# [test] Filtered Hits@5: 49.54
# [test] Filtered Hits@10: 55.58
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-15484
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 15485 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 93.56018, step = 15485
# INFO:tensorflow:lr = 0.0022997933
# INFO:tensorflow:global_step/sec: 2.53254
# INFO:tensorflow:loss = 92.968376, step = 15585 (39.487 sec)
# INFO:tensorflow:lr = 0.002295849 (39.487 sec)
# INFO:tensorflow:global_step/sec: 2.51742
# INFO:tensorflow:loss = 84.76619, step = 15685 (39.723 sec)
# INFO:tensorflow:lr = 0.0022919113 (39.723 sec)
# INFO:tensorflow:global_step/sec: 2.25376
# INFO:tensorflow:loss = 108.24864, step = 15785 (44.370 sec)
# INFO:tensorflow:lr = 0.0022879804 (44.370 sec)
# INFO:tensorflow:global_step/sec: 2.30506
# INFO:tensorflow:loss = 87.97918, step = 15885 (43.383 sec)
# INFO:tensorflow:lr = 0.0022840563 (43.383 sec)
# INFO:tensorflow:global_step/sec: 2.28354
# INFO:tensorflow:loss = 112.783455, step = 15985 (43.792 sec)
# INFO:tensorflow:lr = 0.002280139 (43.792 sec)
# INFO:tensorflow:global_step/sec: 2.30372
# INFO:tensorflow:loss = 97.85097, step = 16085 (43.408 sec)
# INFO:tensorflow:lr = 0.0022762283 (43.408 sec)
# INFO:tensorflow:global_step/sec: 2.32629
# INFO:tensorflow:loss = 134.53375, step = 16185 (42.987 sec)
# INFO:tensorflow:lr = 0.0022723244 (42.987 sec)
# INFO:tensorflow:global_step/sec: 2.39232
# INFO:tensorflow:loss = 108.3732, step = 16285 (41.801 sec)
# INFO:tensorflow:lr = 0.002268427 (41.801 sec)
# INFO:tensorflow:global_step/sec: 2.40346
# INFO:tensorflow:loss = 102.175674, step = 16385 (41.606 sec)
# INFO:tensorflow:lr = 0.0022645365 (41.606 sec)
# INFO:tensorflow:global_step/sec: 2.36525
# INFO:tensorflow:loss = 129.49147, step = 16485 (42.279 sec)
# INFO:tensorflow:lr = 0.0022606526 (42.279 sec)
# INFO:tensorflow:global_step/sec: 2.34597
# INFO:tensorflow:loss = 120.030754, step = 16585 (42.626 sec)
# INFO:tensorflow:lr = 0.0022567755 (42.628 sec)
# INFO:tensorflow:Saving checkpoints for 16590 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.41451.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-16590
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 649.5566
# [test] Raw Hits@1: 26.919999999999998
# [test] Raw Hits@3: 40.0
# ...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-71890
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 71891 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 0.4210859, step = 71891
# INFO:tensorflow:lr = 0.0008733429
# INFO:tensorflow:global_step/sec: 2.47724
# INFO:tensorflow:loss = 0.37641907, step = 71991 (40.369 sec)
# INFO:tensorflow:lr = 0.00087184506 (40.368 sec)
# INFO:tensorflow:global_step/sec: 2.57947
# INFO:tensorflow:loss = 8.013223, step = 72091 (38.769 sec)
# INFO:tensorflow:lr = 0.0008703498 (38.769 sec)
# INFO:tensorflow:global_step/sec: 2.57973
# INFO:tensorflow:loss = 11.625432, step = 72191 (38.763 sec)
# INFO:tensorflow:lr = 0.000868857 (38.763 sec)
# INFO:tensorflow:global_step/sec: 2.52506
# INFO:tensorflow:loss = 1.7576666, step = 72291 (39.603 sec)
# INFO:tensorflow:lr = 0.00086736685 (39.603 sec)
# INFO:tensorflow:global_step/sec: 2.54101
# INFO:tensorflow:loss = 0.8862432, step = 72391 (39.354 sec)
# INFO:tensorflow:lr = 0.00086587924 (39.354 sec)
# INFO:tensorflow:global_step/sec: 2.60238
# INFO:tensorflow:loss = 2.8762994, step = 72491 (38.427 sec)
# INFO:tensorflow:lr = 0.0008643942 (38.427 sec)
# INFO:tensorflow:global_step/sec: 2.59564
# INFO:tensorflow:loss = 0.57796216, step = 72591 (38.526 sec)
# INFO:tensorflow:lr = 0.0008629117 (38.526 sec)
# INFO:tensorflow:global_step/sec: 2.52122
# INFO:tensorflow:loss = 7.2541842, step = 72691 (39.663 sec)
# INFO:tensorflow:lr = 0.00086143165 (39.664 sec)
# INFO:tensorflow:global_step/sec: 2.5629
# INFO:tensorflow:loss = 6.9421606, step = 72791 (39.018 sec)
# INFO:tensorflow:lr = 0.0008599542 (39.018 sec)
# INFO:tensorflow:global_step/sec: 2.58738
# INFO:tensorflow:loss = 6.214118, step = 72891 (38.649 sec)
# INFO:tensorflow:lr = 0.00085847935 (38.650 sec)
# INFO:tensorflow:global_step/sec: 2.52524
# INFO:tensorflow:loss = 8.385664, step = 72991 (39.600 sec)
# INFO:tensorflow:lr = 0.000857007 (39.600 sec)
# INFO:tensorflow:Saving checkpoints for 72996 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.00012897055.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-72996
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 521.2056
# [test] Raw Hits@1: 32.58
# [test] Raw Hits@3: 45.800000000000004
# [test] Raw Hits@5: 52.12
# [test] Raw Hits@10: 60.72
# [test] Filtered Mean Rank: 505.1784
# [test] Filtered Hits@1: 40.64
# [test] Filtered Hits@3: 54.279999999999994
# [test] Filtered Hits@5: 59.8
# [test] Filtered Hits@10: 67.16
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-72996
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 72997 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 1.6140453, step = 72997
# INFO:tensorflow:lr = 0.00085691875
# INFO:tensorflow:global_step/sec: 2.42367
# INFO:tensorflow:loss = 4.213119, step = 73097 (41.262 sec)
# INFO:tensorflow:lr = 0.000855449 (41.261 sec)
# INFO:tensorflow:global_step/sec: 2.57463
# INFO:tensorflow:loss = 2.038479, step = 73197 (38.840 sec)
# INFO:tensorflow:lr = 0.0008539818 (38.840 sec)
# INFO:tensorflow:global_step/sec: 2.53374
# INFO:tensorflow:loss = 20.343224, step = 73297 (39.467 sec)
# INFO:tensorflow:lr = 0.00085251714 (39.467 sec)
# INFO:tensorflow:global_step/sec: 2.48859
# INFO:tensorflow:loss = 0.66611344, step = 73397 (40.184 sec)
# INFO:tensorflow:lr = 0.0008510551 (40.183 sec)
# INFO:tensorflow:global_step/sec: 2.52953
# INFO:tensorflow:loss = 3.4588957, step = 73497 (39.533 sec)
# INFO:tensorflow:lr = 0.0008495954 (39.533 sec)
# INFO:tensorflow:global_step/sec: 2.60336
# INFO:tensorflow:loss = 2.2236872, step = 73597 (38.412 sec)
# INFO:tensorflow:lr = 0.0008481383 (38.412 sec)
# INFO:tensorflow:global_step/sec: 2.50587
# INFO:tensorflow:loss = 2.8701792, step = 73697 (39.906 sec)
# INFO:tensorflow:lr = 0.00084668363 (39.906 sec)
# INFO:tensorflow:global_step/sec: 2.55152
# INFO:tensorflow:loss = 1.666337, step = 73797 (39.192 sec)
# INFO:tensorflow:lr = 0.00084523147 (39.192 sec)
# INFO:tensorflow:global_step/sec: 2.61466
# INFO:tensorflow:loss = 4.8064675, step = 73897 (38.246 sec)
# INFO:tensorflow:lr = 0.00084378186 (38.246 sec)
# INFO:tensorflow:global_step/sec: 2.57221
# INFO:tensorflow:loss = 1.4514605, step = 73997 (38.877 sec)
# INFO:tensorflow:lr = 0.0008423347 (38.877 sec)
# INFO:tensorflow:global_step/sec: 2.53994
# INFO:tensorflow:loss = 11.855795, step = 74097 (39.371 sec)
# INFO:tensorflow:lr = 0.00084089 (39.371 sec)
# INFO:tensorflow:Saving checkpoints for 74102 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.6582558e-05.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-74102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 508.7264
# [test] Raw Hits@1: 31.919999999999998
# [test] Raw Hits@3: 46.300000000000004
# [test] Raw Hits@5: 52.339999999999996
# [test] Raw Hits@10: 61.0
# [test] Filtered Mean Rank: 492.696
# [test] Filtered Hits@1: 40.04
# [test] Filtered Hits@3: 54.82
# [test] Filtered Hits@5: 60.519999999999996
# [test] Filtered Hits@10: 67.66
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-74102
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 74103 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 0.36988574, step = 74103
# INFO:tensorflow:lr = 0.00084080343
# INFO:tensorflow:global_step/sec: 2.41352
# INFO:tensorflow:loss = 0.59795225, step = 74203 (41.435 sec)
# INFO:tensorflow:lr = 0.0008393614 (41.434 sec)
# INFO:tensorflow:global_step/sec: 2.54163
# INFO:tensorflow:loss = 18.446571, step = 74303 (39.345 sec)
# INFO:tensorflow:lr = 0.00083792175 (39.345 sec)
# INFO:tensorflow:global_step/sec: 2.39218
# INFO:tensorflow:loss = 4.5227857, step = 74403 (41.803 sec)
# INFO:tensorflow:lr = 0.0008364846 (41.803 sec)
# INFO:tensorflow:global_step/sec: 2.5445
# INFO:tensorflow:loss = 2.991467, step = 74503 (39.300 sec)
# INFO:tensorflow:lr = 0.00083505 (39.300 sec)
# INFO:tensorflow:global_step/sec: 2.48834
# INFO:tensorflow:loss = 4.9847555, step = 74603 (40.187 sec)
# INFO:tensorflow:lr = 0.00083361776 (40.187 sec)
# INFO:tensorflow:global_step/sec: 2.43201
# INFO:tensorflow:loss = 1.0221622, step = 74703 (41.119 sec)
# INFO:tensorflow:lr = 0.00083218806 (41.118 sec)
# INFO:tensorflow:global_step/sec: 2.37204
# INFO:tensorflow:loss = 4.193805, step = 74803 (42.158 sec)
# INFO:tensorflow:lr = 0.0008307608 (42.159 sec)
# INFO:tensorflow:global_step/sec: 2.49565
# INFO:tensorflow:loss = 3.9946783, step = 74903 (40.069 sec)
# INFO:tensorflow:lr = 0.0008293359 (40.069 sec)
# INFO:tensorflow:global_step/sec: 2.41961
# INFO:tensorflow:loss = 3.7850556, step = 75003 (41.332 sec)
# INFO:tensorflow:lr = 0.00082791364 (41.332 sec)
# INFO:tensorflow:global_step/sec: 2.40101
# INFO:tensorflow:loss = 3.840806, step = 75103 (41.646 sec)
# INFO:tensorflow:lr = 0.00082649355 (41.646 sec)
# INFO:tensorflow:global_step/sec: 2.43196
# INFO:tensorflow:loss = 4.1660523, step = 75203 (41.119 sec)
# INFO:tensorflow:lr = 0.00082507613 (41.119 sec)
# INFO:tensorflow:Saving checkpoints for 75208 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.556311e-05.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-75208
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 504.7558
# [test] Raw Hits@1: 32.32
# [test] Raw Hits@3: 46.339999999999996
# [test] Raw Hits@5: 52.480000000000004
# [test] Raw Hits@10: 61.38
# [test] Filtered Mean Rank: 488.716
# [test] Filtered Hits@1: 40.64
# [test] Filtered Hits@3: 55.14
# [test] Filtered Hits@5: 61.1
# [test] Filtered Hits@10: 68.28
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-75208
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 75209 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 2.4254935, step = 75209
# INFO:tensorflow:lr = 0.0008249911
# INFO:tensorflow:global_step/sec: 2.31997
# INFO:tensorflow:loss = 4.714037, step = 75309 (43.105 sec)
# INFO:tensorflow:lr = 0.00082357624 (43.105 sec)
# INFO:tensorflow:global_step/sec: 2.31327
# INFO:tensorflow:loss = 5.253553, step = 75409 (43.228 sec)
# INFO:tensorflow:lr = 0.00082216365 (43.229 sec)
# INFO:tensorflow:global_step/sec: 2.44649
# INFO:tensorflow:loss = 7.610153, step = 75509 (40.875 sec)
# INFO:tensorflow:lr = 0.00082075363 (40.875 sec)
# INFO:tensorflow:global_step/sec: 2.37744
# INFO:tensorflow:loss = 8.187106, step = 75609 (42.062 sec)
# INFO:tensorflow:lr = 0.00081934594 (42.062 sec)
# INFO:tensorflow:global_step/sec: 2.46385
# INFO:tensorflow:loss = 17.253954, step = 75709 (40.587 sec)
# INFO:tensorflow:lr = 0.0008179406 (40.587 sec)
# INFO:tensorflow:global_step/sec: 2.43573
# INFO:tensorflow:loss = 4.402358, step = 75809 (41.056 sec)
# INFO:tensorflow:lr = 0.0008165378 (41.055 sec)
# INFO:tensorflow:global_step/sec: 2.44782
# INFO:tensorflow:loss = 10.391172, step = 75909 (40.853 sec)
# INFO:tensorflow:lr = 0.00081513735 (40.853 sec)
# INFO:tensorflow:global_step/sec: 2.53473
# INFO:tensorflow:loss = 3.8418198, step = 76009 (39.452 sec)
# INFO:tensorflow:lr = 0.0008137394 (39.452 sec)
# INFO:tensorflow:global_step/sec: 2.47197
# INFO:tensorflow:loss = 2.174475, step = 76109 (40.454 sec)
# INFO:tensorflow:lr = 0.00081234373 (40.454 sec)
# INFO:tensorflow:global_step/sec: 2.56414
# INFO:tensorflow:loss = 1.36189, step = 76209 (39.000 sec)
# INFO:tensorflow:lr = 0.0008109504 (39.000 sec)
# INFO:tensorflow:global_step/sec: 2.53485
# INFO:tensorflow:loss = 8.994904, step = 76309 (39.450 sec)
# INFO:tensorflow:lr = 0.0008095596 (39.450 sec)
# INFO:tensorflow:Saving checkpoints for 76314 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.9045006e-05.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-76314
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 507.764
# [test] Raw Hits@1: 32.28
# [test] Raw Hits@3: 46.26
# [test] Raw Hits@5: 51.76
# [test] Raw Hits@10: 60.68
# [test] Filtered Mean Rank: 491.7264
# [test] Filtered Hits@1: 40.239999999999995
# [test] Filtered Hits@3: 53.800000000000004
# [test] Filtered Hits@5: 59.099999999999994
# [test] Filtered Hits@10: 67.28
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:
# [<tf.Variable 'e_embed:0' shape=(40943, 200) dtype=float32_ref>,
#  <tf.Variable 'p_embed:0' shape=(18, 200) dtype=float32_ref>,
#  <tf.Variable 'conv2d/kernel:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv2d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'dense/kernel:0' shape=(10368, 200) dtype=float32_ref>,
#  <tf.Variable 'dense/bias:0' shape=(200,) dtype=float32_ref>]
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-76314
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 76315 into ./ConvE/model.ckpt.
# INFO:tensorflow:loss = 1.5511022, step = 76315
# INFO:tensorflow:lr = 0.0008094762
# INFO:tensorflow:global_step/sec: 2.50019
# INFO:tensorflow:loss = 2.5568593, step = 76415 (39.998 sec)
# INFO:tensorflow:lr = 0.0008080879 (39.998 sec)
# INFO:tensorflow:global_step/sec: 2.47049
# INFO:tensorflow:loss = 2.8365073, step = 76515 (40.478 sec)
# INFO:tensorflow:lr = 0.0008067019 (40.478 sec)
# INFO:tensorflow:global_step/sec: 2.36342
# INFO:tensorflow:loss = 9.390091, step = 76615 (42.312 sec)
# INFO:tensorflow:lr = 0.0008053184 (42.312 sec)
# INFO:tensorflow:global_step/sec: 2.4331
# INFO:tensorflow:loss = 1.4849643, step = 76715 (41.099 sec)
# INFO:tensorflow:lr = 0.00080393715 (41.099 sec)
# INFO:tensorflow:global_step/sec: 2.55283
# INFO:tensorflow:loss = 7.7429266, step = 76815 (39.172 sec)
# INFO:tensorflow:lr = 0.00080255844 (39.172 sec)
# INFO:tensorflow:global_step/sec: 2.59192
# INFO:tensorflow:loss = 1.876231, step = 76915 (38.582 sec)
# INFO:tensorflow:lr = 0.00080118194 (38.582 sec)
# INFO:tensorflow:global_step/sec: 2.62809
# INFO:tensorflow:loss = 11.24466, step = 77015 (38.051 sec)
# INFO:tensorflow:lr = 0.00079980784 (38.051 sec)
# INFO:tensorflow:global_step/sec: 2.61334
# INFO:tensorflow:loss = 2.6203241, step = 77115 (38.265 sec)
# INFO:tensorflow:lr = 0.00079843606 (38.265 sec)
# INFO:tensorflow:global_step/sec: 2.63667
# INFO:tensorflow:loss = 1.1053087, step = 77215 (37.927 sec)
# INFO:tensorflow:lr = 0.0007970667 (37.927 sec)
# INFO:tensorflow:global_step/sec: 2.60884
# INFO:tensorflow:loss = 0.6373121, step = 77315 (38.331 sec)
# INFO:tensorflow:lr = 0.00079569966 (38.331 sec)
# INFO:tensorflow:global_step/sec: 2.54594
# INFO:tensorflow:loss = 5.766023, step = 77415 (39.279 sec)
# INFO:tensorflow:lr = 0.00079433486 (39.279 sec)
# INFO:tensorflow:Saving checkpoints for 77420 into ./ConvE/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.3441922e-05.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./ConvE/model.ckpt-77420
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [test] Raw Mean Rank: 503.054
# [test] Raw Hits@1: 32.800000000000004
# [test] Raw Hits@3: 45.9
# [test] Raw Hits@5: 52.26
# [test] Raw Hits@10: 60.58
# [test] Filtered Mean Rank: 487.0138
# [test] Filtered Hits@1: 40.68
# [test] Filtered Hits@3: 54.120000000000005
# [test] Filtered Hits@5: 59.72
# [test] Filtered Hits@10: 67.24
